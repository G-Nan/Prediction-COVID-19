# %%
pip install xmltodict
# Out:
# Requirement already satisfied: xmltodict in c:\users\pc\anaconda3\lib\site-packages (0.13.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from urllib import parse
import xmltodict
import requests
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from urllib.parse import unquote

# %%
def get_request_query(url, serviceKey, params, gubun):
    import urllib.parse as urlparse
    params = urlparse.urlencode(params)
    request_query = url + "?serviceKey=" + serviceKey + '&' + params + '&gubun=' + gubun 
    return request_query

Seoul_data = pd.DataFrame() # 최종데이터를 받을 데이터프레임

# %%
start_date = '20200729' # 2020년 7월 29일 ~ (차분 후 8월 데이터를 모두 사용하기 위함)
end_date = '20230305' # ~ 3월 5일까지 데이터 존재
date_list = [d.strftime('%Y-%m-%d') for d in pd.date_range(start=start_date, end=end_date, freq="D")]

# %%
url_base = "http://apis.data.go.kr/1352000/ODMS_COVID_04/callCovid04Api"
url_serviceKey = "2qbQVBtKT9B0MU%2BONommVKsHJNUzNczJOH3DqVI8CIETW28uJqTgK9SRiXRBCau0%2Fr8oeVltLeOwE%2BePIxQujg%3D%3D"
# url_pages = "1" #페이지당열갯수
url_gubun = '부산' #지역

urls = []
for date in date_list:
    params = {'pageNo' : '1', 'numOfRows' : '500', 'std_day' : date}
    urls.append(get_request_query(url_base, url_serviceKey, params, url_gubun))

# %%
req = requests.get(urls[1]).content
xmlObject = xmltodict.parse(req)

# %%
xmlObject
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE'},
#   'body': {'items': {'item': {'deathCnt': '3',
#      'defCnt': '171',
#      'gubun': '부산',
#      'gubunCn': '釜山',
#      'gubunEn': 'Busan',
#      'incDec': '0',
#      'isolClearCnt': '152',
#      'isolIngCnt': '16',
#      'localOccCnt': '0',
#      'overFlowCnt': '0',
#      'qurRate': '5.01',
#      'stdDay': '2020-07-30'}},
#    'numOfRows': '500',
#    'pageNo': '1',
#    'totalCount': '22704'}}}

# %%
dict_data = []

for url in tqdm(urls):
    req = requests.get(url).content
    xmlObject = xmltodict.parse(req)
    dict_data.append(xmlObject['response']['body']['items']['item'])
# Out:
#   0%|▏                                                                               | 2/950 [00:14<1:51:59,  7.09s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_11776\2164057513.py in <module>
#       2
#       3 for url in tqdm(urls):
# ----> 4     req = requests.get(url).content
#       5     xmlObject = xmltodict.parse(req)
#       6     dict_data.append(xmlObject['response']['body']['items']['item'])
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
concat_df = pd.DataFrame()
for data in dict_data:
    if type(data) == list:
        df = pd.DataFrame([data[0]])
        concat_df = pd.concat([concat_df, df], ignore_index=True)
    else:
        df = pd.DataFrame([data])
        concat_df = pd.concat([concat_df, df], ignore_index=True)

concat_df
# Out:
#     deathCnt   defCnt gubun gubunCn gubunEn incDec isolClearCnt isolIngCnt  \
# 0         11     1600    서울      首尔   Seoul      8         1423        166
# 1         11     1602    서울      首尔   Seoul      2         1433        158
# 2         11     1607    서울      首尔   Seoul      5         1441        155
# 3         11     1612    서울      首尔   Seoul      5         1448        153
# 4         11     1621    서울      首尔   Seoul      9         1461        149
# ..       ...      ...   ...     ...     ...    ...          ...        ...
# 943     6345  5926866    서울      首尔   Seoul   2301            0          0
# 944     6347  5928066    서울      首尔   Seoul   1200            0          0
# 945     6351  5930362    서울      首尔   Seoul   2296            0          0
# 946     6352  5932505    서울      首尔   Seoul   2214            0          0
# 947        0  5934513    서울      首尔   Seoul   2008            0          0
#
#     localOccCnt overFlowCnt qurRate      stdDay
# 0             8           0   16.44  2020-07-31
# 1             2           0   16.46  2020-08-01
# 2             5           0   16.51  2020-08-02
# 3             2           3   16.56  2020-08-03
# 4             6           3   16.65  2020-08-04
# ..          ...         ...     ...         ...
# 943        2301           0   62862  2023-03-01
# 944        1199           1   62875  2023-03-02
# 945        2292           4   62899  2023-03-03
# 946        2214           0   62922  2023-03-04
# 947        2007           1   62943  2023-03-05
#
# [948 rows x 12 columns]

# %%
use_df = concat_df[['gubun','defCnt','stdDay']]
col =['시도명','def_Acc','date']
use_df.columns = col
use_df.set_index('date', drop=True, inplace=True)

# %%
use_df
# Out:
#            시도명  def_Acc
# date
# 2020-07-29  서울     1589
# 2020-07-30  서울     1592
# 2020-07-31  서울     1600
# 2020-08-01  서울     1602
# 2020-08-02  서울     1607
# ...         ..      ...
# 2023-03-01  서울  5926866
# 2023-03-02  서울  5928066
# 2023-03-03  서울  5930362
# 2023-03-04  서울  5932505
# 2023-03-05  서울  5934513
#
# [950 rows x 2 columns]

# %%
use_df.to_csv(f'./drive/MyDrive/{url_gubun}_data.csv')

# %%
data = pd.read_csv(f'./drive/MyDrive/{url_gubun}_data.csv', index_col=['date'])
data
# Out:
#            시도명  def_Acc
# date
# 2020-07-29  서울     1589
# 2020-07-30  서울     1592
# 2020-07-31  서울     1600
# 2020-08-01  서울     1602
# 2020-08-02  서울     1607
# ...         ..      ...
# 2023-03-01  서울  5926866
# 2023-03-02  서울  5928066
# 2023-03-03  서울  5930362
# 2023-03-04  서울  5932505
# 2023-03-05  서울  5934513
#
# [950 rows x 2 columns]

# %%
data['daily_Acc'] = data['def_Acc'].diff()
data['DAC'] = data['daily_Acc'].diff()
data['DDAC'] = data['DAC'].diff()
# data.drop(data.index[:3], inplace=True)
data
# Out:
#            시도명  def_Acc  daily_Acc     DAC    DDAC
# date
# 2020-07-29  서울     1589        NaN     NaN     NaN
# 2020-07-30  서울     1592        3.0     NaN     NaN
# 2020-07-31  서울     1600        8.0     5.0     NaN
# 2020-08-01  서울     1602        2.0    -6.0   -11.0
# 2020-08-02  서울     1607        5.0     3.0     9.0
# ...         ..      ...        ...     ...     ...
# 2023-03-01  서울  5926866     2301.0   -25.0 -1728.0
# 2023-03-02  서울  5928066     1200.0 -1101.0 -1076.0
# 2023-03-03  서울  5930362     2296.0  1096.0  2197.0
# 2023-03-04  서울  5932505     2143.0  -153.0 -1249.0
# 2023-03-05  서울  5934513     2008.0  -135.0    18.0
#
# [950 rows x 5 columns]

# %%
data.to_csv(f'./drive/MyDrive/{url_gubun}_data.csv')
