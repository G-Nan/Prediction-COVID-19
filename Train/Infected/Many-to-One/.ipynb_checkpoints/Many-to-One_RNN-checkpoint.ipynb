# %%
import os
os.chdir('D:\\Gnan\\DA\\KMU\\Prediction-COVID-19')
from utils import *
from model import *
from trainer import *

from tqdm.notebook import tqdm
from torch.optim.adam import Adam
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# !pip install --force-reinstall -v "ipywidgets == 7.7.2"
# !pip install --force-reinstall -v "jupyterlab_widgets == 1.1.1"
# Out:
# Using pip 22.2.2 from C:\Users\PC\anaconda3\lib\site-packages\pip (python 3.9)
# Collecting ipywidgets==7.7.2
#   Using cached ipywidgets-7.7.2-py2.py3-none-any.whl (123 kB)
# Collecting ipykernel>=4.5.1
#   Downloading ipykernel-6.23.1-py3-none-any.whl (152 kB)
#      -------------------------------------- 152.2/152.2 kB 8.9 MB/s eta 0:00:00
# Collecting ipython>=4.0.0
#   Downloading ipython-8.13.2-py3-none-any.whl (797 kB)
#      ------------------------------------- 797.7/797.7 kB 24.6 MB/s eta 0:00:00
# Collecting widgetsnbextension~=3.6.0
#   Downloading widgetsnbextension-3.6.4-py2.py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 51.2 MB/s eta 0:00:00
# Collecting traitlets>=4.3.1
#   Downloading traitlets-5.9.0-py3-none-any.whl (117 kB)
#      ---------------------------------------- 117.4/117.4 kB ? eta 0:00:00
# Collecting jupyterlab-widgets<3,>=1.0.0
#   Downloading jupyterlab_widgets-1.1.4-py3-none-any.whl (246 kB)
#      ------------------------------------- 246.1/246.1 kB 15.7 MB/s eta 0:00:00
# Collecting ipython-genutils~=0.2.0
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting pyzmq>=20
#   Downloading pyzmq-25.1.0-cp39-cp39-win_amd64.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 70.9 MB/s eta 0:00:00
# Collecting nest-asyncio
#   Using cached nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# Collecting tornado>=6.1
#   Downloading tornado-6.3.2-cp38-abi3-win_amd64.whl (428 kB)
#      ------------------------------------- 428.4/428.4 kB 27.9 MB/s eta 0:00:00
# Collecting jupyter-core!=5.0.*,>=4.12
#   Downloading jupyter_core-5.3.0-py3-none-any.whl (93 kB)
#      ---------------------------------------- 93.2/93.2 kB ? eta 0:00:00
# Collecting debugpy>=1.6.5
#   Downloading debugpy-1.6.7-cp39-cp39-win_amd64.whl (4.8 MB)
#      ---------------------------------------- 4.8/4.8 MB 44.4 MB/s eta 0:00:00
# Collecting matplotlib-inline>=0.1
#   Using cached matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Collecting comm>=0.1.1
#   Downloading comm-0.1.3-py3-none-any.whl (6.6 kB)
# Collecting jupyter-client>=6.1.12
#   Downloading jupyter_client-8.2.0-py3-none-any.whl (103 kB)
#      -------------------------------------- 103.2/103.2 kB 5.8 MB/s eta 0:00:00
# Collecting psutil
#   Downloading psutil-5.9.5-cp36-abi3-win_amd64.whl (255 kB)
#      ---------------------------------------- 255.1/255.1 kB ? eta 0:00:00
# Collecting packaging
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      ---------------------------------------- 48.9/48.9 kB ? eta 0:00:00
# Collecting pickleshare
#   Using cached pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting jedi>=0.16
#   Using cached jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
# Collecting backcall
#   Using cached backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30
#   Downloading prompt_toolkit-3.0.38-py3-none-any.whl (385 kB)
#      ------------------------------------- 385.8/385.8 kB 25.0 MB/s eta 0:00:00
# Collecting typing-extensions
#   Downloading typing_extensions-4.6.2-py3-none-any.whl (31 kB)
# Collecting pygments>=2.4.0
#   Downloading Pygments-2.15.1-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 36.7 MB/s eta 0:00:00
# Collecting decorator
#   Using cached decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting colorama
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting stack-data
#   Using cached stack_data-0.6.2-py3-none-any.whl (24 kB)
# Collecting notebook>=4.4.1
#   Downloading notebook-6.5.4-py3-none-any.whl (529 kB)
#      ------------------------------------- 529.8/529.8 kB 32.5 MB/s eta 0:00:00
# Collecting parso<0.9.0,>=0.8.0
#   Using cached parso-0.8.3-py2.py3-none-any.whl (100 kB)
# Collecting python-dateutil>=2.8.2
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting importlib-metadata>=4.8.3
#   Downloading importlib_metadata-6.6.0-py3-none-any.whl (22 kB)
# Collecting platformdirs>=2.5
#   Downloading platformdirs-3.5.1-py3-none-any.whl (15 kB)
# Collecting pywin32>=300
#   Downloading pywin32-306-cp39-cp39-win_amd64.whl (9.3 MB)
#      ---------------------------------------- 9.3/9.3 MB 49.5 MB/s eta 0:00:00
# Collecting nbconvert>=5
#   Downloading nbconvert-7.4.0-py3-none-any.whl (285 kB)
#      ------------------------------------- 285.9/285.9 kB 17.2 MB/s eta 0:00:00
# Collecting argon2-cffi
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting Send2Trash>=1.8.0
#   Downloading Send2Trash-1.8.2-py3-none-any.whl (18 kB)
# Collecting prometheus-client
#   Downloading prometheus_client-0.17.0-py3-none-any.whl (60 kB)
#      ---------------------------------------- 60.6/60.6 kB ? eta 0:00:00
# Collecting nbformat
#   Downloading nbformat-5.9.0-py3-none-any.whl (77 kB)
#      ---------------------------------------- 77.6/77.6 kB ? eta 0:00:00
# Collecting terminado>=0.8.3
#   Using cached terminado-0.17.1-py3-none-any.whl (17 kB)
# Collecting nbclassic>=0.4.7
#   Downloading nbclassic-1.0.0-py3-none-any.whl (10.0 MB)
#      --------------------------------------- 10.0/10.0 MB 48.9 MB/s eta 0:00:00
# Collecting jinja2
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting wcwidth
#   Downloading wcwidth-0.2.6-py2.py3-none-any.whl (29 kB)
# Collecting executing>=1.2.0
#   Using cached executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting asttokens>=2.1.0
#   Using cached asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Collecting pure-eval
#   Using cached pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting six
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Collecting jupyter-server>=1.8
#   Downloading jupyter_server-2.6.0-py3-none-any.whl (375 kB)
#      ---------------------------------------- 375.0/375.0 kB ? eta 0:00:00
# Collecting notebook-shim>=0.2.3
#   Downloading notebook_shim-0.2.3-py3-none-any.whl (13 kB)
# Collecting bleach
#   Downloading bleach-6.0.0-py3-none-any.whl (162 kB)
#      ---------------------------------------- 162.5/162.5 kB ? eta 0:00:00
# Collecting mistune<3,>=2.0.3
#   Downloading mistune-2.0.5-py2.py3-none-any.whl (24 kB)
# Collecting tinycss2
#   Using cached tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      ---------------------------------------- 143.0/143.0 kB ? eta 0:00:00
# Collecting markupsafe>=2.0
#   Downloading MarkupSafe-2.1.2-cp39-cp39-win_amd64.whl (16 kB)
# Collecting pandocfilters>=1.4.1
#   Using cached pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.8.0-py3-none-any.whl (73 kB)
#      ---------------------------------------- 73.1/73.1 kB ? eta 0:00:00
# Collecting defusedxml
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.17.1-py3-none-any.whl (23 kB)
# Collecting jsonschema>=2.6
#   Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
# Collecting pywinpty>=1.1.0
#   Downloading pywinpty-2.0.10-cp39-none-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 45.2 MB/s eta 0:00:00
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.19.3-cp39-cp39-win_amd64.whl (62 kB)
#      ---------------------------------------- 62.7/62.7 kB ? eta 0:00:00
# Collecting attrs>=17.4.0
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      ---------------------------------------- 61.2/61.2 kB ? eta 0:00:00
# Collecting jupyter-server-terminals
#   Downloading jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Collecting jupyter-events>=0.6.0
#   Downloading jupyter_events-0.6.3-py3-none-any.whl (18 kB)
# Collecting websocket-client
#   Downloading websocket_client-1.5.2-py3-none-any.whl (56 kB)
#      ---------------------------------------- 56.6/56.6 kB ? eta 0:00:00
# Collecting overrides
#   Downloading overrides-7.3.1-py3-none-any.whl (17 kB)
# Collecting anyio>=3.1.0
#   Downloading anyio-3.7.0-py3-none-any.whl (80 kB)
#      ---------------------------------------- 80.9/80.9 kB ? eta 0:00:00
# Collecting cffi>=1.0.1
#   Downloading cffi-1.15.1-cp39-cp39-win_amd64.whl (179 kB)
#      ------------------------------------- 179.1/179.1 kB 10.6 MB/s eta 0:00:00
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4.1-py3-none-any.whl (36 kB)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.1.1-py3-none-any.whl (14 kB)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting idna>=2.8
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ---------------------------------------- 61.5/61.5 kB ? eta 0:00:00
# Collecting pycparser
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting rfc3339-validator
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting pyyaml>=5.3
#   Downloading PyYAML-6.0-cp39-cp39-win_amd64.whl (151 kB)
#      -------------------------------------- 151.6/151.6 kB 9.4 MB/s eta 0:00:00
# Collecting jsonpointer>1.13
#   Using cached jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Collecting uri-template
#   Using cached uri_template-1.2.0-py3-none-any.whl (10 kB)
# Collecting isoduration
#   Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting webcolors>=1.11
#   Downloading webcolors-1.13-py3-none-any.whl (14 kB)
# Collecting fqdn
#   Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting arrow>=0.15.0
#   Using cached arrow-1.2.3-py3-none-any.whl (66 kB)
# Installing collected packages: webencodings, wcwidth, pywin32, pure-eval, pickleshare, mistune, ipython-genutils, fastjsonschema, executing, backcall, zipp, websocket-client, webcolors, uri-template, typing-extensions, traitlets, tornado, tinycss2, soupsieve, sniffio, six, Send2Trash, rfc3986-validator, pyzmq, pyyaml, pywinpty, python-json-logger, pyrsistent, pygments, pycparser, psutil, prompt-toolkit, prometheus-client, platformdirs, parso, pandocfilters, packaging, overrides, nest-asyncio, markupsafe, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, idna, fqdn, exceptiongroup, defusedxml, decorator, debugpy, colorama, attrs, terminado, rfc3339-validator, python-dateutil, matplotlib-inline, jupyter-core, jsonschema, jinja2, jedi, importlib-metadata, comm, cffi, bleach, beautifulsoup4, asttokens, anyio, stack-data, nbformat, jupyter-server-terminals, jupyter-client, arrow, argon2-cffi-bindings, nbclient, isoduration, ipython, argon2-cffi, nbconvert, ipykernel, jupyter-events, jupyter-server, notebook-shim, nbclassic, notebook, widgetsnbextension, ipywidgets
#   Attempting uninstall: webencodings
#     Found existing installation: webencodings 0.5.1
#     Uninstalling webencodings-0.5.1:
#       Removing file or directory c:\users\pc\anaconda3\lib\site-packages\webencodings
#       Removing file or directory c:\users\pc\anaconda3\lib\site-packages\webencodings-0.5.1-py3.9.egg-info
#       Successfully uninstalled webencodings-0.5.1
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.5
#     Uninstalling wcwidth-0.2.5:
#       Removing file or directory c:\users\pc\anaconda3\lib\site-packages\wcwidth-0.2.5.dist-info\
#       Removing file or directory c:\users\pc\anaconda3\lib\site-packages\wcwidth\
#       Successfully uninstalled wcwidth-0.2.5
#   Attempting uninstall: pywin32
#     Found existing installation: pywin32 302
#     Uninstalling pywin32-302:
#       Removing file or directory c:\users\pc\anaconda3\lib\site-packages\__pycache__\pythoncom.cpython-39.pyc
#       Removing file or directory c:\users\pc\anaconda3\lib\site-packages\adodbapi
#       Removing file or directory c:\users\pc\anaconda3\lib\site-packages\isapi
#       Removing file or directory c:\users\pc\anaconda3\lib\site-packages\pythoncom.py
#       Removing file or directory c:\users\pc\anaconda3\lib\site-packages\pythonwin
#       Removing file or directory c:\users\pc\anaconda3\lib\site-packages\pywin32-302-py3.9.egg-info
#       Removing file or directory c:\users\pc\anaconda3\lib\site-packages\win32\lib\
#       Removing file or directory c:\users\pc\anaconda3\lib\site-packages\win32com
#       Removing file or directory c:\users\pc\anaconda3\lib\site-packages\win32comext
#       Successfully uninstalled pywin32-302
#   Rolling back uninstall of pywin32
#   Moving to c:\users\pc\anaconda3\lib\site-packages\__pycache__\pythoncom.cpython-39.pyc
#    from C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-uninstall-gkw9x58v\pythoncom.cpython-39.pyc
#   Moving to c:\users\pc\anaconda3\lib\site-packages\adodbapi
#    from C:\Users\PC\anaconda3\Lib\site-packages\~dodbapi
#   Moving to c:\users\pc\anaconda3\lib\site-packages\isapi
#    from C:\Users\PC\anaconda3\Lib\site-packages\~sapi
#   Moving to c:\users\pc\anaconda3\lib\site-packages\pythoncom.py
#    from C:\Users\Public\Documents\ESTsoft\CreatorTemp\pip-uninstall-0_sbuaqi\pythoncom.py
#   Moving to c:\users\pc\anaconda3\lib\site-packages\pythonwin
#    from C:\Users\PC\anaconda3\Lib\site-packages\~ythonwin
#   Moving to c:\users\pc\anaconda3\lib\site-packages\pywin32-302-py3.9.egg-info
#    from C:\Users\PC\anaconda3\Lib\site-packages\~ywin32-302-py3.9.egg-info
#   Moving to c:\users\pc\anaconda3\lib\site-packages\win32\lib\
#    from C:\Users\PC\anaconda3\Lib\site-packages\win32\~ib
#   Moving to c:\users\pc\anaconda3\lib\site-packages\win32com
#    from C:\Users\PC\anaconda3\Lib\site-packages\~in32com
#   Moving to c:\users\pc\anaconda3\lib\site-packages\win32comext
#    from C:\Users\PC\anaconda3\Lib\site-packages\~in32comext
# ERROR: Could not install packages due to an OSError.
# Consider using the `--user` option or check the permissions.
# Traceback (most recent call last):
#   File "C:\Users\PC\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 461, in run
#     installed = install_given_reqs(
#   File "C:\Users\PC\anaconda3\lib\site-packages\pip\_internal\req\__init__.py", line 73, in install_given_reqs
#     requirement.install(
#   File "C:\Users\PC\anaconda3\lib\site-packages\pip\_internal\req\req_install.py", line 790, in install
#     install_wheel(
#   File "C:\Users\PC\anaconda3\lib\site-packages\pip\_internal\operations\install\wheel.py", line 727, in install_wheel
#     _install_wheel(
#   File "C:\Users\PC\anaconda3\lib\site-packages\pip\_internal\operations\install\wheel.py", line 587, in _install_wheel
#     file.save()
#   File "C:\Users\PC\anaconda3\lib\site-packages\pip\_internal\operations\install\wheel.py", line 382, in save
#     os.unlink(self.dest_path)
# PermissionError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\PC\\anaconda3\\Lib\\site-packages\\win32\\_win32sysloader.pyd'
# Using pip 22.2.2 from C:\Users\PC\anaconda3\lib\site-packages\pip (python 3.9)
# Collecting jupyterlab_widgets==1.1.1
#   Using cached jupyterlab_widgets-1.1.1-py3-none-any.whl (245 kB)
# Installing collected packages: jupyterlab_widgets
#   Attempting uninstall: jupyterlab_widgets
#     Found existing installation: jupyterlab-widgets 1.0.0
#     Uninstalling jupyterlab-widgets-1.0.0:
#       Removing file or directory c:\users\pc\anaconda3\lib\site-packages\jupyterlab_widgets-1.0.0.dist-info\
#       Removing file or directory c:\users\pc\anaconda3\lib\site-packages\jupyterlab_widgets\
#       Successfully uninstalled jupyterlab-widgets-1.0.0
# Successfully installed jupyterlab_widgets-1.1.1

# %%
pip freeze
# Out:
# absl-py==1.3.0
# anyio==3.6.2
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# arrow==1.2.3
# asttokens==2.2.1
# astunparse==1.6.3
# attrs==22.1.0
# backcall==0.2.0
# beautifulsoup4==4.11.1
# bleach==5.0.1
# brotlipy==0.7.0
# cachetools==5.2.0
# certifi @ file:///C:/b/abs_ac29jvt43w/croot/certifi_1665076682579/work/certifi
# cffi @ file:///C:/b/abs_49n3v2hyhr/croot/cffi_1670423218144/work
# charset-normalizer @ file:///tmp/build/80754af9/charset-normalizer_1630003229654/work
# colorama==0.4.6
# colorlover==0.3.0
# comm==0.1.2
# contourpy==1.0.6
# cryptography @ file:///C:/b/abs_36x9ifdcl4/croot/cryptography_1665612655344/work
# cufflinks==0.17.3
# cycler==0.11.0
# debugpy==1.6.4
# decorator==5.1.1
# defusedxml==0.7.1
# entrypoints==0.4
# executing==1.2.0
# fastjsonschema==2.16.2
# flatbuffers==22.12.6
# flit_core @ file:///opt/conda/conda-bld/flit-core_1644941570762/work/source/flit_core
# fonttools==4.38.0
# fqdn==1.5.1
# gast==0.4.0
# google-auth==2.15.0
# google-auth-oauthlib==0.4.6
# google-pasta==0.2.0
# grpcio==1.51.1
# h5py==3.7.0
# idna @ file:///C:/b/abs_bdhbebrioa/croot/idna_1666125572046/work
# ipykernel==6.19.4
# ipython==8.7.0
# ipython-genutils==0.2.0
# ipywidgets==8.0.3
# isoduration==20.11.0
# jedi==0.18.2
# Jinja2==3.1.2
# joblib==1.2.0
# jsonpointer==2.3
# jsonschema==4.17.3
# jupyter==1.0.0
# jupyter-console==6.4.4
# jupyter-events==0.5.0
# jupyter_client==7.4.8
# jupyter_core==5.1.0
# jupyter_server==2.0.2
# jupyter_server_terminals==0.4.3
# jupyterlab-pygments==0.2.2
# jupyterlab-widgets==3.0.4
# keras==2.11.0
# kiwisolver==1.4.4
# libclang==14.0.6
# Markdown==3.4.1
# MarkupSafe==2.1.1
# matplotlib==3.6.2
# matplotlib-inline==0.1.6
# mistune==2.0.4
# mkl-fft==1.3.1
# mkl-random @ file:///C:/ci_310/mkl_random_1643050563308/work
# mkl-service==2.4.0
# nbclassic==0.4.8
# nbclient==0.7.2
# nbconvert==7.2.7
# nbformat==5.7.1
# nest-asyncio==1.5.6
# notebook==6.5.2
# notebook_shim==0.2.2
# numpy @ file:///C:/b/abs_5ct9ex77k9/croot/numpy_and_numpy_base_1668593740598/work
# oauthlib==3.2.2
# opencv-python==4.7.0.72
# opt-einsum==3.3.0
# packaging==22.0
# pandas==1.5.2
# pandocfilters==1.5.0
# parso==0.8.3
# patsy==0.5.3
# pickleshare==0.7.5
# Pillow==9.3.0
# platformdirs==2.6.0
# plotly==5.13.1
# prometheus-client==0.15.0
# prompt-toolkit==3.0.36
# protobuf==3.19.6
# psutil==5.9.4
# pure-eval==0.2.2
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycparser @ file:///tmp/build/80754af9/pycparser_1636541352034/work
# Pygments==2.13.0
# pyOpenSSL @ file:///opt/conda/conda-bld/pyopenssl_1643788558760/work
# pyparsing==3.0.9
# pyrsistent==0.19.2
# PySocks @ file:///C:/ci_310/pysocks_1642089375450/work
# python-dateutil==2.8.2
# python-json-logger==2.0.4
# pytz==2022.7
# pywin32==305
# pywinpty==2.0.9
# PyYAML==6.0
# pyzmq==24.0.1
# qtconsole==5.4.0
# QtPy==2.3.0
# requests @ file:///C:/ci/requests_1657735340829/work
# requests-oauthlib==1.3.1
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rsa==4.9
# scikit-learn==1.2.0
# scipy==1.9.3
# seaborn==0.12.1
# Send2Trash==1.8.0
# six @ file:///tmp/build/80754af9/six_1644875935023/work
# sklearn==0.0.post1
# sniffio==1.3.0
# soupsieve==2.3.2.post1
# stack-data==0.6.2
# statsmodels==0.13.5
# tenacity==8.2.2
# tensorboard==2.11.0
# tensorboard-data-server==0.6.1
# tensorboard-plugin-wit==1.8.1
# tensorflow==2.11.0
# tensorflow-estimator==2.11.0
# tensorflow-intel==2.11.0
# tensorflow-io-gcs-filesystem==0.29.0
# termcolor==2.1.1
# terminado==0.17.1
# threadpoolctl==3.1.0
# tinycss2==1.2.1
# torch==1.12.1
# torchaudio==0.12.1
# torchvision==0.13.1
# tornado==6.2
# tqdm==4.65.0
# traitlets==5.8.0
# typing_extensions @ file:///C:/b/abs_89eui86zuq/croot/typing_extensions_1669923792806/work
# uri-template==1.2.0
# urllib3 @ file:///C:/b/abs_21qa0j12xt/croot/urllib3_1670527000672/work
# wcwidth==0.2.5
# webcolors==1.12
# webencodings==0.5.1
# websocket-client==1.4.2
# Werkzeug==2.2.2
# widgetsnbextension==4.0.4
# win-inet-pton @ file:///C:/ci_310/win_inet_pton_1642658466512/work
# wincertstore==0.2
# wrapt==1.14.1
# xmltodict==0.13.0
# Note: you may need to restart the kernel to use updated packages.

# %%
path = 'Data/Cleaned_deathCnt/*.csv'
dic_files = Load_files.load_files(path, -14, -12)
data = dic_files['서울']
data['dailyCnt'] = data['defCnt'].diff().fillna(0)
data
# Out:
#       deathCnt   defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0            0        0    서울   Seoul     0.0             0           0
# 1            0        0    서울   Seoul     0.0             0           0
# 2            0        0    서울   Seoul     0.0             0           0
# 3            0        0    서울   Seoul     0.0             0           0
# 4            0        1    서울   Seoul     1.0             0           1
# ...        ...      ...   ...     ...     ...           ...         ...
# 1214      6471  6162486    서울   Seoul  4329.0             0           0
# 1215      6473  6166682    서울   Seoul  4196.0             0           0
# 1216      6476  6167953    서울   Seoul  1271.0             0           0
# 1217      6477  6173315    서울   Seoul  5362.0             0           0
# 1218      6479  6178627    서울   Seoul  5312.0             0           0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay  dailyCnt
# 0               0            0      0.0  2020-01-20       0.0
# 1               0            0      0.0  2020-01-21       0.0
# 2               0            0      0.0  2020-01-22       0.0
# 3               0            0      0.0  2020-01-23       0.0
# 4               0            1      0.0  2020-01-24       1.0
# ...           ...          ...      ...         ...       ...
# 1214         4371            0  65361.0  2023-05-20    4329.0
# 1215         4195            1  65406.0  2023-05-21    4196.0
# 1216         1271            0  65419.0  2023-05-22    1271.0
# 1217         5359            3  65476.0  2023-05-23    5362.0
# 1218         5310            2  65532.0  2023-05-24    5312.0
#
# [1219 rows x 12 columns]

# %%
learning_rates_list = [1e-3, 1e-4, 1e-5]
patiences_list = [20, 50, 100]
num_layers_list = [2, 4, 8]
batch_sizes_list = [16, 32, 64]
hidden_sizes_list = [8, 16, 32]
dropout_list = [0.25, 0.5]

hyperparameter_dict = {}
i = 0

for lr in learning_rates_list:
    for patience in patiences_list:
        for num_layers in num_layers_list:
            for batch_sizes in batch_sizes_list:
                for hidden_size in hidden_sizes_list:    
                    for dropout in dropout_list:
                        hyperparameter_dict[i] = [lr, patience, num_layers, batch_sizes, hidden_size, dropout]
                        i += 1
                        
print(i)
# Out:
# 486

# %%
criterion = nn.MSELoss()

input_size = 3
sequence_length = 60
num_epochs = 10000

df = Prepare_df.processing(data, 'stdDay', 'dailyCnt')

x = df.iloc[:, 0:]
y = df.iloc[:,:1]

ms = MinMaxScaler()
ss = StandardScaler()

ss.fit(x)
ms.fit(y)

mape_min = np.inf
best_model = {}

for hyperparameter in tqdm(hyperparameter_dict.values(), position = 0, leave = False):
    lr = hyperparameter[0]
    patience = hyperparameter[1]
    num_layers = hyperparameter[2]
    batch_size = hyperparameter[3]
    hidden_size = hyperparameter[4]
    dropout = hyperparameter[5]
    print('-------------------------------------------------------------------------------------')
    print('lr:', lr, ' patience:', patience, ' num_layers:', num_layers, 
          ' batch_size:', batch_size, ' hidden_size:', hidden_size, ' dropout:', dropout)
    
    x, y, x_ss, y_ms, train_loader, test_loader = Prepare_df.split_data(df, 800, 60, 1, batch_size, 'mto')
    

    model = RNN(input_size = input_size,
                hidden_size = hidden_size,
                sequence_length = sequence_length,
                num_layers = num_layers, 
                dropout = dropout, 
                device = device).to(device)

    optimizer = Adam(model.parameters(), lr = lr)
    
    loss_list, model, epoch = Trainer.Many_to_One(train_loader, 
                                           test_loader, 
                                           model, 
                                           criterion, 
                                           optimizer, 
                                           num_epochs, 
                                           patience,
                                           device)
    
    label_y, predicted = predict_mto(model, df, x_ss, y_ms)
    
    if mape_min > mape(label_y+1, predicted):
        mape_min = mape(label_y+1, predicted)
        best_model['RNN'] = [mape_min, model, epoch, lr, patience, num_layers, batch_size, hidden_size, dropout]
# Out:
#   0%|          | 0/486 [00:00<?, ?it/s]
# -------------------------------------------------------------------------------------
# lr: 0.001  patience: 20  num_layers: 2  batch_size: 16  hidden_size: 8  dropout: 0.25
#   0%|          | 0/10000 [00:00<?, ?it/s]
#  Early Stopping / epoch: 98 loss: 0.0006
# -------------------------------------------------------------------------------------
# lr: 0.001  patience: 20  num_layers: 2  batch_size: 16  hidden_size: 8  dropout: 0.5
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 44
#      35 model = RNN(input_size = input_size,
#      36             hidden_size = hidden_size,
#      37             sequence_length = sequence_length,
#      38             num_layers = num_layers,
#      39             dropout = dropout,
#      40             device = device).to(device)
#      42 optimizer = Adam(model.parameters(), lr = lr)
# ---> 44 loss_list, model, epoch = Trainer.Many_to_One(train_loader,
#      45                                        test_loader,
#      46                                        model,
#      47                                        criterion,
#      48                                        optimizer,
#      49                                        num_epochs,
#      50                                        patience,
#      51                                        device)
#      53 label_y, predicted = predict_mto(model, df, x_ss, y_ms)
#      55 if mape_min > mape(label_y+1, predicted):
#
# File D:\Gnan\DA\KMU\Prediction-COVID-19\trainer.py:39, in Trainer.Many_to_One(train_loader, test_loader, model, criterion, optimizer, num_epochs, patience, device)
#      36 loss = criterion(out, target)
#      38 optimizer.zero_grad()
# ---> 39 loss.backward()
#      40 optimizer.step()
#      41 running_loss += loss.item()
#
# File ~\anaconda3\envs\KMU_DA\lib\site-packages\torch\_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~\anaconda3\envs\KMU_DA\lib\site-packages\torch\autograd\__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
save_model(best_model['RNN'][1], "model/Infected/RNN.pth")
save_hyperparameter(best_model['RNN'][2:], "hyperparameter/Infected/RNN.pkl")

# %%
load_model(model, "model/Infected/RNN.pth")

# %%
plt.plot(loss_list)

# %%
label_y, predicted = predict_mto(model, df, x_ss, y_ms)

# %%
mape(label_y+1, predicted)

# %%
print(mape(label_y+1, predicted))
plotting(label_y, predicted, 800)

# %%
data
