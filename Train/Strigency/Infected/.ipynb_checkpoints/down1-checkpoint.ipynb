# %%
import os
os.chdir('D:\\Gnan\\DA\\KMU\\Prediction-COVID-19')
from utils import *
from model import *
from trainer import *

from tqdm.notebook import tqdm
from torch.optim.adam import Adam
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

import warnings
warnings.filterwarnings('ignore')

# %%
var1 = 'Infected'
var2 = 'down1'

path = f'Data/Stricgency/{var1}/{var2}/*.csv'
dic_files = Load_files.load_files(path, -17, -15)
dic_files
# Out:
# {'강원':      Unnamed: 0  deathCnt  defCnt gubun     gubunEn  incDec  isolClearCnt  \
#  0             0         3     266    강원  Gangwon-do    14.0           228
#  1             1         3     273    강원  Gangwon-do     7.0           228
#  2             2         3     279    강원  Gangwon-do     6.0           228
#  3             3         3     279    강원  Gangwon-do     0.0           232
#  4             4         3     282    강원  Gangwon-do     3.0           233
#  ..          ...       ...     ...   ...         ...     ...           ...
#  202         202        50    2979    강원  Gangwon-do    25.0          2718
#  203         203        50    2995    강원  Gangwon-do    16.0          2740
#  204         204        50    3003    강원  Gangwon-do     8.0          2741
#  205         205        50    3010    강원  Gangwon-do     7.0          2771
#  206         206        50    3039    강원  Gangwon-do    29.0          2790
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0            35           14            0    17.27  2020-10-28
#  1            42            7            0    17.72  2020-10-29
#  2            48            6            0    18.11  2020-10-30
#  3            44            0            0    18.11  2020-10-31
#  4            46            3            0    18.31  2020-11-01
#  ..          ...          ...          ...      ...         ...
#  202         211           25            0   193.37  2021-05-18
#  203         205           16            0   194.41  2021-05-19
#  204         212            8            0   194.93  2021-05-20
#  205         189            7            0   195.39  2021-05-21
#  206         199           29            0   197.27  2021-05-22
#
#  [207 rows x 12 columns],
#  '경기':      Unnamed: 0  deathCnt  defCnt gubun      gubunEn  incDec  isolClearCnt  \
#  0             0        89    5286    경기  Gyeonggi-do      31          4605
#  1             1        89    5344    경기  Gyeonggi-do      58          4636
#  2             2        89    5376    경기  Gyeonggi-do      32          4655
#  3             3        89    5403    경기  Gyeonggi-do      27          4686
#  4             4        89    5441    경기  Gyeonggi-do      38          4710
#  ..          ...       ...     ...   ...          ...     ...           ...
#  202         202       617   37055    경기  Gyeonggi-do     137         34228
#  203         203       621   37219    경기  Gyeonggi-do     164         34374
#  204         204       623   37406    경기  Gyeonggi-do     187         34509
#  205         205       624   37570    경기  Gyeonggi-do     164         34629
#  206         206       625   37735    경기  Gyeonggi-do     165         34803
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0           592           28            3    39.89  2020-10-28
#  1           619           52            6    40.33  2020-10-29
#  2           632           23            9    40.57  2020-10-30
#  3           628           23            4    40.78  2020-10-31
#  4           642           36            2    41.06  2020-11-01
#  ..          ...          ...          ...      ...         ...
#  202        2210          134            3   279.65  2021-05-18
#  203        2224          159            5   280.89  2021-05-19
#  204        2274          183            4   282.30  2021-05-20
#  205        2317          161            3   283.54  2021-05-21
#  206        2307          163            2   284.78  2021-05-22
#
#  [207 rows x 12 columns],
#  '경남':      Unnamed: 0  deathCnt  defCnt gubun           gubunEn  incDec  \
#  0             0         0     314    경남  Gyeongsangnam-do     3.0
#  1             1         0     314    경남  Gyeongsangnam-do     0.0
#  2             2         0     315    경남  Gyeongsangnam-do     1.0
#  3             3         0     316    경남  Gyeongsangnam-do     1.0
#  4             4         0     318    경남  Gyeongsangnam-do     2.0
#  ..          ...       ...     ...   ...               ...     ...
#  202         202        19    4479    경남  Gyeongsangnam-do    16.0
#  203         203        19    4495    경남  Gyeongsangnam-do    16.0
#  204         204        19    4507    경남  Gyeongsangnam-do    12.0
#  205         205        19    4525    경남  Gyeongsangnam-do    18.0
#  206         206        19    4546    경남  Gyeongsangnam-do    21.0
#
#       isolClearCnt  isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0             295          19            3            0     9.34  2020-10-28
#  1             296          18            0            0     9.34  2020-10-29
#  2             299          16            0            1     9.37  2020-10-30
#  3             299          17            1            0     9.40  2020-10-31
#  4             299          19            2            0     9.46  2020-11-01
#  ..            ...         ...          ...          ...      ...         ...
#  202          4134         326           15            1   133.25  2021-05-18
#  203          4166         310           16            0   133.73  2021-05-19
#  204          4182         306           12            0   134.08  2021-05-20
#  205          4212         294           18            0   134.62  2021-05-21
#  206          4234         293           21            0   135.24  2021-05-22
#
#  [207 rows x 12 columns],
#  '경북':      Unnamed: 0  deathCnt  defCnt gubun           gubunEn  incDec  \
#  0             0        57    1586    경북  Gyeongsangbuk-do     5.0
#  1             1        57    1587    경북  Gyeongsangbuk-do     1.0
#  2             2        57    1587    경북  Gyeongsangbuk-do     0.0
#  3             3        57    1587    경북  Gyeongsangbuk-do     0.0
#  4             4        57    1587    경북  Gyeongsangbuk-do     0.0
#  ..          ...       ...     ...   ...               ...     ...
#  202         202        81    4497    경북  Gyeongsangbuk-do    23.0
#  203         203        81    4521    경북  Gyeongsangbuk-do    24.0
#  204         204        81    4554    경북  Gyeongsangbuk-do    33.0
#  205         205        82    4565    경북  Gyeongsangbuk-do    11.0
#  206         206        82    4581    경북  Gyeongsangbuk-do    16.0
#
#       isolClearCnt  isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0            1511          18            5            0    59.57  2020-10-28
#  1            1511          19            0            1    59.61  2020-10-29
#  2            1513          17            0            0    59.61  2020-10-30
#  3            1514          16            0            0    59.61  2020-10-31
#  4            1516          14            0            0    59.61  2020-11-01
#  ..            ...         ...          ...          ...      ...         ...
#  202          4136         280           21            2   168.90  2021-05-18
#  203          4173         267           24            0   169.80  2021-05-19
#  204          4188         285           33            0   171.04  2021-05-20
#  205          4208         275           11            0   171.45  2021-05-21
#  206          4215         284           15            1   172.06  2021-05-22
#
#  [207 rows x 12 columns],
#  '광주':      Unnamed: 0  deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  \
#  0             0         3     509    광주  Gwangju     0.0           498
#  1             1         3     511    광주  Gwangju     2.0           498
#  2             2         3     511    광주  Gwangju     0.0           500
#  3             3         3     511    광주  Gwangju     0.0           500
#  4             4         3     514    광주  Gwangju     3.0           500
#  ..          ...       ...     ...   ...      ...     ...           ...
#  202         202        22    2637    광주  Gwangju    11.0          2453
#  203         203        22    2641    광주  Gwangju     4.0          2463
#  204         204        22    2656    광주  Gwangju    15.0          2468
#  205         205        22    2669    광주  Gwangju    13.0          2489
#  206         206        22    2684    광주  Gwangju    15.0          2512
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0             8            0            0    34.94  2020-10-28
#  1            10            1            1    35.08  2020-10-29
#  2             8            0            0    35.08  2020-10-30
#  3             8            0            0    35.08  2020-10-31
#  4            11            0            3    35.29  2020-11-01
#  ..          ...          ...          ...      ...         ...
#  202         162           11            0   181.03  2021-05-18
#  203         156            4            0   181.30  2021-05-19
#  204         166           15            0   182.33  2021-05-20
#  205         158           13            0   183.22  2021-05-21
#  206         150           15            0   184.25  2021-05-22
#
#  [207 rows x 12 columns],
#  '대구':      Unnamed: 0  deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  \
#  0             0       196    7152    대구   Daegu     2.0          6942
#  1             1       196    7155    대구   Daegu     3.0          6943
#  2             2       196    7165    대구   Daegu    10.0          6943
#  3             3       196    7174    대구   Daegu     9.0          6943
#  4             4       196    7176    대구   Daegu     2.0          6943
#  ..          ...       ...     ...   ...     ...     ...           ...
#  202         202       221    9521    대구   Daegu    23.0          9194
#  203         203       221    9544    대구   Daegu    23.0          9203
#  204         204       221    9553    대구   Daegu     9.0          9207
#  205         205       221    9572    대구   Daegu    19.0          9217
#  206         206       221    9628    대구   Daegu    56.0          9221
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0            14            2            0   293.54  2020-10-28
#  1            16            3            0   293.66  2020-10-29
#  2            26           10            0   294.07  2020-10-30
#  3            35            9            0   294.44  2020-10-31
#  4            37            2            0   294.52  2020-11-01
#  ..          ...          ...          ...      ...         ...
#  202         106           23            0   390.77  2021-05-18
#  203         120           23            0   391.71  2021-05-19
#  204         125            9            0   392.08  2021-05-20
#  205         134           18            1   392.86  2021-05-21
#  206         186           55            1   395.16  2021-05-22
#
#  [207 rows x 12 columns],
#  '대전':      Unnamed: 0  deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  \
#  0             0         6     442    대전  Daejeon     7.0           400
#  1             1         6     442    대전  Daejeon     0.0           401
#  2             2         6     442    대전  Daejeon     0.0           405
#  3             3         6     442    대전  Daejeon     0.0           407
#  4             4         6     442    대전  Daejeon     0.0           409
#  ..          ...       ...     ...   ...      ...     ...           ...
#  202         202        21    1920    대전  Daejeon    12.0          1771
#  203         203        21    1930    대전  Daejeon    10.0          1776
#  204         204        22    1938    대전  Daejeon     8.0          1785
#  205         205        22    1953    대전  Daejeon    15.0          1791
#  206         206        23    1958    대전  Daejeon     5.0          1803
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0            36            7            0    29.98  2020-10-28
#  1            35            0            0    29.98  2020-10-29
#  2            31            0            0    29.98  2020-10-30
#  3            29            0            0    29.98  2020-10-31
#  4            27            0            0    29.98  2020-11-01
#  ..          ...          ...          ...      ...         ...
#  202         128           12            0   130.24  2021-05-18
#  203         133           10            0   130.92  2021-05-19
#  204         131            7            1   131.47  2021-05-20
#  205         140           15            0   132.48  2021-05-21
#  206         132            5            0   132.82  2021-05-22
#
#  [207 rows x 12 columns],
#  '부산':      Unnamed: 0  deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  \
#  0             0         7     590    부산   Busan     0.0           483
#  1             1         7     590    부산   Busan     0.0           487
#  2             2         7     590    부산   Busan     0.0           495
#  3             3         8     592    부산   Busan     2.0           504
#  4             4         9     592    부산   Busan     0.0           516
#  ..          ...       ...     ...   ...     ...     ...           ...
#  202         202       122    5438    부산   Busan    13.0          5058
#  203         203       123    5465    부산   Busan    27.0          5087
#  204         204       123    5482    부산   Busan    17.0          5099
#  205         205       123    5497    부산   Busan    15.0          5118
#  206         206       123    5525    부산   Busan    28.0          5133
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0           100            0            0    17.29  2020-10-28
#  1            96            0            0    17.29  2020-10-29
#  2            88            0            0    17.29  2020-10-30
#  3            80            2            0    17.35  2020-10-31
#  4            67            0            0    17.35  2020-11-01
#  ..          ...          ...          ...      ...         ...
#  202         258           13            0   159.39  2021-05-18
#  203         255           27            0   160.18  2021-05-19
#  204         260           17            0   160.68  2021-05-20
#  205         256           13            2   161.12  2021-05-21
#  206         269           27            1   161.94  2021-05-22
#
#  [207 rows x 12 columns],
#  '서울':      Unnamed: 0  deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  \
#  0             0        77    5876    서울   Seoul    25.0          5432
#  1             1        78    5912    서울   Seoul    36.0          5460
#  2             2        78    5959    서울   Seoul    47.0          5473
#  3             3        78    6011    서울   Seoul    52.0          5493
#  4             4        78    6056    서울   Seoul    45.0          5494
#  ..          ...       ...     ...   ...     ...     ...           ...
#  202         202       472   41408    서울   Seoul   172.0         37954
#  203         203       474   41657    서울   Seoul   249.0         38113
#  204         204       475   41899    서울   Seoul   242.0         38264
#  205         205       479   42071    서울   Seoul   172.0         38407
#  206         206       480   42279    서울   Seoul   208.0         38857
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0           367           23            2    60.37  2020-10-28
#  1           374           36            0    60.74  2020-10-29
#  2           408           47            0    61.22  2020-10-30
#  3           440           51            1    61.76  2020-10-31
#  4           484           45            0    62.22  2020-11-01
#  ..          ...          ...          ...      ...         ...
#  202        2982          169            3   425.42  2021-05-18
#  203        3070          245            4   427.98  2021-05-19
#  204        3160          238            4   430.46  2021-05-20
#  205        3185          171            1   432.23  2021-05-21
#  206        2942          205            3   434.37  2021-05-22
#
#  [207 rows x 12 columns],
#  '세종':      Unnamed: 0  deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  \
#  0             0         0    79.0    세종  Sejong     0.0            78
#  1             1         0    79.0    세종  Sejong     0.0            78
#  2             2         0    79.0    세종  Sejong     0.0            78
#  3             3         0    82.0    세종  Sejong     3.0            78
#  4             4         0    82.0    세종  Sejong     0.0            78
#  ..          ...       ...     ...   ...     ...     ...           ...
#  202         202         1   403.0    세종  Sejong     4.0           375
#  203         203         1   406.0    세종  Sejong     3.0           378
#  204         204         1   415.0    세종  Sejong     9.0           385
#  205         205         1   416.0    세종  Sejong     1.0           385
#  206         206         1   416.0    세종  Sejong     0.0           386
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0           1.0            0            0    23.08  2020-10-28
#  1           1.0            0            0    23.08  2020-10-29
#  2           1.0            0            0    23.08  2020-10-30
#  3           4.0            3            0    23.95  2020-10-31
#  4           4.0            0            0    23.95  2020-11-01
#  ..          ...          ...          ...      ...         ...
#  202        27.0            4            0   117.72  2021-05-18
#  203        27.0            3            0   118.60  2021-05-19
#  204        29.0            8            1   121.23  2021-05-20
#  205        30.0            1            0   121.52  2021-05-21
#  206        29.0            0            0   121.52  2021-05-22
#
#  [207 rows x 12 columns],
#  '울산':      Unnamed: 0  deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  \
#  0             0         2     159    울산   Ulsan     0.0           153
#  1             1         2     161    울산   Ulsan     2.0           153
#  2             2         2     163    울산   Ulsan     2.0           153
#  3             3         2     163    울산   Ulsan     0.0           153
#  4             4         2     163    울산   Ulsan     0.0           154
#  ..          ...       ...     ...   ...     ...     ...           ...
#  202         202        39    2390    울산   Ulsan     6.0          2061
#  203         203        39    2417    울산   Ulsan    27.0          2110
#  204         204        39    2442    울산   Ulsan    25.0          2139
#  205         205        39    2455    울산   Ulsan    13.0          2168
#  206         206        39    2484    울산   Ulsan    29.0          2212
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0             4            0            0    13.86  2020-10-28
#  1             6            1            1    14.04  2020-10-29
#  2             8            0            2    14.21  2020-10-30
#  3             8            0            0    14.21  2020-10-31
#  4             7            0            0    14.21  2020-11-01
#  ..          ...          ...          ...      ...         ...
#  202         290            6            0   208.36  2021-05-18
#  203         268           27            0   210.72  2021-05-19
#  204         264           25            0   212.90  2021-05-20
#  205         248           13            0   214.03  2021-05-21
#  206         233           29            0   216.56  2021-05-22
#
#  [207 rows x 12 columns],
#  '인천':      Unnamed: 0  deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  \
#  0             0         9    1034    인천  Incheon    10.0           958
#  1             1         9    1039    인천  Incheon     5.0           974
#  2             2        10    1042    인천  Incheon     3.0           979
#  3             3        10    1045    인천  Incheon     3.0           986
#  4             4        11    1049    인천  Incheon     4.0           986
#  ..          ...       ...     ...   ...      ...     ...           ...
#  202         202        60    5971    인천  Incheon    16.0          5704
#  203         203        60    5994    인천  Incheon    23.0          5723
#  204         204        60    6007    인천  Incheon    13.0          5729
#  205         205        60    6019    인천  Incheon    12.0          5740
#  206         206        61    6034    인천  Incheon    15.0          5761
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0            67           10            0    34.98  2020-10-28
#  1            56            5            0    35.15  2020-10-29
#  2            53            2            1    35.25  2020-10-30
#  3            49            3            0    35.35  2020-10-31
#  4            52            0            4    35.49  2020-11-01
#  ..          ...          ...          ...      ...         ...
#  202         207           16            0   201.99  2021-05-18
#  203         211           23            0   202.77  2021-05-19
#  204         218           13            0   203.21  2021-05-20
#  205         219           12            0   203.61  2021-05-21
#  206         212           13            2   204.12  2021-05-22
#
#  [207 rows x 12 columns],
#  '전남':      Unnamed: 0  deathCnt  defCnt gubun       gubunEn  incDec  isolClearCnt  \
#  0             0         2     184    전남  Jeollanam-do     0.0           174
#  1             1         2     184    전남  Jeollanam-do     0.0           174
#  2             2         2     185    전남  Jeollanam-do     1.0           174
#  3             3         2     185    전남  Jeollanam-do     0.0           174
#  4             4         2     188    전남  Jeollanam-do     3.0           174
#  ..          ...       ...     ...   ...           ...     ...           ...
#  202         202        12    1328    전남  Jeollanam-do    12.0          1075
#  203         203        12    1338    전남  Jeollanam-do    10.0          1097
#  204         204        12    1345    전남  Jeollanam-do     7.0          1108
#  205         205        12    1362    전남  Jeollanam-do    17.0          1116
#  206         206        12    1378    전남  Jeollanam-do    16.0          1133
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0             8            0            0     9.87  2020-10-28
#  1             8            0            0     9.87  2020-10-29
#  2             9            1            0     9.92  2020-10-30
#  3             9            0            0     9.92  2020-10-31
#  4            12            3            0    10.08  2020-11-01
#  ..          ...          ...          ...      ...         ...
#  202         241           12            0    71.22  2021-05-18
#  203         229           10            0    71.75  2021-05-19
#  204         225            6            1    72.13  2021-05-20
#  205         234           17            0    73.04  2021-05-21
#  206         233           16            0    73.90  2021-05-22
#
#  [207 rows x 12 columns],
#  '전북':      Unnamed: 0  deathCnt  defCnt gubun       gubunEn  incDec  isolClearCnt  \
#  0             0         0     163    전북  Jeollabuk-do     3.0           143
#  1             1         0     164    전북  Jeollabuk-do     1.0           144
#  2             2         0     166    전북  Jeollabuk-do     2.0           144
#  3             3         0     166    전북  Jeollabuk-do     0.0           149
#  4             4         0     166    전북  Jeollabuk-do     0.0           149
#  ..          ...       ...     ...   ...           ...     ...           ...
#  202         202        58    2120    전북  Jeollabuk-do     7.0          1930
#  203         203        58    2129    전북  Jeollabuk-do     9.0          1943
#  204         204        58    2136    전북  Jeollabuk-do     7.0          1952
#  205         205        58    2152    전북  Jeollabuk-do    16.0          1966
#  206         206        58    2164    전북  Jeollabuk-do    12.0          1974
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0            20            3            0     8.97  2020-10-28
#  1            20            1            0     9.02  2020-10-29
#  2            22            1            1     9.13  2020-10-30
#  3            17            0            0     9.13  2020-10-31
#  4            17            0            0     9.13  2020-11-01
#  ..          ...          ...          ...      ...         ...
#  202         132            7            0   116.66  2021-05-18
#  203         128            9            0   117.15  2021-05-19
#  204         126            7            0   117.54  2021-05-20
#  205         128           15            1   118.42  2021-05-21
#  206         132           12            0   119.08  2021-05-22
#
#  [207 rows x 12 columns],
#  '제주':      Unnamed: 0  deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  \
#  0             0         0      59    제주    Jeju     0.0            59
#  1             1         0      59    제주    Jeju     0.0            59
#  2             2         0      59    제주    Jeju     0.0            59
#  3             3         0      59    제주    Jeju     0.0            59
#  4             4         0      59    제주    Jeju     0.0            59
#  ..          ...       ...     ...   ...     ...     ...           ...
#  202         202         1     897    제주    Jeju    11.0           744
#  203         203         1     901    제주    Jeju     4.0           765
#  204         204         1     907    제주    Jeju     6.0           770
#  205         205         1     912    제주    Jeju     5.0           793
#  206         206         1     919    제주    Jeju     7.0           812
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0             0            0            0     8.80  2020-10-28
#  1             0            0            0     8.80  2020-10-29
#  2             0            0            0     8.80  2020-10-30
#  3             0            0            0     8.80  2020-10-31
#  4             0            0            0     8.80  2020-11-01
#  ..          ...          ...          ...      ...         ...
#  202         152           10            1   133.73  2021-05-18
#  203         135            4            0   134.33  2021-05-19
#  204         136            6            0   135.22  2021-05-20
#  205         118            5            0   135.97  2021-05-21
#  206         106            7            0   137.01  2021-05-22
#
#  [207 rows x 12 columns],
#  '충남':      Unnamed: 0  deathCnt  defCnt gubun            gubunEn  incDec  \
#  0             0         8     532    충남  Chungcheongnam-do     1.0
#  1             1         8     533    충남  Chungcheongnam-do     1.0
#  2             2         8     536    충남  Chungcheongnam-do     3.0
#  3             3         8     541    충남  Chungcheongnam-do     5.0
#  4             4         8     550    충남  Chungcheongnam-do     9.0
#  ..          ...       ...     ...   ...                ...     ...
#  202         202        36    3287    충남  Chungcheongnam-do    15.0
#  203         203        37    3304    충남  Chungcheongnam-do    17.0
#  204         204        37    3323    충남  Chungcheongnam-do    19.0
#  205         205        37    3364    충남  Chungcheongnam-do    41.0
#  206         206        37    3381    충남  Chungcheongnam-do    17.0
#
#       isolClearCnt  isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0             484          40            1            0    25.07  2020-10-28
#  1             488          37            1            0    25.11  2020-10-29
#  2             488          40            3            0    25.25  2020-10-30
#  3             488          45            4            1    25.49  2020-10-31
#  4             488          54            9            0    25.91  2020-11-01
#  ..            ...         ...          ...          ...      ...         ...
#  202          3041         210           15            0   154.87  2021-05-18
#  203          3060         207           16            1   155.67  2021-05-19
#  204          3065         221           19            0   156.56  2021-05-20
#  205          3078         249           40            1   158.50  2021-05-21
#  206          3103         241           17            0   159.30  2021-05-22
#
#  [207 rows x 12 columns],
#  '충북':      Unnamed: 0  deathCnt  defCnt gubun            gubunEn  incDec  \
#  0             0         2     187    충북  Chungcheongbuk-do     0.0
#  1             1         2     187    충북  Chungcheongbuk-do     0.0
#  2             2         2     189    충북  Chungcheongbuk-do     2.0
#  3             3         2     189    충북  Chungcheongbuk-do     0.0
#  4             4         2     190    충북  Chungcheongbuk-do     1.0
#  ..          ...       ...     ...   ...                ...     ...
#  202         202        68    2795    충북  Chungcheongbuk-do    13.0
#  203         203        68    2816    충북  Chungcheongbuk-do    21.0
#  204         204        68    2829    충북  Chungcheongbuk-do    13.0
#  205         205        68    2841    충북  Chungcheongbuk-do    12.0
#  206         206        68    2847    충북  Chungcheongbuk-do     6.0
#
#       isolClearCnt  isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
#  0             169          16            0            0    11.69  2020-10-28
#  1             172          13            0            0    11.69  2020-10-29
#  2             174          13            0            2    11.82  2020-10-30
#  3             175          12            0            0    11.82  2020-10-31
#  4             175          13            1            0    11.88  2020-11-01
#  ..            ...         ...          ...          ...      ...         ...
#  202          2598         129           13            0   174.75  2021-05-18
#  203          2612         136           21            0   176.07  2021-05-19
#  204          2617         144           13            0   176.88  2021-05-20
#  205          2619         154           12            0   177.63  2021-05-21
#  206          2632         147            4            2   178.01  2021-05-22
#
#  [207 rows x 12 columns]}

# %%
city_list = ['강원', '경기', '경남', '경북', '광주', '대구', '대전', '부산', 
             '서울', '세종', '울산', '인천', '전남', '전북', '제주', '충남', '충북']
models_list = ['RNN', 'LSTM', 'GRU', 'BiRNN', 'BiLSTM', 'BiGRU', 
               'seq2seq_RNN', 'seq2seq_LSTM', 'seq2seq_GRU', 'seq2seq_BiRNN', 'seq2seq_BiLSTM', 'seq2seq_BiGRU']

for city in city_list:
    data = dic_files[city]

# %%
lr = 1e-3
batch_size = 64
patience = 50
dropout = 0.25
num_layers_list = [1, 2, 4]
hidden_sizes_list = [8, 16]
criterions_list = [nn.MSELoss(), criterion3]

hyperparameter_dict = {}
i = 0

for num_layers in num_layers_list:
    for hidden_size in hidden_sizes_list:
        for criterion in criterions_list:
            hyperparameter_dict[i] = [lr, patience, num_layers, hidden_size, dropout, criterion]
            i += 1
            
print(i)
# Out:
# 12

# %%
trained_data = {}
city_list = ['강원', '경기', '경남', '경북', '광주', '대구', '대전', '부산', 
             '서울', '세종', '울산', '인천', '전남', '전북', '제주', '충남', '충북']
models_list = ['RNN', 'LSTM', 'GRU', 'BiRNN', 'BiLSTM', 'BiGRU', 
               'seq2seq_RNN', 'seq2seq_LSTM', 'seq2seq_GRU', 'seq2seq_BiRNN', 'seq2seq_BiLSTM', 'seq2seq_BiGRU']


for city in tqdm(city_list, desc = 'cities', position = 0):
    data = dic_files[city]
    best_model = {}
    
    input_size = 3
    sequence_length = 60
    num_epochs = 10000

    df = Prepare_df.processing(data, 'stdDay', 'defCnt')

    x = df.iloc[:, 0:]
    y = df.iloc[:,:1]

    ms = MinMaxScaler()
    ss = StandardScaler()

    ss.fit(x)
    ms.fit(y)
    
    for num_model in tqdm(range(12), desc = f'{city}', position = 1):
        rmse_min = np.inf
        h = -1
        
        for hyperparameter in tqdm(hyperparameter_dict.values(), desc = f'{city}_{models_list[num_model]}', position = 2):
            h += 1
            if (num_model < 6) and (h % 2 == 1):
                continue
            model_name = models_list[num_model]
            lr = hyperparameter[0]
            patience = hyperparameter[1]
            num_layers = hyperparameter[2]
            hidden_size = hyperparameter[3]
            dropout = hyperparameter[4]

            if num_model < 6:
                criterion = nn.MSELoss()
            else:
                criterion = hyperparameter[5]

            if num_model < 6:
                x, y, x_ss, y_ms, train_loader, test_loader = Prepare_df.split_data(df, 138, 60, 1, batch_size, 'mto')
            else:
                x, y, x_ss, y_ms, train_loader, test_loader = Prepare_df.split_data(df, 132, 60, 7, batch_size, 'mtm')

            if num_model == 0:
                model = RNN(input_size = input_size,
                            hidden_size = hidden_size,
                            sequence_length = sequence_length,
                            num_layers = num_layers, 
                            dropout = dropout, 
                            device = device).to(device)

            elif num_model == 1:
                model = LSTM(input_size = input_size,
                             hidden_size = hidden_size,
                             sequence_length = sequence_length,
                             num_layers = num_layers, 
                             dropout = dropout, 
                             device = device).to(device)

            elif num_model == 2:
                model = GRU(input_size = input_size,
                            hidden_size = hidden_size,
                            sequence_length = sequence_length,
                            num_layers = num_layers, 
                            dropout = dropout, 
                            device = device).to(device)

            elif num_model == 3:
                model = BiRNN(input_size = input_size,
                              hidden_size = hidden_size,
                              sequence_length = sequence_length,
                              num_layers = num_layers, 
                              dropout = dropout, 
                              device = device).to(device)

            elif num_model == 4:
                model = BiLSTM(input_size = input_size,
                               hidden_size = hidden_size,
                               sequence_length = sequence_length,
                               num_layers = num_layers, 
                               dropout = dropout, 
                               device = device).to(device)

            elif num_model == 5:
                model = BiGRU(input_size = input_size,
                              hidden_size = hidden_size,
                              sequence_length = sequence_length,
                              num_layers = num_layers, 
                              dropout = dropout, 
                              device = device).to(device)

            elif num_model == 6:
                model = RNN_encoder_decoder(input_size = input_size, 
                                            hidden_size = hidden_size,
                                            num_layers = num_layers, 
                                            dropout = dropout,
                                            device = device).to(device)

            elif num_model == 7:
                model = LSTM_encoder_decoder(input_size = input_size, 
                                             hidden_size = hidden_size,
                                             num_layers = num_layers, 
                                             dropout = dropout,
                                             device = device).to(device)

            elif num_model == 8:
                model = GRU_encoder_decoder(input_size = input_size, 
                                            hidden_size = hidden_size,
                                            num_layers = num_layers, 
                                            dropout = dropout,
                                            device = device).to(device)

            elif num_model == 9:
                model = BiRNN_encoder_decoder(input_size = input_size, 
                                                hidden_size = hidden_size,
                                                num_layers = num_layers, 
                                                dropout = dropout,
                                                device = device).to(device)

            elif num_model == 10:
                model = BiLSTM_encoder_decoder(input_size = input_size, 
                                                  hidden_size = hidden_size,
                                                  num_layers = num_layers, 
                                                  dropout = dropout,
                                                  device = device).to(device)

            elif num_model == 11:
                model = BiGRU_encoder_decoder(input_size = input_size, 
                                                hidden_size = hidden_size,
                                                num_layers = num_layers, 
                                                dropout = dropout,
                                                device = device).to(device)            

            optimizer = Adam(model.parameters(), lr = lr)

            if num_model < 6:
                loss_list, model, epoch = Trainer.Many_to_One(train_loader, 
                                                              test_loader, 
                                                              model, 
                                                              criterion, 
                                                              optimizer, 
                                                              num_epochs, 
                                                              patience,
                                                              device)

                label_y, predicted = predict_mto(model, df, x_ss, y_ms)
                
                if rmse_min > rmse(label_y[-7:], predicted[-7:]):
                    rmse_min = rmse(label_y[-7:], predicted[-7:])
                    best_model[models_list[num_model]] = [rmse_min, model, loss_list, epoch, lr, patience, 
                                                          num_layers,hidden_size, dropout]
                
                
            else:
                loss_list, model, epoch = Trainer.Many_to_Many(train_loader, 
                                                               test_loader, 
                                                               model, 
                                                               criterion, 
                                                               optimizer, 
                                                               num_epochs, 
                                                               patience,
                                                               7,
                                                               device)        
                
                label_y, predicted, first_label_y, first_predicted, all_predicted = predict_mtm(model, df, x_ss, y_ms, 
                                                                                                7, 0.5, device)
    
                if rmse_min > rmse(label_y[-7:], predicted[-7:]):
                    rmse_min = rmse(label_y[-7:], predicted[-7:])
                    best_model[models_list[num_model]] = [rmse_min, model, loss_list, epoch, lr, patience, 
                                                          num_layers, hidden_size, dropout, criterion]
            
        
            
    trained_data[city] = best_model
# Out:
# cities:   0%|          | 0/17 [00:00<?, ?it/s]
# 강원:   0%|          | 0/12 [00:00<?, ?it/s]
# 강원_RNN:   0%|          | 0/12 [00:00<?, ?it/s]
# 강원_LSTM:   0%|          | 0/12 [00:00<?, ?it/s]
# 강원_GRU:   0%|          | 0/12 [00:00<?, ?it/s]
# 강원_BiRNN:   0%|          | 0/12 [00:00<?, ?it/s]
# 강원_BiLSTM:   0%|          | 0/12 [00:00<?, ?it/s]
# 강원_BiGRU:   0%|          | 0/12 [00:00<?, ?it/s]
# 강원_seq2seq_RNN:   0%|          | 0/12 [00:00<?, ?it/s]
# 강원_seq2seq_LSTM:   0%|          | 0/12 [00:00<?, ?it/s]

# %%
for city in trained_data:
    for name, values in trained_data[city].items():
        save_model(values[1].state_dict(), f"model/Stricgency/{var1}/{var2}/{city}_{name}.pth")
        save_hyperparameter(values[3:], f"hyperparameter/Stricgency/{var1}/{var2}/{city}_{name}.pkl")
