# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
# Initial conditions (from the literature)
N = 2412642-(221+9436+9091+124) #population size

S0 = N - 320 #everyone starts out as susceptible, except for 1 person that is infected
I10 = 300 #1 infected person
I20 = 20
D0 = 0
R0 = 0

# A grid of time points (in days)
t = np.linspace(0, 150) #from day 0 to day 500, generate 100 points

#parameters (from the literature)
alpha1 = 0.262
beta1 = 0.143
gamma1 = 0.00294


alpha2 = 0.291
beta2 = 0.143
gamma2 = 0.00194

# %%
# The SIDR model differential equations.
def deriv(y, t, alpha1, beta1, gamma1, alpha2, beta2, gamma2,):
    S, I1, I2, D, R = y
    dSdt = - (alpha1/ N) * S * I1- (alpha2/ N) * S * I2
    dI1dt = (alpha1/ N) * S * I1 - beta1 * I1 - gamma1 * I1
    dI2dt = (alpha2/ N) * S * I2 - beta1 * I2 - gamma1 * I2
    dDdt = gamma1 * I1+ gamma2 * I2
    dRdt = beta1 * I1 + beta2 * I2

    return dSdt, dI1dt, dI2dt, dDdt, dRdt

# %%
# Initial conditions vector
y0 = S0, I10, I20, D0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(alpha1, beta1, gamma1, alpha2, beta2, gamma2))
S, I1, I2, D, R = ret.T

# %%
S == I1 + I2 + R + D
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False])

# %%
# Plot the data
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.set_facecolor('xkcd:white')

ax.plot(t, S, 'violet', alpha=0.5, lw=2, label='Susceptible', linestyle='dashed')
ax.plot(t, I1, 'darkgreen', alpha=0.5, lw=2, label='Infected1', linestyle='dashed')
ax.plot(t, I2, 'orange', alpha=0.5, lw=2, label='Infected2', linestyle='dashed')
ax.plot(t, D, 'blue', alpha=0.5, lw=2, label='Dead', linestyle='dashed')
ax.plot(t, R, 'red', alpha=0.5, lw=2, label='Recovered', linestyle='dashed')

ax.set_xlabel('Time /days')
ax.set_ylabel('Number')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(visible=True, which='major', c='black', lw=0.2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()

# %%
#save to csv file
COVID_Data = np.asarray([t, S, I1, I2, D, R]) 
np.savetxt("Covid_practice1.csv", COVID_Data, delimiter=",")

# %%
import torch
from torch.autograd import grad
import torch.nn as nn
from numpy import genfromtxt
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %%
covid_data = genfromtxt('Covid_practice1.csv', delimiter=',') #in the form of [t,S,I1,I2,D,R]

# %%
covid_data
# Out:
# array([[0.00000000e+00, 3.06122449e+00, 6.12244898e+00, 9.18367347e+00,
#         1.22448980e+01, 1.53061224e+01, 1.83673469e+01, 2.14285714e+01,
#         2.44897959e+01, 2.75510204e+01, 3.06122449e+01, 3.36734694e+01,
#         3.67346939e+01, 3.97959184e+01, 4.28571429e+01, 4.59183673e+01,
#         4.89795918e+01, 5.20408163e+01, 5.51020408e+01, 5.81632653e+01,
#         6.12244898e+01, 6.42857143e+01, 6.73469388e+01, 7.04081633e+01,
#         7.34693878e+01, 7.65306122e+01, 7.95918367e+01, 8.26530612e+01,
#         8.57142857e+01, 8.87755102e+01, 9.18367347e+01, 9.48979592e+01,
#         9.79591837e+01, 1.01020408e+02, 1.04081633e+02, 1.07142857e+02,
#         1.10204082e+02, 1.13265306e+02, 1.16326531e+02, 1.19387755e+02,
#         1.22448980e+02, 1.25510204e+02, 1.28571429e+02, 1.31632653e+02,
#         1.34693878e+02, 1.37755102e+02, 1.40816327e+02, 1.43877551e+02,
#         1.46938776e+02, 1.50000000e+02],
#        [2.39345000e+06, 2.39313876e+06, 2.39269194e+06, 2.39205027e+06,
#         2.39112852e+06, 2.38980417e+06, 2.38790130e+06, 2.38516772e+06,
#         2.38124303e+06, 2.37561446e+06, 2.36755775e+06, 2.35606087e+06,
#         2.33973279e+06, 2.31670789e+06, 2.28457567e+06, 2.24039468e+06,
#         2.18088908e+06, 2.10294847e+06, 2.00450363e+06, 1.88565845e+06,
#         1.74963574e+06, 1.60287594e+06, 1.45388661e+06, 1.31120453e+06,
#         1.18146967e+06, 1.06846806e+06, 9.73269941e+05, 8.95006415e+05,
#         8.31750591e+05, 7.81200019e+05, 7.41092914e+05, 7.09410947e+05,
#         6.84447378e+05, 6.64803888e+05, 6.49356203e+05, 6.37210377e+05,
#         6.27660135e+05, 6.20149442e+05, 6.14241321e+05, 6.09592631e+05,
#         6.05933961e+05, 6.03053765e+05, 6.00785885e+05, 5.98999766e+05,
#         5.97592794e+05, 5.96484281e+05, 5.95610768e+05, 5.94922325e+05,
#         5.94379657e+05, 5.93951836e+05],
#        [3.00000000e+02, 4.27909604e+02, 6.10278757e+02, 8.70214137e+02,
#         1.24054207e+03, 1.76780846e+03, 2.51783147e+03, 3.58331022e+03,
#         5.09404656e+03, 7.23025649e+03, 1.02390378e+04, 1.44529436e+04,
#         2.03071315e+04, 2.83467660e+04, 3.92083060e+04, 5.35474531e+04,
#         7.18780013e+04, 9.42946162e+04, 1.20104484e+05, 1.47503966e+05,
#         1.73558266e+05, 1.94723457e+05, 2.07857394e+05, 2.11249842e+05,
#         2.05089467e+05, 1.91162039e+05, 1.72073114e+05, 1.50460599e+05,
#         1.28488140e+05, 1.07659294e+05, 8.88526414e+04, 7.24583950e+04,
#         5.85335074e+04, 4.69342801e+04, 3.74140585e+04, 2.96880384e+04,
#         2.34723863e+04, 1.85053652e+04, 1.45568183e+04, 1.14306483e+04,
#         8.96341989e+03, 7.02106742e+03, 5.49489974e+03, 4.29756890e+03,
#         3.35934576e+03, 2.62484953e+03, 2.05026782e+03, 1.60104549e+03,
#         1.24999305e+03, 9.75756038e+02],
#        [2.00000000e+01, 3.11751091e+01, 4.85875914e+01, 7.57104364e+01,
#         1.17940008e+02, 1.83648342e+02, 2.85795182e+02, 4.44377599e+02,
#         6.90108089e+02, 1.06983856e+03, 1.65434073e+03, 2.54898635e+03,
#         3.90735846e+03, 5.94631087e+03, 8.95758650e+03, 1.33048592e+04,
#         1.93863230e+04, 2.75366564e+04, 3.78520617e+04, 4.99675535e+04,
#         6.28962367e+04, 7.50939319e+04, 8.48331465e+04, 9.07508245e+04,
#         9.22679221e+04, 8.96611543e+04, 8.38174429e+04, 7.58696466e+04,
#         6.68952836e+04, 5.77507735e+04, 4.90256395e+04, 4.10688609e+04,
#         3.40443795e+04, 2.79891955e+04, 2.28619466e+04, 1.85787661e+04,
#         1.50375023e+04, 1.21328404e+04, 9.76495174e+03, 7.84383974e+03,
#         6.29099322e+03, 5.03945811e+03, 4.03305762e+03, 3.22521721e+03,
#         2.57766634e+03, 2.05916960e+03, 1.64436463e+03, 1.31273936e+03,
#         1.04775532e+03, 8.36109547e+02],
#        [0.00000000e+00, 3.39113766e+00, 8.24762639e+00, 1.52040956e+01,
#         2.51702726e+01, 3.94497859e+01, 5.99094090e+01, 8.92190197e+01,
#         1.31189353e+02, 1.91242124e+02, 2.77053297e+02, 3.99410123e+02,
#         5.73305345e+02, 8.19237156e+02, 1.16455726e+03, 1.64446836e+03,
#         2.30189189e+03, 3.18498241e+03, 4.34087427e+03, 5.80494830e+03,
#         7.58711929e+03, 9.65991002e+03, 1.19549370e+04, 1.43719086e+04,
#         1.67977371e+04, 1.91278484e+04, 2.12817014e+04, 2.32090307e+04,
#         2.48881100e+04, 2.63195452e+04, 2.75188769e+04, 2.85100007e+04,
#         2.93202070e+04, 2.99768785e+04, 3.05055473e+04, 3.09289298e+04,
#         3.12665999e+04, 3.15350440e+04, 3.17479188e+04, 3.19163979e+04,
#         3.20495382e+04, 3.21546289e+04, 3.22375049e+04, 3.23028172e+04,
#         3.23542615e+04, 3.23947669e+04, 3.24266505e+04, 3.24517425e+04,
#         3.24714871e+04, 3.24870226e+04],
#        [0.00000000e+00, 1.68691670e+02, 4.10751344e+02, 7.58215374e+02,
#         1.25715061e+03, 1.97379209e+03, 3.00332954e+03, 4.48243185e+03,
#         6.60697867e+03, 9.65690091e+03, 1.40304182e+04, 2.02900432e+04,
#         2.92219363e+04, 4.19074361e+04, 5.97990077e+04, 8.47799746e+04,
#         1.19166594e+05, 1.65585908e+05, 2.26650029e+05, 3.04382104e+05,
#         3.99466939e+05, 5.10579441e+05, 6.34154982e+05, 7.64840123e+05,
#         8.96511169e+05, 1.02343744e+06, 1.14114813e+06, 1.24679983e+06,
#         1.33910474e+06, 1.41800649e+06, 1.48428278e+06, 1.53918697e+06,
#         1.58417498e+06, 1.62072151e+06, 1.65021039e+06, 1.67387881e+06,
#         1.69279702e+06, 1.70786951e+06, 1.71984780e+06, 1.72934844e+06,
#         1.73687250e+06, 1.74282422e+06, 1.74752796e+06, 1.75124287e+06,
#         1.75417533e+06, 1.75648926e+06, 1.75831463e+06, 1.75975433e+06,
#         1.76088969e+06, 1.76178499e+06]])

# %%
class DINN(nn.Module):
    def __init__(self, t, S_data, I1_data, I2_data, D_data, R_data): #[t,S,I1, I2,D,R]
        super(DINN, self).__init__()
        
        self.N = 2412642-(221+9436+9091+124) #population size
        
        #for the time steps, we need to convert them to a tensor, a float, and eventually to reshape it so it can be used as a batch
        self.t = torch.tensor(t, requires_grad=True)
        self.t_float = self.t.float()
        self.t_batch = torch.reshape(self.t_float, (len(self.t),1)) #reshape for batch 

        #for the compartments we just need to convert them into tensors
        self.S = torch.tensor(S_data)
        self.I1 = torch.tensor(I1_data)
        self.I2 = torch.tensor(I2_data)
        self.D = torch.tensor(D_data)
        self.R = torch.tensor(R_data)

        self.losses = [] # here I saved the model's losses per epoch

        #setting the parameters
        self.alpha1_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.beta1_tilda = torch.tensor(0.143)
        self.gamma1_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))

        self.alpha2_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.beta2_tilda = torch.tensor(0.143)
        self.gamma2_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        #find values for normalization
        self.S_max = max(self.S)
        self.I1_max = max(self.I1)
        self.I2_max = max(self.I2)
        self.D_max = max(self.D)
        self.R_max = max(self.R)
        self.S_min = min(self.S)
        self.I1_min = min(self.I1)
        self.I2_min = min(self.I2)
        self.D_min = min(self.D)
        self.R_min = min(self.R)

        #normalize
        self.S_hat = (self.S - self.S_min) / (self.S_max - self.S_min)
        self.I1_hat = (self.I1 - self.I1_min) / (self.I1_max - self.I1_min)
        self.I2_hat = (self.I2 - self.I2_min) / (self.I2_max - self.I2_min)
        self.D_hat = (self.D - self.D_min) / (self.D_max - self.D_min)
        self.R_hat = (self.R - self.R_min) / (self.R_max - self.R_min)        

        #matrices (x4 for S,I1, I2,D,R) for the gradients
        self.m1 = torch.zeros((len(self.t), 5)); self.m1[:, 0] = 1
        self.m2 = torch.zeros((len(self.t), 5)); self.m2[:, 1] = 1
        self.m3 = torch.zeros((len(self.t), 5)); self.m3[:, 2] = 1
        self.m4 = torch.zeros((len(self.t), 5)); self.m4[:, 3] = 1
        self.m5 = torch.zeros((len(self.t), 5)); self.m5[:, 4] = 1

        #NN
        self.net_sidr = self.Net_sidr()
        self.params = list(self.net_sidr.parameters())
        self.params.extend(list([self.alpha1_tilda, self.beta1_tilda, self.gamma1_tilda, self.alpha2_tilda, self.beta2_tilda, self.gamma2_tilda]))

    #force parameters to be in a range
    @property
    def alpha1(self):
        return torch.tanh(self.alpha1_tilda) #* 0.1 + 0.2

    @property
    def beta1(self):
        return torch.tanh(self.beta1_tilda) #* 0.01 + 0.05
    
    @property
    def gamma1(self):
        return torch.tanh(self.gamma1_tilda) #* 0.01 + 0.03
    
    @property
    def alpha2(self):
        return torch.tanh(self.alpha2_tilda) #* 0.1 + 0.2

    @property
    def beta2(self):
        return torch.tanh(self.beta2_tilda) #* 0.01 + 0.05
    
    @property
    def gamma2(self):
        return torch.tanh(self.gamma2_tilda) #* 0.01 + 0.03

    class Net_sidr(nn.Module): # input = [[t1], [t2]...[t100]] -- that is, a batch of timesteps 
        def __init__(self):
            super(DINN.Net_sidr, self).__init__()

            self.fc1=nn.Linear(1, 20) #takes 100 t's
            self.fc2=nn.Linear(20, 20)
            self.fc3=nn.Linear(20, 20)
            self.fc4=nn.Linear(20, 20)
            self.fc5=nn.Linear(20, 20)
            self.fc6=nn.Linear(20, 20)
            self.fc7=nn.Linear(20, 20)
            self.fc8=nn.Linear(20, 20)
            self.out=nn.Linear(20, 5) #outputs S, I1, I2, D, R (100 S, 100 I, 100 D, 100 R --- since we have a batch of 100 timesteps)

        def forward(self, t_batch):
            sidr=F.relu(self.fc1(t_batch))
            sidr=F.relu(self.fc2(sidr))
            sidr=F.relu(self.fc3(sidr))
            sidr=F.relu(self.fc4(sidr))
            sidr=F.relu(self.fc5(sidr))
            sidr=F.relu(self.fc6(sidr))
            sidr=F.relu(self.fc7(sidr))
            sidr=F.relu(self.fc8(sidr))
            sidr=self.out(sidr)
            return sidr

    def net_f(self, t_batch):
            
            #pass the timesteps batch to the neural network
            sidr_hat = self.net_sidr(t_batch)
            
            #organize S,I,D,R from the neural network's output -- note that these are normalized values -- hence the "hat" part
            S_hat, I1_hat, I2_hat, D_hat, R_hat = sidr_hat[:,0], sidr_hat[:,1], sidr_hat[:,2], sidr_hat[:,3], sidr_hat[:,4]

            #S_t
            sidr_hat.backward(self.m1, retain_graph=True)
            S_hat_t = self.t.grad.clone()
            self.t.grad.zero_()

            #I1_t
            sidr_hat.backward(self.m2, retain_graph=True)
            I1_hat_t = self.t.grad.clone()
            self.t.grad.zero_()

            #I2_t
            sidr_hat.backward(self.m3, retain_graph=True)
            I2_hat_t = self.t.grad.clone()
            self.t.grad.zero_()

            #D_t
            sidr_hat.backward(self.m4, retain_graph=True)
            D_hat_t = self.t.grad.clone()
            self.t.grad.zero_()

            #R_t
            sidr_hat.backward(self.m5, retain_graph=True)
            R_hat_t = self.t.grad.clone()
            self.t.grad.zero_() 

            #unnormalize
            S = self.S_min + (self.S_max - self.S_min) * S_hat
            I1 = self.I1_min + (self.I1_max - self.I1_min) * I1_hat
            I2 = self.I2_min + (self.I2_max - self.I2_min) * I2_hat
            D = self.D_min + (self.D_max - self.D_min) * D_hat      
            R = self.R_min + (self.R_max - self.R_min) * R_hat        

            f1_hat = S_hat_t - (-(self.alpha1 / self.N) * S * I1 -(self.alpha2 / self.N) * S * I2 )  / (self.S_max - self.S_min)
            f2_hat = I1_hat_t - ((self.alpha1 / self.N) * S * I1 - self.beta1 * I1 - self.gamma1 * I1 ) / (self.I1_max - self.I1_min)
            f3_hat = I2_hat_t - ((self.alpha2 / self.N) * S * I2 - self.beta2 * I2 - self.gamma2 * I2 ) / (self.I2_max - self.I2_min)
            f4_hat = D_hat_t - (self.gamma1 * I1 + self.gamma2 * I2) / (self.D_max - self.D_min)
            f5_hat = R_hat_t - (self.beta1 * I1 + self.beta2 * I2) / (self.R_max - self.R_min)        

            return f1_hat, f2_hat, f3_hat, f4_hat, f5_hat, S_hat, I1_hat, I2_hat, D_hat, R_hat
    def train(self, n_epochs):
        # train
        print('\nstarting training...\n')
        
        for epoch in range(n_epochs):
            # lists to hold the output (maintain only the final epoch)
            S_pred_list = []
            I1_pred_list = []
            I2_pred_list = []
            D_pred_list = []
            R_pred_list = []

            # we pass the timesteps batch into net_f
            f1, f2, f3, f4, f5, S_pred, I1_pred, I2_pred, D_pred, R_pred = self.net_f(self.t_batch) # net_f outputs f1_hat, f2_hat, f3_hat, f4_hat, S_hat, I_hat, D_hat, R_hat
            
            self.optimizer.zero_grad() #zero grad
            
            #append the values to plot later (note that we unnormalize them here for plotting)
            S_pred_list.append(self.S_min + (self.S_max - self.S_min) * S_pred)
            I1_pred_list.append(self.I1_min + (self.I1_max - self.I1_min) * I1_pred)
            I2_pred_list.append(self.I2_min + (self.I2_max - self.I2_min) * I2_pred)
            D_pred_list.append(self.D_min + (self.D_max - self.D_min) * D_pred)
            R_pred_list.append(self.R_min + (self.R_max - self.R_min) * R_pred)

            #calculate the loss --- MSE of the neural networks output and each compartment
            loss = (torch.mean(torch.square(self.S_hat - S_pred))+ 
                    torch.mean(torch.square(self.I1_hat - I1_pred))+
                    torch.mean(torch.square(self.I2_hat - I2_pred))+
                    torch.mean(torch.square(self.D_hat - D_pred))+
                    torch.mean(torch.square(self.R_hat - R_pred))+
                    torch.mean(torch.square(f1))+
                    torch.mean(torch.square(f2))+
                    torch.mean(torch.square(f3))+
                    torch.mean(torch.square(f4))+
                    torch.mean(torch.square(f5))
                    ) 

            loss.backward()
            self.optimizer.step()
            self.scheduler.step() 

            # append the loss value (we call "loss.item()" because we just want the value of the loss and not the entire computational graph)
            self.losses.append(loss.item())

            if epoch % 1000 == 0:          
                print('\nEpoch ', epoch)

                print('alpha1: (goal 0.262 ', self.alpha1)
                print('beta1: (goal 0.05 ', self.beta1)
                print('gamm1: (goal 0.0294 ', self.gamma1)

                print('alpha2: (goal 0.291 ', self.alpha2)
                print('beta2: (goal 0.045 ', self.beta2)
                print('gamma2: (goal 0.0194 ', self.gamma2)

                print('#################################')                

        return S_pred_list, I1_pred_list, I2_pred_list, D_pred_list, R_pred_list

# %%
# %%time
dinn = DINN(covid_data[0], covid_data[1], covid_data[2], covid_data[3], 
            covid_data[4], covid_data[5]) #in the form of [t,S,I1,I2,D,R]
learning_rate = 1e-6
optimizer = optim.Adam(dinn.params, lr = learning_rate)
dinn.optimizer = optimizer
scheduler = torch.optim.lr_scheduler.CyclicLR(dinn.optimizer, base_lr=1e-5, max_lr=1e-3, step_size_up=1000, mode="exp_range", gamma=0.85, cycle_momentum=False)
dinn.scheduler = scheduler
S_pred_list, I1_pred_list, I2_pred_list, D_pred_list, R_pred_list = dinn.train(50000) #train
# Out:
# starting training...
#
#
# Epoch  0
# alpha1: (goal 0.262  tensor([0.5997], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1390], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4614], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.6585], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.7143], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6130], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  1000
# alpha1: (goal 0.262  tensor([0.6089], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1272], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4500], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.6658], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.7091], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6166], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  2000
# alpha1: (goal 0.262  tensor([0.6140], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1212], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4414], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.6685], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.7075], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  3000
# alpha1: (goal 0.262  tensor([0.6158], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1187], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4377], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.6688], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.7072], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6211], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  4000
# alpha1: (goal 0.262  tensor([0.6169], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1170], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4357], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.6715], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.7052], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6151], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  5000
# alpha1: (goal 0.262  tensor([0.6178], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1155], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4350], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.6774], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.7003], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6066], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  6000
# alpha1: (goal 0.262  tensor([0.6188], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1140], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4360], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.6846], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.6940], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5981], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  7000
# alpha1: (goal 0.262  tensor([0.6199], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1124], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4388], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.6911], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.6882], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5905], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  8000
# alpha1: (goal 0.262  tensor([0.6204], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1114], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4415], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.6961], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.6834], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5841], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  9000
# alpha1: (goal 0.262  tensor([0.6199], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1110], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4428], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7010], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.6783], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5771], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  10000
# alpha1: (goal 0.262  tensor([0.6190], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1105], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4416], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7064], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.6724], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5693], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  11000
# alpha1: (goal 0.262  tensor([0.6189], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1091], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4342], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7118], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.6662], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5614], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  12000
# alpha1: (goal 0.262  tensor([0.6222], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1044], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4223], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7168], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.6601], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5536], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  13000
# alpha1: (goal 0.262  tensor([0.6281], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.0971], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4118], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7217], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.6539], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5459], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  14000
# alpha1: (goal 0.262  tensor([0.6338], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.0912], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4025], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7266], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.6477], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5382], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  15000
# alpha1: (goal 0.262  tensor([0.6382], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.0884], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3943], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7315], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.6413], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5305], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  16000
# alpha1: (goal 0.262  tensor([0.6418], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.0860], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3859], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7363], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.6348], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5228], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  17000
# alpha1: (goal 0.262  tensor([0.6428], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.0920], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3765], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7410], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.6285], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5151], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  18000
# alpha1: (goal 0.262  tensor([0.6417], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1062], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3663], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7455], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.6222], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5074], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  19000
# alpha1: (goal 0.262  tensor([0.6402], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1195], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3558], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7498], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.6159], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4997], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  20000
# alpha1: (goal 0.262  tensor([0.6389], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1318], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3453], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7541], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.6096], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4918], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  21000
# alpha1: (goal 0.262  tensor([0.6414], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1431], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3348], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7583], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.6033], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4840], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  22000
# alpha1: (goal 0.262  tensor([0.6467], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1539], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3243], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7624], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.5968], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4761], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  23000
# alpha1: (goal 0.262  tensor([0.6541], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1640], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3138], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7665], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.5903], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4680], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  24000
# alpha1: (goal 0.262  tensor([0.6607], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1739], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3033], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7704], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.5838], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4599], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  25000
# alpha1: (goal 0.262  tensor([0.6667], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1836], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.2927], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7743], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.5771], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4518], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  26000
# alpha1: (goal 0.262  tensor([0.6722], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.1930], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.2822], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7782], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.5704], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4435], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  27000
# alpha1: (goal 0.262  tensor([0.6770], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2019], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.2716], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7819], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.5636], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4352], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  28000
# alpha1: (goal 0.262  tensor([0.6808], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2102], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.2610], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7857], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.5567], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4267], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  29000
# alpha1: (goal 0.262  tensor([0.6825], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2172], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.2504], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7893], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.5498], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4182], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  30000
# alpha1: (goal 0.262  tensor([0.6793], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2211], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.2398], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7930], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.5428], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4097], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  31000
# alpha1: (goal 0.262  tensor([0.6703], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2194], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.2291], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.7966], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.5357], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4010], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  32000
# alpha1: (goal 0.262  tensor([0.6604], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2176], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.2184], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8001], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.5285], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3922], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  33000
# alpha1: (goal 0.262  tensor([0.6517], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2174], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.2076], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8036], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.5212], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3834], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  34000
# alpha1: (goal 0.262  tensor([0.6436], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2180], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.1968], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8070], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.5139], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3745], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  35000
# alpha1: (goal 0.262  tensor([0.6357], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2184], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.1860], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8104], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.5065], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3655], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  36000
# alpha1: (goal 0.262  tensor([0.6279], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2206], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.1752], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8138], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.4989], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3564], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  37000
# alpha1: (goal 0.262  tensor([0.6200], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2208], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.1644], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8171], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.4913], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3473], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  38000
# alpha1: (goal 0.262  tensor([0.6122], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2229], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.1535], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8203], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.4835], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3380], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  39000
# alpha1: (goal 0.262  tensor([0.6044], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2256], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.1427], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8235], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.4757], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3287], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  40000
# alpha1: (goal 0.262  tensor([0.5966], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2270], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.1318], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8267], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.4677], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3193], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  41000
# alpha1: (goal 0.262  tensor([0.5889], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2300], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.1210], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8299], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.4596], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3098], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  42000
# alpha1: (goal 0.262  tensor([0.5811], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2345], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.1101], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8330], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.4514], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3002], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  43000
# alpha1: (goal 0.262  tensor([0.5732], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2390], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0994], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8361], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.4431], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.2906], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  44000
# alpha1: (goal 0.262  tensor([0.5653], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2438], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0886], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8391], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.4347], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.2809], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  45000
# alpha1: (goal 0.262  tensor([0.5573], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2484], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0780], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8421], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.4262], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.2711], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  46000
# alpha1: (goal 0.262  tensor([0.5493], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2530], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0674], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8450], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.4176], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.2613], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  47000
# alpha1: (goal 0.262  tensor([0.5412], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2576], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0569], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8479], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.4089], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.2515], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  48000
# alpha1: (goal 0.262  tensor([0.5332], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2621], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0466], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8507], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.4002], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.2418], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  49000
# alpha1: (goal 0.262  tensor([0.5252], grad_fn=<TanhBackward0>)
# beta1: (goal 0.05  tensor([0.2667], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0364], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor([0.8534], grad_fn=<TanhBackward0>)
# beta2: (goal 0.045  tensor([0.3914], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.2320], grad_fn=<TanhBackward0>)
# #################################
# CPU times: user 2min 9s, sys: 546 ms, total: 2min 10s
# Wall time: 2min 10s

# %%
plt.plot(dinn.losses[0:], color = 'teal')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.set_facecolor('xkcd:white')

ax.plot(covid_data[0], covid_data[1], 'pink', alpha=0.5, lw=2, label='Susceptible')
ax.plot(covid_data[0], S_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')

ax.plot(covid_data[0], covid_data[2], 'violet', alpha=0.5, lw=2, label='Infected1')
ax.plot(covid_data[0], I1_pred_list[0].detach().numpy(), 'dodgerblue', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')

ax.plot(covid_data[0], covid_data[3], 'orange', alpha=0.5, lw=2, label='Infected2')
ax.plot(covid_data[0], I2_pred_list[0].detach().numpy(), 'dodgerblue', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')


ax.plot(covid_data[0], covid_data[4], 'darkgreen', alpha=0.5, lw=2, label='Dead')
ax.plot(covid_data[0], D_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')

ax.plot(covid_data[0], covid_data[5], 'blue', alpha=0.5, lw=2, label='Recovered')
ax.plot(covid_data[0], R_pred_list[0].detach().numpy(), 'teal', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')

  
ax.set_xlabel('Time /days')
ax.set_ylabel('Number')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(visible=True, which='major', c='black', lw=0.2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()
