# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
# Initial conditions (from the literature)
N = 2412642-(221+9436+9091+124) #population size

S0 = N - 320 #everyone starts out as susceptible, except for 1 person that is infected
I10 = 300 #1 infected person
I20 = 20
D0 = 0
R0 = 0

# A grid of time points (in days)
t = np.linspace(0, 500, 101) #from day 0 to day 500, generate 100 points

#parameters (from the literature)
alpha1 = 0.262
beta1 = 0.0714
gamma1 = 0.008


alpha2 = 0.291
beta2 = 0.143
gamma2 = 0.016

# %%
S_cal = [S0]
I1_cal = [I10]
I2_cal = [I20]
R_cal = [R0]
D_cal = [D0]

for i in range(len(t)-1):
    S_cal.append(S_cal[i] - (alpha1/N)*S_cal[i]*I1_cal[i] - (alpha2/N)*S_cal[i]*I2_cal[i])
    R_cal.append(R_cal[i] + beta1 * I1_cal[i] + beta2 * I2_cal[i])
    D_cal.append(D_cal[i] + gamma1 * I1_cal[i] + gamma2 * I2_cal[i])
    I1_cal.append(I1_cal[i] + (alpha1/ N) * S_cal[i] * I1_cal[i] - beta1 * I1_cal[i] - gamma1 * I1_cal[i])
    I2_cal.append(I2_cal[i] + (alpha2/ N) * S_cal[i] * I2_cal[i] - beta2 * I2_cal[i] - gamma2 * I2_cal[i])
    
#for i in range(len(t)-1):
#    print((S[i+1]-S[i]) / (S_cal[i+1]-S_cal[i]))

# %%
print(sum(S-S_cal))
print(sum(I1-I1_cal))
print(sum(I2-I2_cal))
print(sum(R-R_cal))
print(sum(D-D_cal))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(sum(S-S_cal))
#       2 print(sum(I1-I1_cal))
#       3 print(sum(I2-I2_cal))
#
# NameError: name 'S' is not defined

# %%
# a1, a2 계산
t_q = t[:-1]
S_q = S[:-1]
I1_q = I1[:-1]
I2_q = I2[:-1]
D_q = D[:-1]
R_q = R[:-1]

Sa = S[1:]
I1a = I1[1:]
I2a = I2[1:]

a1 = []
a2 = []
for i in range(len(t_q)):
    alpha1 = ((N / S_q[i]) * ((I1a[i] / I1_q[i]) + (beta1 + gamma1 - 1)))
    alpha2 = ((N / S_q[i]) * ((I2a[i] / I2_q[i]) + (beta2 + gamma2 - 1)))
    a1.append(alpha1)
    a2.append(alpha2)
    
a1
# Out:
# [1.5705634193241154,
#  1.5695032369859339,
#  1.566898298055402,
#  1.5605100061542563,
#  1.5449793221599668,
#  1.508117486280529,
#  1.4255380005173603,
#  1.2620532107727906,
#  1.0016894947555266,
#  0.6844100123504532,
#  0.3504505168987154,
#  -0.030226530330004314,
#  -0.5070190069871673,
#  -1.0824474565595654,
#  -1.7103062395492672,
#  -2.3285759753407427,
#  -2.8878307720331935,
#  -3.361712013606595,
#  -3.7441916508519575,
#  -4.042104724236021,
#  -4.268240356523313,
#  -4.436732649217232,
#  -4.560613085560808,
#  -4.650829111359002,
#  -4.7160830176541975,
#  -4.763052868573068,
#  -4.796744954285863,
#  -4.820853187274845,
#  -4.838073466094656,
#  -4.850358380716753,
#  -4.859114618937765,
#  -4.865351891991121,
#  -4.869792754145307,
#  -4.872953600728208,
#  -4.875202538019406,
#  -4.87680297802016,
#  -4.877941437456619,
#  -4.878751231343855,
#  -4.879327304246366,
#  -4.879737019116635,
#  -4.880028434327788,
#  -4.880235723703924,
#  -4.8803831236518285,
#  -4.880487972812277,
#  -4.88056255145163,
#  -4.8806155680026615,
#  -4.880653299254951,
#  -4.880680124118718,
#  -4.880699188442551,
#  -4.880712776685879,
#  -4.880722416564936,
#  -4.880729271925878,
#  -4.880734173083318,
#  -4.88073762798881,
#  -4.880739961928213,
#  -4.8807417355584555,
#  -4.880743002391731,
#  -4.8807439043308944,
#  -4.880744170547641,
#  -4.880744736731421,
#  -4.880745147012231,
#  -4.880745353867897,
#  -4.880744941519324,
#  -4.880745264414753,
#  -4.880745554496332,
#  -4.880745441712386,
#  -4.880745510287575,
#  -4.880745514382744,
#  -4.880745620981553,
#  -4.880745617395764,
#  -4.880745452193652,
#  -4.88074408450843,
#  -4.880744335369489,
#  -4.88076184778137,
#  -4.880759434925183,
#  -4.880752172729355,
#  -4.880754986502138,
#  -4.8807557903935175,
#  -4.880776759082481,
#  -4.880702651037562,
#  -4.880445371558833,
#  -4.880702599063787,
#  -4.880709846879563,
#  -4.880635717878946,
#  -4.880307961360969,
#  -4.881185617454611,
#  -4.8811634876565915,
#  -4.880802435302614,
#  -4.8818428748612135,
#  -4.880612706600721,
#  -4.879489211141062,
#  -4.88937947089871,
#  -4.885756228230488,
#  -4.875783054640573,
#  -4.887083667123449,
#  -4.864073239266848,
#  -4.872948694734547,
#  -4.877639658496772,
#  -4.877982347659054,
#  -4.909386463989975]

# %%
# a1, a2 계산
t_q = t[:-1]
S_q = S_cal[:-1]
I1_q = I1_cal[:-1]
I2_q = I2_cal[:-1]
D_q = D_cal[:-1]
R_q = R_cal[:-1]

Sa = S_cal[1:]
I1a = I1_cal[1:]
I2a = I2_cal[1:]

a1 = []
a2 = []
for i in range(len(t_q)):
    alpha1 = ((N / S_q[i]) * ((I1a[i] / I1_q[i]) + (beta1 + gamma1 - 1)))
    alpha2 = ((N / S_q[i]) * ((I2a[i] / I2_q[i]) + (beta2 + gamma2 - 1)))
    a1.append(alpha1)
    a2.append(alpha2)
    
a1
# Out:
# [0.26199999999999996,
#  0.2620000000000001,
#  0.26199999999999996,
#  0.2620000000000001,
#  0.2620000000000002,
#  0.26200000000000007,
#  0.26199999999999984,
#  0.2619999999999999,
#  0.26199999999999996,
#  0.2620000000000002,
#  0.26200000000000007,
#  0.2620000000000002,
#  0.26200000000000007,
#  0.2619999999999999,
#  0.2619999999999999,
#  0.2620000000000002,
#  0.26200000000000007,
#  0.26199999999999996,
#  0.262,
#  0.26199999999999996,
#  0.2620000000000001,
#  0.26199999999999996,
#  0.26199999999999996,
#  0.26200000000000007,
#  0.2619999999999999,
#  0.26200000000000007,
#  0.26199999999999996,
#  0.2619999999999999,
#  0.2619999999999999,
#  0.26199999999999996,
#  0.2620000000000001,
#  0.26200000000000023,
#  0.2619999999999998,
#  0.2620000000000001,
#  0.2620000000000002,
#  0.262,
#  0.26200000000000007,
#  0.26200000000000023,
#  0.26200000000000023,
#  0.2620000000000001,
#  0.2620000000000001,
#  0.26199999999999973,
#  0.26200000000000023,
#  0.26200000000000007,
#  0.2620000000000001,
#  0.262,
#  0.2620000000000002,
#  0.26199999999999996,
#  0.262,
#  0.26199999999999973,
#  0.2620000000000002,
#  0.2619999999999999,
#  0.26200000000000023,
#  0.26200000000000023,
#  0.26200000000000045,
#  0.26199999999999996,
#  0.26200000000000007,
#  0.2619999999999998,
#  0.2619999999999996,
#  0.26199999999999984,
#  0.2620000000000003,
#  0.26200000000000007,
#  0.2620000000000001,
#  0.26199999999999984,
#  0.2620000000000003,
#  0.2620000000000002,
#  0.26200000000000045,
#  0.2620000000000004,
#  0.2620000000000007,
#  0.2620000000000003,
#  0.26200000000000045,
#  0.2619999999999993,
#  0.2620000000000002,
#  0.26199999999999984,
#  0.26199999999999807,
#  0.2619999999999991,
#  0.26200000000000184,
#  0.26200000000000045,
#  0.2619999999999981,
#  0.26199999999999785,
#  0.26200000000000073,
#  0.262,
#  0.26199999999999996,
#  0.26200000000000234,
#  0.26200000000000156,
#  0.26200000000000206,
#  0.2619999999999992,
#  0.2620000000000028,
#  0.2619999999999984,
#  0.262000000000002,
#  0.2620000000000011,
#  0.26200000000000107,
#  0.2620000000000028,
#  0.2620000000000014,
#  0.2620000000000012,
#  0.2620000000000008,
#  0.2620000000000025,
#  0.2619999999999993,
#  0.2620000000000011,
#  0.2620000000000038]

# %%
# Plot the data
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.set_facecolor('xkcd:white')

ax.plot(t, S, 'violet', alpha=0.5, lw=2, label='Susceptible', linestyle='dashed')
ax.plot(t, I1, 'darkgreen', alpha=0.5, lw=2, label='Infected1', linestyle='dashed')
ax.plot(t, I2, 'orange', alpha=0.5, lw=2, label='Infected2', linestyle='dashed')
ax.plot(t, D, 'blue', alpha=0.5, lw=2, label='Dead', linestyle='dashed')
ax.plot(t, R, 'red', alpha=0.5, lw=2, label='Recovered', linestyle='dashed')

ax.set_xlabel('Time /days')
ax.set_ylabel('Number')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(visible=True, which='major', c='black', lw=0.2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
    
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])
 
plt.show()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_7508\2234718582.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])

# %%
# Plot the data
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.set_facecolor('xkcd:white')

ax.plot(t, S_cal, 'violet', alpha=0.5, lw=2, label='Susceptible', linestyle='dashed')
ax.plot(t, I1_cal, 'darkgreen', alpha=0.5, lw=2, label='Infected1', linestyle='dashed')
ax.plot(t, I2_cal, 'orange', alpha=0.5, lw=2, label='Infected2', linestyle='dashed')
ax.plot(t, D_cal, 'blue', alpha=0.5, lw=2, label='Dead', linestyle='dashed')
ax.plot(t, R_cal, 'red', alpha=0.5, lw=2, label='Recovered', linestyle='dashed')

ax.set_xlabel('Time /days')
ax.set_ylabel('Number')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(visible=True, which='major', c='black', lw=0.2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
    
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])
 
plt.show()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_11208\1657746631.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])

# %%
#save to csv file
COVID_Data = np.asarray([t_q, S_q, I1_q, I2_q, D_q, R_q, a1, a2, I1a, I2a]) 
np.savetxt("Covid_practice1.csv", COVID_Data, delimiter=",")

# %%
import numpy as np
import pandas as pd
from scipy.integrate import odeint
import matplotlib.pyplot as plt

import torch
from torch.autograd import grad
import torch.nn as nn
from numpy import genfromtxt
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %%
real_data = pd.read_csv('../Data/Variants/SIR/delta_omicron/대구_delta_omicron.csv', encoding = 'cp949')

# %%
covid_cumulative_cases = pd.read_csv('../data/Variants/SIR/delta_omicron/대구_delta_omicron.csv', delimiter=',') #in the form of [t,S,I,D,R]
covid_cumulative_cases['cumulative_dead'] = covid_cumulative_cases['Delta_Dead'] + covid_cumulative_cases['Omicron_Dead']
covid_cumulative_cases['cumulative_recovered'] = covid_cumulative_cases['Delta_Recovered'] + covid_cumulative_cases['Omicron_Recovered']
covid_cumulative_cases.drop(labels=['Delta_Dead', 'Delta_Recovered', 'Omicron_Dead', 'Omicron_Recovered'], axis=1, inplace=True)
covid_cumulative_cases.columns = ['Date', 'cumulative_susceptible', 'cumulative_infected1', 'alpha1', 'beta1', 'gamma1', 
                                  'cumulative_infected2', 'alpha2', 'beta2', 'gamma2', 'cumulative_dead', 'cumulative_recovered'] #rename columns
covid_cumulative_cases = covid_cumulative_cases[240:440].copy() # 240 ~ 440 (200days)
covid_cumulative_cases.reset_index(drop=True,inplace=True)
covid_cumulative_cases['t'] = covid_cumulative_cases.index.astype(float)
covid_cumulative_cases
# Out:
#            Date  cumulative_susceptible  cumulative_infected1    alpha1  \
# 0    2021-12-08                 2369328                754.40  0.169380
# 1    2021-12-09                 2369196                812.52  0.194208
# 2    2021-12-10                 2369033                871.98  0.158772
# 3    2021-12-11                 2368890                921.06  0.144013
# 4    2021-12-12                 2368753                937.92  0.148659
# ..          ...                     ...                   ...       ...
# 195  2022-06-21                 1619599                  0.00  0.000000
# 196  2022-06-22                 1619130                  0.00  0.000000
# 197  2022-06-23                 1618779                  0.00  0.000000
# 198  2022-06-24                 1618396                  0.00  0.000000
# 199  2022-06-25                 1618080                  0.00  0.000000
#
#         beta1    gamma1  cumulative_infected2    alpha2     beta2    gamma2  \
# 0    0.088335  0.002598                 35.96  0.148058  0.043938  0.001112
# 1    0.116994  0.002412                 39.62  0.165949  0.050984  0.001010
# 2    0.097777  0.003372                 44.08  0.130866  0.033122  0.001361
# 3    0.123423  0.001064                 48.28  0.114475  0.043496  0.000414
# 4    0.149437  0.000000                 51.64  0.112502  0.034082  0.000000
# ..        ...       ...                   ...       ...       ...       ...
# 195  0.000000  0.000000               7018.00  0.098581  0.140923  0.000142
# 196  0.000000  0.000000               6497.00  0.079718  0.103432  0.000154
# 197  0.000000  0.000000               6175.00  0.091541  0.091822  0.000000
# 198  0.000000  0.000000               5991.00  0.077866  0.088800  0.000000
# 199  0.000000  0.000000               5775.00  0.072357  0.068571  0.000000
#
#      cumulative_dead  cumulative_recovered      t
# 0             103.62               8042.57    0.0
# 1             105.62               8110.79    1.0
# 2             107.62               8207.87    2.0
# 3             110.62               8294.59    3.0
# 4             111.62               8410.37    4.0
# ..               ...                   ...    ...
# 195          1110.46             748237.09  195.0
# 196          1111.46             749226.09  196.0
# 197          1112.46             749898.09  197.0
# 198          1112.46             750465.09  198.0
# 199          1112.46             750997.09  199.0
#
# [200 rows x 13 columns]

# %%
class DINN(nn.Module):
    def __init__(self, t, S_data, I1_data, I2_data, D_data, R_data, a1, a2): #[t,S,I1, I2,D,R]
        super(DINN, self).__init__()
        
        self.N = 2412642-(221+9436+9091+124) #population size
        
        #for the time steps, we need to convert them to a tensor, a float, and eventually to reshape it so it can be used as a batch
        self.t = torch.tensor(t, requires_grad=True)
        self.t_float = self.t.float()
        self.t_batch = torch.reshape(self.t_float, (len(self.t),1)) #reshape for batch 

        #for the compartments we just need to convert them into tensors
        self.S = torch.tensor(S_data)
        self.I1 = torch.tensor(I1_data)
        self.I2 = torch.tensor(I2_data)
        self.D = torch.tensor(D_data)
        self.R = torch.tensor(R_data)

        self.losses = [] # here I saved the model's losses per epoch

        #setting the parameters
        # self.alpha1_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.alpha1_tilda = torch.tensor(a1)
        self.beta1_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.gamma1_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))

        # self.alpha2_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.alpha2_tilda = torch.tensor(a2)
        self.beta2_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.gamma2_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        #find values for normalization
        self.S_max = max(self.S)
        self.I1_max = max(self.I1)
        self.I2_max = max(self.I2)
        self.D_max = max(self.D)
        self.R_max = max(self.R)
        self.S_min = min(self.S)
        self.I1_min = min(self.I1)
        self.I2_min = min(self.I2)
        self.D_min = min(self.D)
        self.R_min = min(self.R)

        #normalize
        self.S_hat = (self.S - self.S_min) / (self.S_max - self.S_min)
        self.I1_hat = (self.I1 - self.I1_min) / (self.I1_max - self.I1_min)
        self.I2_hat = (self.I2 - self.I2_min) / (self.I2_max - self.I2_min)
        self.D_hat = (self.D - self.D_min) / (self.D_max - self.D_min)
        self.R_hat = (self.R - self.R_min) / (self.R_max - self.R_min)        
        
        #matrices (x4 for S,I1, I2,D,R) for the gradients
        self.m1 = torch.zeros((len(self.t), 5)); self.m1[:, 0] = 1
        self.m2 = torch.zeros((len(self.t), 5)); self.m2[:, 1] = 1
        self.m3 = torch.zeros((len(self.t), 5)); self.m3[:, 2] = 1
        self.m4 = torch.zeros((len(self.t), 5)); self.m4[:, 3] = 1
        self.m5 = torch.zeros((len(self.t), 5)); self.m5[:, 4] = 1


        #NN
        self.net_sidr = self.Net_sidr()
        self.params = list(self.net_sidr.parameters())
        self.params.extend(list([self.alpha1_tilda, self.beta1_tilda, self.gamma1_tilda, 
                                 self.alpha2_tilda, self.beta2_tilda, self.gamma2_tilda]))

    #force parameters to be in a range
    @property
    def alpha1(self):
         return torch.tanh(self.alpha1_tilda) #* 0.1 + 0.2

    @property
    def beta1(self):
        return torch.tanh(self.beta1_tilda) #* 0.01 + 0.05
    
    @property
    def gamma1(self):
        return torch.tanh(self.gamma1_tilda) #* 0.01 + 0.03
    
    @property
    def alpha2(self):
        return torch.tanh(self.alpha2_tilda) #* 0.1 + 0.2

    @property
    def beta2(self):
        return torch.tanh(self.beta2_tilda) #* 0.01 + 0.05
    
    @property
    def gamma2(self):
        return torch.tanh(self.gamma2_tilda) #* 0.01 + 0.03

    class Net_sidr(nn.Module): # input = [[t1], [t2]...[t100]] -- that is, a batch of timesteps 
        def __init__(self):
            super(DINN.Net_sidr, self).__init__()

            self.fc1=nn.Linear(1, 20) #takes 100 t's
            self.fc2=nn.Linear(20, 20)
            self.fc3=nn.Linear(20, 20)
            self.fc4=nn.Linear(20, 20)
            self.fc5=nn.Linear(20, 20)
            self.fc6=nn.Linear(20, 20)
            self.fc7=nn.Linear(20, 20)
            self.fc8=nn.Linear(20, 20)
            self.out=nn.Linear(20, 5) #outputs S, I1, I2, D, R (100 S, 100 I, 100 D, 100 R --- since we have a batch of 100 timesteps)

        def forward(self, t_batch):
            sidr=F.relu(self.fc1(t_batch))
            sidr=F.relu(self.fc2(sidr))
            sidr=F.relu(self.fc3(sidr))
            sidr=F.relu(self.fc4(sidr))
            sidr=F.relu(self.fc5(sidr))
            sidr=F.relu(self.fc6(sidr))
            sidr=F.relu(self.fc7(sidr))
            sidr=F.relu(self.fc8(sidr))
            sidr=self.out(sidr)
            return sidr

    def net_f(self, t_batch):
            
        #pass the timesteps batch to the neural network
        sidr_hat = self.net_sidr(t_batch)

        #organize S,I,D,R from the neural network's output -- note that these are normalized values -- hence the "hat" part
        S_hat, I1_hat, I2_hat, D_hat, R_hat = sidr_hat[:,0], sidr_hat[:,1], sidr_hat[:,2], sidr_hat[:,3], sidr_hat[:,4]

        #S_t
        sidr_hat.backward(self.m1, retain_graph=True)
        S_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #I1_t
        sidr_hat.backward(self.m2, retain_graph=True)
        I1_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #I2_t
        sidr_hat.backward(self.m3, retain_graph=True)
        I2_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #D_t
        sidr_hat.backward(self.m4, retain_graph=True)
        D_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #R_t
        sidr_hat.backward(self.m5, retain_graph=True)
        R_hat_t = self.t.grad.clone()
        self.t.grad.zero_() 

        #unnormalize
        S = self.S_min + (self.S_max - self.S_min) * S_hat
        I1 = self.I1_min + (self.I1_max - self.I1_min) * I1_hat
        I2 = self.I2_min + (self.I2_max - self.I2_min) * I2_hat
        D = self.D_min + (self.D_max - self.D_min) * D_hat      
        R = self.R_min + (self.R_max - self.R_min) * R_hat    

        f1_hat = S_hat_t - (-(self.alpha1 / self.N) * S * I1 -(self.alpha2 / self.N) * S * I2 )  / (self.S_max - self.S_min)
        f2_hat = I1_hat_t - ((self.alpha1 / self.N) * S * I1 - self.beta1 * I1 - self.gamma1 * I1 ) / (self.I1_max - self.I1_min)
        f3_hat = I2_hat_t - ((self.alpha2 / self.N) * S * I2 - self.beta2 * I2 - self.gamma2 * I2 ) / (self.I2_max - self.I2_min)
        f4_hat = D_hat_t - (self.gamma1 * I1 + self.gamma2 * I2) / (self.D_max - self.D_min)
        f5_hat = R_hat_t - (self.beta1 * I1 + self.beta2 * I2) / (self.R_max - self.R_min)   
        #print(((self.alpha1 * self.N)*S).shape)
        return f1_hat, f2_hat, f3_hat, f4_hat, f5_hat, S_hat, I1_hat, I2_hat, D_hat, R_hat

    def train(self, n_epochs):
        # train
        print('\nstarting training...\n')
        min_loss = np.inf
        
        for epoch in range(n_epochs):
            # lists to hold the output (maintain only the final epoch)
            S_pred_list = []
            I1_pred_list = []
            I2_pred_list = []
            D_pred_list = []
            R_pred_list = []

            # we pass the timesteps batch into net_f
            f1, f2, f3, f4, f5, S_pred, I1_pred, I2_pred, D_pred, R_pred = self.net_f(self.t_batch) 
            # net_f outputs f1_hat, f2_hat, f3_hat, f4_hat, S_hat, I_hat, D_hat, R_hat
            
            self.optimizer.zero_grad() #zero grad
            
            #append the values to plot later (note that we unnormalize them here for plotting)
            S_pred_list.append(self.S_min + (self.S_max - self.S_min) * S_pred)
            I1_pred_list.append(self.I1_min + (self.I1_max - self.I1_min) * I1_pred)
            I2_pred_list.append(self.I2_min + (self.I2_max - self.I2_min) * I2_pred)
            D_pred_list.append(self.D_min + (self.D_max - self.D_min) * D_pred)
            R_pred_list.append(self.R_min + (self.R_max - self.R_min) * R_pred)

            #calculate the loss --- MSE of the neural networks output and each compartment
            loss = (torch.mean(torch.square(self.S_hat - S_pred))+ 
                    torch.mean(torch.square(self.I1_hat - I1_pred))+
                    torch.mean(torch.square(self.I2_hat - I2_pred))+
                    torch.mean(torch.square(self.D_hat - D_pred))+
                    torch.mean(torch.square(self.R_hat - R_pred))+
                    torch.mean(torch.square(f1))+
                    torch.mean(torch.square(f2))+
                    torch.mean(torch.square(f3))+
                    torch.mean(torch.square(f4))+
                    torch.mean(torch.square(f5))
                    ) 

            loss.backward()
            self.optimizer.step()
            self.scheduler.step() 
            # append the loss value (we call "loss.item()" because we just want the value of the loss and not the entire computational graph)
            self.losses.append(loss.item())

            if epoch % 1000 == 0:          
                print('\nEpoch ', epoch)
                print(loss.item())
                print('alpha1: (goal 0.262 ', self.alpha1.mean())
                print('beta1: (goal 0.05 ', self.beta1)
                print('gamm1: (goal 0.0294 ', self.gamma1)

                print('alpha2: (goal 0.291 ', self.alpha2.mean())
                print('beta2: (goal 0.045 ', self.beta2)
                print('gamma2: (goal 0.0194 ', self.gamma2)

                print('#################################')    
            if loss.item() < min_loss:
                min_loss = loss.item()
                model = dinn
                best_S = S_pred_list
                best_I1 = I1_pred_list
                best_I2 = I2_pred_list
                best_D = D_pred_list
                best_R = R_pred_list
                
        return S_pred_list, I1_pred_list, I2_pred_list, D_pred_list, R_pred_list, best_S, best_I1, best_I2, best_D, best_R

# %%
# %%time
dinn = DINN(covid_cumulative_cases['t'], covid_cumulative_cases['cumulative_susceptible'], 
            covid_cumulative_cases['cumulative_infected1'], covid_cumulative_cases['cumulative_infected2'],
            covid_cumulative_cases['cumulative_dead'], covid_cumulative_cases['cumulative_recovered'], 
            covid_cumulative_cases['alpha1'], covid_cumulative_cases['alpha2']) #in the form of [t,S,I1,I2,D,R]
learning_rate = 1e-6
optimizer = optim.Adam(dinn.params, lr = learning_rate)
dinn.optimizer = optimizer
scheduler = torch.optim.lr_scheduler.CyclicLR(dinn.optimizer, base_lr=1e-5, max_lr=1e-3, step_size_up=1000, mode="exp_range", gamma=0.85, cycle_momentum=False)
dinn.scheduler = scheduler
S_pred_list, I1_pred_list, I2_pred_list, D_pred_list, R_pred_list, best_S, best_I1, best_I2, best_D, best_R = dinn.train(500000) #train
# Out:
# starting training...
#
#
# Epoch  0
# 1090.9913822442281
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1648], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6369], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3176], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7270], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  1000
# 186.1613793325313
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1571], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6326], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3118], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7239], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  2000
# 36.98161049044895
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1530], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6309], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3101], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7229], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  3000
# 17.812747256963622
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1486], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6298], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3090], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7223], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  4000
# 5.948623539079484
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1443], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6290], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3083], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7219], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  5000
# 2.3020918550505853
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1425], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6287], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3080], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7218], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  6000
# 1.6054926808663135
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1393], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6286], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3079], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  7000
# 1.356384082936739
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1320], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6285], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3079], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  8000
# 1.181949815190192
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1215], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6284], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3079], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  9000
# 1.024754941061119
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1097], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6282], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3079], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  10000
# 0.9036582164723852
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.0983], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6279], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3079], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  11000
# 0.8334041339362002
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.0859], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6274], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3078], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  12000
# 0.7919996053415655
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.0724], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6259], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3078], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  13000
# 0.7616391692218148
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.0598], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6229], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3078], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  14000
# 0.7325560612219312
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.0481], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6182], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3077], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  15000
# 0.7003225666124696
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.0369], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6122], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3075], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  16000
# 0.6578559264388064
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.0257], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.6056], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3072], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  17000
# 0.6043880729540598
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.0148], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.5986], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3066], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  18000
# 0.5523840059207048
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.0036], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.5914], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3054], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
# Epoch  19000
# 0.4956256850423035
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.0079], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.5839], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.3032], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  20000
# 0.43743226788631373
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.0197], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.5760], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.2990], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  21000
# 0.3825261272908953
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.0317], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.5679], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.2922], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  22000
# 0.3333193312661069
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.0436], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.5596], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.2831], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7217], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  23000
# 0.29242698125632993
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.0553], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.5515], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.2731], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7216], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  24000
# 0.26179547649824003
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.0666], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.5434], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.2630], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7216], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  25000
# 0.24216025932104102
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.0772], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.5358], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.2532], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7216], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  26000
# 0.22828659827839573
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.0874], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.5283], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.2439], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7216], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  27000
# 0.22288667924644623
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.0971], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.5212], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.2349], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7214], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  28000
# 0.2165794513178159
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.1066], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.5141], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.2261], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7208], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  29000
# 0.2096017423747644
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.1160], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.5069], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.2174], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7207], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  30000
# 0.20310942936503812
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.1254], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4997], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.2087], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7206], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  31000
# 0.1970557883402692
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.1347], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4925], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.2001], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7198], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  32000
# 0.1915821923335263
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.1439], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4853], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.1916], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7175], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  33000
# 0.18649900633213143
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.1530], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4780], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.1834], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7128], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  34000
# 0.18151273409606813
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.1621], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4707], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.1753], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7065], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  35000
# 0.17694865730925124
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.1711], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4634], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.1677], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.7020], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  36000
# 0.1729241764521065
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.1800], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4561], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.1600], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6988], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  37000
# 0.16955614790471382
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.1886], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4489], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.1523], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6952], grad_fn=<TanhBackward0>)
# #################################
# Epoch  38000
# 0.16681344315169774
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.1971], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4417], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.1444], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6912], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  39000
# 0.16463273026446734
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2054], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4347], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.1355], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6871], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  40000
# 0.16283499661295323
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2134], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4277], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.1257], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6828], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  41000
# 0.1613930521493023
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2211], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4210], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.1157], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6787], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  42000
# 0.16033238034362787
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2282], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4147], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.1060], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6746], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  43000
# 0.15944210355580773
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2346], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4091], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0967], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6703], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  44000
# 0.15869713783129963
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2399], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4043], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0869], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6656], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  45000
# 0.15803121704513437
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2439], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.4007], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0773], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6613], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  46000
# 0.15747332397840116
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2462], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3986], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0676], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6566], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  47000
# 0.15696725153663374
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2473], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3976], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0573], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6516], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  48000
# 0.15647960668587996
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2476], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3972], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0469], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6468], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  49000
# 0.15604788814704462
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2482], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3966], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0362], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6417], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  50000
# 0.15565179909389099
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2484], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3962], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0254], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6366], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  51000
# 0.15531372085575845
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2481], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3959], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0148], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6314], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  52000
# 0.15500003323070607
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2478], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3956], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0044], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6266], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  53000
# 0.15472878692284964
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2480], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3952], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0057], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6220], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  54000
# 0.1545034248868736
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2481], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3947], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0158], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6177], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  55000
# 0.15429867145755785
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2480], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3943], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0257], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6135], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  56000
# 0.15410980141197242
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2477], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3939], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0347], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6092], grad_fn=<TanhBackward0>)
# #################################
# Epoch  57000
# 0.1539442996223769
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2476], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3935], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0439], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6049], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  58000
# 0.15379904714542156
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2475], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3931], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0533], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.6005], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  59000
# 0.15367938987348814
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2472], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3926], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0627], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5960], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  60000
# 0.15353235418627087
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2467], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3922], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0717], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5915], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  61000
# 0.1534193221677143
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2460], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3918], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0807], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5869], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  62000
# 0.15331683826431614
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2457], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3914], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0903], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5823], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  63000
# 0.15324197405955828
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2454], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3909], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0999], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5777], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  64000
# 0.15314544997151405
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2449], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3904], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1089], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5731], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  65000
# 0.1530653984175793
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2445], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3899], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1179], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5685], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  66000
# 0.15299695522574594
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2439], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3894], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1274], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5639], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  67000
# 0.15294185114889605
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2434], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3888], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1369], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5594], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  68000
# 0.15294098166041858
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2429], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3883], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1461], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5550], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  69000
# 0.15285160944963153
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2421], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3877], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1551], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5508], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  70000
# 0.1528038260886835
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2414], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3871], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1637], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5465], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  71000
# 0.15277425543574216
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2407], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3865], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1721], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5423], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  72000
# 0.15274488457106394
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2401], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3859], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1800], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5379], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  73000
# 0.15272172154745886
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2395], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3852], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1877], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5335], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  74000
# 0.15270662405578875
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2389], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3846], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1950], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5290], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  75000
# 0.1526780738495573
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2383], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3839], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.2023], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5244], grad_fn=<TanhBackward0>)
# #################################
# Epoch  76000
# 0.15267162332772832
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2376], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3832], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.2087], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5198], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  77000
# 0.15264697421445844
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2369], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3825], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.2145], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5149], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  78000
# 0.15265565466594064
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2363], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3817], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.2193], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5101], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  79000
# 0.1526120702065786
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2356], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3810], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.2232], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5052], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  80000
# 0.15258516645628495
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2350], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3802], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.2252], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.5001], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  81000
# 0.1525735673052124
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2342], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3795], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.2250], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4950], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  82000
# 0.15257391584004396
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2336], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3787], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.2240], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4898], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  83000
# 0.15255732532461908
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2330], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3779], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.2239], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4844], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  84000
# 0.1525415560495998
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2326], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3769], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.2155], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4790], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  85000
# 0.15252298135500253
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2317], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3761], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.2084], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4734], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  86000
# 0.15251601927980513
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2308], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3752], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.2019], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4678], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  87000
# 0.15250162566626158
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2297], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3743], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1955], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4620], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  88000
# 0.15247984820618496
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2288], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3732], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1901], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4561], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  89000
# 0.15246652839977673
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2278], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3722], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1848], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4501], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  90000
# 0.15245770534517708
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2267], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3712], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1794], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4439], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  91000
# 0.15243634766831146
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2255], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3701], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1787], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4376], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  92000
# 0.15241366277087953
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2243], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3690], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1754], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4311], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  93000
# 0.1523948986925238
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2232], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3678], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1724], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4245], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  94000
# 0.15238158506667687
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2219], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3667], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1684], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4178], grad_fn=<TanhBackward0>)
# #################################
# Epoch  95000
# 0.15235346928990648
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2206], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3655], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1644], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4109], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  96000
# 0.1523448329151453
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2193], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3642], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1592], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.4038], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  97000
# 0.15231549707218678
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2180], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3629], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1536], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3966], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  98000
# 0.15229438171791718
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2167], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3615], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1451], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3892], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  99000
# 0.15227524634738063
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2152], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3601], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1369], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3816], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  100000
# 0.15225640874269322
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2138], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3587], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1300], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3739], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  101000
# 0.15223301371756656
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2119], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3573], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1216], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3660], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  102000
# 0.15221518739898077
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2106], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3557], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1119], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3579], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  103000
# 0.1521815471521692
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2093], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3541], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.1026], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3496], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  104000
# 0.15215810952613126
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2076], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3525], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0923], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3411], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  105000
# 0.152136465733767
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2059], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3509], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0832], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3324], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  106000
# 0.15211333759722967
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2040], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3491], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0751], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3236], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  107000
# 0.15208603438309978
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2022], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3473], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0669], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3146], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  108000
# 0.1520671562342742
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.2001], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3455], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0616], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.3054], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  109000
# 0.1520283725508108
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.1981], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3435], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0543], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([0.2961], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  110000
# 0.15200124385706984
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([-0.1961], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.3414], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([-0.0468], grad_fn=<TanhBackward0>)
# ...
# gamma2: (goal 0.0194  tensor([8.8407e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  464000
# 0.0005610212100672609
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1374], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0015], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0691], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8528e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  465000
# 0.000560282056209661
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1373], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0015], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0691], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8566e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  466000
# 0.0005730518096454629
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1374], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0691], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8438e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  467000
# 0.0005644061117255765
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1375], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0691], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8431e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  468000
# 0.0005740445147961492
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1375], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0691], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8523e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  469000
# 0.0005700111339344574
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1374], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0691], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([9.1079e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  470000
# 0.0005662836458133984
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1374], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0691], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.7766e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  471000
# 0.0005652378940544715
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1374], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0691], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8380e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  472000
# 0.0005646392374377658
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1374], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0691], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8135e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  473000
# 0.0005646439460206627
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1374], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0691], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8111e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  474000
# 0.0005646879235228482
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1374], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0691], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8512e-05], grad_fn=<TanhBackward0>)
# #################################
# Epoch  475000
# 0.0005689762840957593
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1373], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0691], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8614e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  476000
# 0.0005614048885600129
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1373], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0691], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8492e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  477000
# 0.0005896857075283501
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1373], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0690], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.7698e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  478000
# 0.0005713820554258728
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1373], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0690], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8306e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  479000
# 0.0005688312018066511
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1373], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0690], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([9.0718e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  480000
# 0.0005756600037838626
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1372], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0690], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8829e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  481000
# 0.0005661939101978213
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1372], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.7625e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  482000
# 0.0005705070621279816
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1372], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8314e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  483000
# 0.0005630564937925465
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1372], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8359e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  484000
# 0.0005719118187045751
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1372], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.5765e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  485000
# 0.0005632234545885013
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1372], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.9150e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  486000
# 0.0005673597618480386
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1371], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.5897e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  487000
# 0.0005797849026915429
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1370], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.4097e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  488000
# 0.000557480955791202
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1370], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8521e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  489000
# 0.0005894779234707602
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1370], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8605e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  490000
# 0.0005720603345862671
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1370], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.7759e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  491000
# 0.0005719695302009052
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1370], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0013], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.7770e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  492000
# 0.0005714153694861702
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1370], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8566e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  493000
# 0.0005572821611655677
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1369], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8137e-05], grad_fn=<TanhBackward0>)
# #################################
# Epoch  494000
# 0.0005549095251230392
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1369], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([9.3168e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  495000
# 0.0005623649096122276
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1369], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.9047e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  496000
# 0.0005783689152012277
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1370], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([9.5409e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  497000
# 0.0005600716237708573
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1368], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.6072e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  498000
# 0.0005673221506279112
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1369], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.8604e-05], grad_fn=<TanhBackward0>)
# #################################
#
# Epoch  499000
# 0.0005581817845617199
# alpha1: (goal 0.262  tensor(0.0462, dtype=torch.float64)
# beta1: (goal 0.05  tensor([0.1368], grad_fn=<TanhBackward0>)
# gamm1: (goal 0.0294  tensor([0.0014], grad_fn=<TanhBackward0>)
# alpha2: (goal 0.291  tensor(0.1033, dtype=torch.float64)
# beta2: (goal 0.045  tensor([0.0689], grad_fn=<TanhBackward0>)
# gamma2: (goal 0.0194  tensor([8.7872e-05], grad_fn=<TanhBackward0>)
# #################################
# CPU times: total: 4h 8min 31s
# Wall time: 1h 2min 8s

# %%
plt.plot(dinn.losses[0:], color = 'teal')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.set_facecolor('xkcd:white')

ax.plot(covid_cumulative_cases['t'], covid_cumulative_cases['cumulative_susceptible'], 'pink', alpha=0.5, lw=2, label='Susceptible')
ax.plot(covid_cumulative_cases['t'], S_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')

ax.plot(covid_cumulative_cases['t'], covid_cumulative_cases['cumulative_infected1'], 'violet', alpha=0.5, lw=2, label='Infected1')
ax.plot(covid_cumulative_cases['t'], I1_pred_list[0].detach().numpy(), 'dodgerblue', alpha=0.9, lw=2, label='Infected1 Prediction', linestyle='dashed')

ax.plot(covid_cumulative_cases['t'], covid_cumulative_cases['cumulative_infected2'], 'orange', alpha=0.5, lw=2, label='Infected2')
ax.plot(covid_cumulative_cases['t'], I2_pred_list[0].detach().numpy(), 'skyblue', alpha=0.9, lw=2, label='Infected2 Prediction', linestyle='dashed')


ax.plot(covid_cumulative_cases['t'], covid_cumulative_cases['cumulative_dead'], 'darkgreen', alpha=0.5, lw=2, label='Dead')
ax.plot(covid_cumulative_cases['t'], D_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')

ax.plot(covid_cumulative_cases['t'], covid_cumulative_cases['cumulative_recovered'], 'blue', alpha=0.5, lw=2, label='Recovered')
ax.plot(covid_cumulative_cases['t'], R_pred_list[0].detach().numpy(), 'teal', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')

  
ax.set_xlabel('Time /days')
ax.set_ylabel('Number')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(visible=True, which='major', c='black', lw=0.2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
    

current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])

plt.show()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_8028\2676392951.py:34: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])

# %%
fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.set_facecolor('xkcd:white')

ax.plot(covid_cumulative_cases['t'], covid_cumulative_cases['cumulative_susceptible'], 'pink', alpha=0.5, lw=2, label='Susceptible')
ax.plot(covid_cumulative_cases['t'], best_S[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')

ax.plot(covid_cumulative_cases['t'], covid_cumulative_cases['cumulative_infected1'], 'violet', alpha=0.5, lw=2, label='Infected1')
ax.plot(covid_cumulative_cases['t'], best_I1[0].detach().numpy(), 'dodgerblue', alpha=0.9, lw=2, label='Infected1 Prediction', linestyle='dashed')

ax.plot(covid_cumulative_cases['t'], covid_cumulative_cases['cumulative_infected2'], 'orange', alpha=0.5, lw=2, label='Infected2')
ax.plot(covid_cumulative_cases['t'], best_I2[0].detach().numpy(), 'skyblue', alpha=0.9, lw=2, label='Infected2 Prediction', linestyle='dashed')


ax.plot(covid_cumulative_cases['t'], covid_cumulative_cases['cumulative_dead'], 'darkgreen', alpha=0.5, lw=2, label='Dead')
ax.plot(covid_cumulative_cases['t'], best_D[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')

ax.plot(covid_cumulative_cases['t'], covid_cumulative_cases['cumulative_recovered'], 'blue', alpha=0.5, lw=2, label='Recovered')
ax.plot(covid_cumulative_cases['t'], best_R[0].detach().numpy(), 'teal', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')

  
ax.set_xlabel('Time /days')
ax.set_ylabel('Number')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(visible=True, which='major', c='black', lw=0.2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
    

current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])

plt.show()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_8028\3589995305.py:34: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}'.format(x) for x in current_values])
