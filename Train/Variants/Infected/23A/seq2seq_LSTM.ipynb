# %%
import os
os.chdir('D:\\Gnan\\DA\\KMU\\Prediction-COVID-19')
from utils import *
from model import *
from trainer import *

from torch.optim.adam import Adam
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
path = 'Data/Variants/omicron/*.csv'
dic_files = Load_files.load_files(path, -14, -12)
path = 'Data/SIR_Origin/*.csv'
dic_SIRs = Load_files.load_files(path, -17, -15)

data = dic_files['대구']
data
# Out:
#          stdDay  Susceptible  22D_Infected  22D_Recovered  22D_dead  \
# 0    2022-12-19      1154500        467.04           0.00      0.00
# 1    2022-12-20      1150875       2207.04           0.00      0.00
# 2    2022-12-21      1147259       3942.72           0.00      0.00
# 3    2022-12-22      1144062       5477.28           0.00      0.00
# 4    2022-12-23      1141405       6752.64           0.00      0.00
# ..          ...          ...           ...            ...       ...
# 132  2023-04-30      1031603        503.31       68965.31     79.76
# 133  2023-05-01      1031481        494.57       68997.23     79.76
# 134  2023-05-02      1031001        504.26       69078.74     79.76
# 135  2023-05-03      1030537        510.91       69160.25     79.76
# 136  2023-05-04      1029951        547.01       69235.49     79.76
#
#      22D_alpha  22D_beta  22D_gamma  23A_Infected  23A_Recovered  23A_dead  \
# 0     7.709827  0.000000        0.0          9.73           0.00       0.0
# 1     1.632581  0.000000        0.0         45.98           0.00       0.0
# 2     0.810531  0.000000        0.0         82.14           0.00       0.0
# 3     0.486252  0.000000        0.0        114.11           0.00       0.0
# 4     0.420776  0.000000        0.0        140.68           0.00       0.0
# ..         ...       ...        ...           ...            ...       ...
# 132   0.106662  0.063420        0.0       1695.36        9188.34       9.9
# 133   0.427119  0.164810        0.0       1665.92        9295.86       9.9
# 134   0.405137  0.161643        0.0       1698.56        9570.42       9.9
# 135   0.505227  0.147267        0.0       1720.96        9844.98       9.9
# 136   0.000000  0.000000        0.0       1842.56       10098.42       9.9
#
#      23A_alpha  23A_beta  23A_gamma
# 0     7.709827  0.000000        0.0
# 1     1.632581  0.000000        0.0
# 2     0.810531  0.000000        0.0
# 3     0.486252  0.000000        0.0
# 4     0.420776  0.000000        0.0
# ..         ...       ...        ...
# 132   0.106662  0.063420        0.0
# 133   0.427119  0.164810        0.0
# 134   0.405137  0.161643        0.0
# 135   0.505227  0.147267        0.0
# 136   0.000000  0.000000        0.0
#
# [137 rows x 14 columns]

# %%
criterion = nn.MSELoss()
lr = 1e-4
patience = 300
hidden_size = 32
num_layers = 4
batch_size = 8
dropout = 0.25

input_size = 3
sequence_length = 60
num_epochs = 10000

df = Prepare_df.processing(data[:-1], 'stdDay', '22D_alpha')

x = df.iloc[:, 0:]
y = df.iloc[:,:1]

ms = MinMaxScaler()
ss = StandardScaler()

ss.fit(x)
ms.fit(y)

x, y, x_ss, y_ms, train_loader, test_loader = Prepare_df.split_data(df, 54, 60, 7, batch_size, 'mtm')
model_LSTM_seq2seq = LSTM_encoder_decoder(input_size = input_size,
                                            hidden_size = hidden_size,
                                            num_layers = num_layers, 
                                            dropout = dropout, 
                                            device = device).to(device)

model = model_LSTM_seq2seq

optimizer = Adam(model.parameters(), lr = lr)
# Out:
# torch.Size([54, 60, 3])
# torch.Size([54, 7, 1])
# torch.Size([14, 60, 3])
# torch.Size([14, 7, 1])

# %%
loss_list, model = Trainer.Many_to_Many(train_loader, 
                                        test_loader, 
                                        model, 
                                        criterion, 
                                        optimizer, 
                                        num_epochs, 
                                        patience,
                                        device)
# Out:
# C:\Users\PC\anaconda3\envs\KMU_DA\lib\site-packages\torch\nn\modules\loss.py:530: UserWarning: Using a target size (torch.Size([8, 14, 1])) that is different to the input size (torch.Size([8, 7, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 loss_list, model = Trainer.Many_to_Many(train_loader,
#       2                                         test_loader,
#       3                                         model,
#       4                                         criterion,
#       5                                         optimizer,
#       6                                         num_epochs,
#       7                                         patience,
#       8                                         device)
#
# File D:\Gnan\DA\KMU\Prediction-COVID-19\trainer.py:64, in Trainer.Many_to_Many(train_loader, test_loader, model, criterion, optimizer, num_epochs, patience, device)
#      62 seq, target = data
#      63 out = model(seq, target, 7, 0.5, device).to(device)
# ---> 64 loss = criterion(out, target)
#      65 optimizer.zero_grad()
#      66 loss.backward()
#
# File ~\anaconda3\envs\KMU_DA\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\envs\KMU_DA\lib\site-packages\torch\nn\modules\loss.py:530, in MSELoss.forward(self, input, target)
#     529 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 530     return F.mse_loss(input, target, reduction=self.reduction)
#
# File ~\anaconda3\envs\KMU_DA\lib\site-packages\torch\nn\functional.py:3279, in mse_loss(input, target, size_average, reduce, reduction)
#    3276 if size_average is not None or reduce is not None:
#    3277     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3279 expanded_input, expanded_target = torch.broadcast_tensors(input, target)
#    3280 return torch._C._nn.mse_loss(expanded_input, expanded_target, _Reduction.get_enum(reduction))
#
# File ~\anaconda3\envs\KMU_DA\lib\site-packages\torch\functional.py:73, in broadcast_tensors(*tensors)
#      71 if has_torch_function(tensors):
#      72     return handle_torch_function(broadcast_tensors, tensors, *tensors)
# ---> 73 return _VF.broadcast_tensors(tensors)
#
# RuntimeError: The size of tensor a (7) must match the size of tensor b (14) at non-singleton dimension 1

# %%
plt.plot(loss_list)

# %%
label_y, predicted, first_label_y, first_predicted = predict_mtm(model, df, x_ss, y_ms, len(x_ss), 7, 0.5, device)

# %%
print(mape(first_label_y, first_predicted))
plotting(first_label_y, first_predicted, 54)
# Out:
# 560.0323677062988

# %%
con_prediction = np.concatenate((predicted[-15].squeeze(-1), predicted[-8].squeeze(-1)), axis = 0)

data_predicted = data[['stdDay']].copy()
data_predicted['predicted_alpha'] = 0
data_predicted.iloc[69:, -1] = first_predicted
data_predicted.iloc[123:, -1] = con_prediction
data_predicted['predicted_22D'] = data['22D_Infected']
for i in range(123, len(data_predicted)):
    data_predicted.iloc[i, -1] = (data_predicted.iloc[i-1, -1]
                                  *(1-data.iloc[i-1, 6]-data.iloc[i-1, 7]
                                    +(data_predicted.iloc[i-1, 1]*data.iloc[i-1, 1]
                                      /dic_SIRs['대구'].iloc[0, 2])))
data_predicted
# Out:
#          stdDay  predicted_alpha  predicted_22D
# 0    2022-12-19         0.000000     467.040000
# 1    2022-12-20         0.000000    2207.040000
# 2    2022-12-21         0.000000    3942.720000
# 3    2022-12-22         0.000000    5477.280000
# 4    2022-12-23         0.000000    6752.640000
# ..          ...              ...            ...
# 132  2023-04-30         0.391305     646.249366
# 133  2023-05-01         0.377551     714.454600
# 134  2023-05-02         0.408375     713.163025
# 135  2023-05-03         0.421940     723.564655
# 136  2023-05-04         0.354510     748.696356
#
# [137 rows x 3 columns]

# %%
print(mape(data['22D_Infected'], data_predicted['predicted_22D']))
plotting(data['22D_Infected'], data_predicted['predicted_22D'], 123)
# Out:
# 2.301445645690731

# %%
import os
os.chdir('D:\\Gnan\\DA\\KMU\\Prediction-COVID-19')
from utils import *
from model import *
from trainer import *

from torch.optim.adam import Adam
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

path = 'Data/Variants/omicron/*.csv'
dic_files = Load_files.load_files(path, -14, -12)
path = 'Data/SIR_Origin/*.csv'
dic_SIRs = Load_files.load_files(path, -17, -15)

data = dic_files['대구']
data

criterion = nn.MSELoss()
lr = 1e-4
patience = 300
hidden_size = 32
num_layers = 4
batch_size = 8
dropout = 0.25

input_size = 3
sequence_length = 60
num_epochs = 10000

df = Prepare_df.processing(data[:-1], 'stdDay', '22D_alpha')

x = df.iloc[:, 0:]
y = df.iloc[:,:1]

ms = MinMaxScaler()
ss = StandardScaler()

ss.fit(x)
ms.fit(y)

x, y, x_ss, y_ms, train_loader, test_loader = Prepare_df.split_data(df, 54, 60, 7, batch_size, 'mtm')
model_BiLSTM_seq2seq = BiLSTM_encoder_decoder(input_size = input_size,
                                            hidden_size = hidden_size,
                                            num_layers = num_layers, 
                                            dropout = dropout, 
                                            device = device).to(device)

model = model_BiLSTM_seq2seq

optimizer = Adam(model.parameters(), lr = lr)

loss_list, model = Trainer.Many_to_Many(train_loader, 
                                        test_loader, 
                                        model, 
                                        criterion, 
                                        optimizer, 
                                        num_epochs, 
                                        patience,
                                        device)

plt.plot(loss_list)

label_y, predicted, first_label_y, first_predicted = predict_mtm(model, df, x_ss, y_ms, len(x_ss), 7, 0.5, device)

print(mape(first_label_y, first_predicted))
plotting(first_label_y, first_predicted, 54)

con_prediction = np.concatenate((predicted[-15].squeeze(-1), predicted[-8].squeeze(-1)), axis = 0)

data_predicted = data[['stdDay']].copy()
data_predicted['predicted_alpha'] = 0
data_predicted.iloc[69:, -1] = first_predicted
data_predicted.iloc[123:, -1] = con_prediction
data_predicted['predicted_22D'] = data['22D_Infected']
for i in range(123, len(data_predicted)):
    data_predicted.iloc[i, -1] = (data_predicted.iloc[i-1, -1]
                                  *(1-data.iloc[i-1, 6]-data.iloc[i-1, 7]
                                    +(data_predicted.iloc[i-1, 1]*data.iloc[i-1, 1]
                                      /dic_SIRs['대구'].iloc[0, 2])))
data_predicted

print(mape(data['22D_Infected'], data_predicted['predicted_22D']))
plotting(data['22D_Infected'], data_predicted['predicted_22D'], 123)
