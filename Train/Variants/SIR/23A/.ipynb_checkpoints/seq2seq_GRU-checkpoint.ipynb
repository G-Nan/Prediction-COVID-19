# %%
import os
os.chdir('D:\\Gnan\\DA\\KMU\\Prediction-COVID-19')
from utils import *
from model import *
from trainer import *

from torch.optim.adam import Adam
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
path = 'Data/Variants/omicron/*.csv'
dic_files = Load_files.load_files(path, -14, -12)
path = 'Data/SIR_Origin/*.csv'
dic_SIRs = Load_files.load_files(path, -17, -15)

data = dic_files['대구']
data
# Out:
#          stdDay  Susceptible  22D_Infected  22D_Recovered  22D_dead  \
# 0    2022-12-19      1154500        467.04           0.00      0.00
# 1    2022-12-20      1150875       2207.04           0.00      0.00
# 2    2022-12-21      1147259       3942.72           0.00      0.00
# 3    2022-12-22      1144062       5477.28           0.00      0.00
# 4    2022-12-23      1141405       6752.64           0.00      0.00
# ..          ...          ...           ...            ...       ...
# 132  2023-04-30      1031603        503.31       68965.31     79.76
# 133  2023-05-01      1031481        494.57       68997.23     79.76
# 134  2023-05-02      1031001        504.26       69078.74     79.76
# 135  2023-05-03      1030537        510.91       69160.25     79.76
# 136  2023-05-04      1029951        547.01       69235.49     79.76
#
#      22D_alpha  22D_beta  22D_gamma  23A_Infected  23A_Recovered  23A_dead  \
# 0     7.709827  0.000000        0.0          9.73           0.00       0.0
# 1     1.632581  0.000000        0.0         45.98           0.00       0.0
# 2     0.810531  0.000000        0.0         82.14           0.00       0.0
# 3     0.486252  0.000000        0.0        114.11           0.00       0.0
# 4     0.420776  0.000000        0.0        140.68           0.00       0.0
# ..         ...       ...        ...           ...            ...       ...
# 132   0.106662  0.063420        0.0       1695.36        9188.34       9.9
# 133   0.427119  0.164810        0.0       1665.92        9295.86       9.9
# 134   0.405137  0.161643        0.0       1698.56        9570.42       9.9
# 135   0.505227  0.147267        0.0       1720.96        9844.98       9.9
# 136   0.000000  0.000000        0.0       1842.56       10098.42       9.9
#
#      23A_alpha  23A_beta  23A_gamma
# 0     7.709827  0.000000        0.0
# 1     1.632581  0.000000        0.0
# 2     0.810531  0.000000        0.0
# 3     0.486252  0.000000        0.0
# 4     0.420776  0.000000        0.0
# ..         ...       ...        ...
# 132   0.106662  0.063420        0.0
# 133   0.427119  0.164810        0.0
# 134   0.405137  0.161643        0.0
# 135   0.505227  0.147267        0.0
# 136   0.000000  0.000000        0.0
#
# [137 rows x 14 columns]

# %%
criterion = nn.MSELoss()
lr = 1e-4
patience = 300
hidden_size = 32
num_layers = 4
batch_size = 8
dropout = 0.25

input_size = 3
sequence_length = 60
num_epochs = 10000

df = Prepare_df.processing(data[:-1], 'stdDay', '23A_alpha')

x = df.iloc[:, 0:]
y = df.iloc[:,:1]

ms = MinMaxScaler()
ss = StandardScaler()

ss.fit(x)
ms.fit(y)

x, y, x_ss, y_ms, train_loader, test_loader = Prepare_df.split_data(df, 54, 60, 7, batch_size, 'mtm')
model_GRU_seq2seq = GRU_encoder_decoder(input_size = input_size,
                                        hidden_size = hidden_size,
                                        num_layers = num_layers, 
                                        dropout = dropout, 
                                        device = device).to(device)

model = model_GRU_seq2seq

optimizer = Adam(model.parameters(), lr = lr)
# Out:
# torch.Size([54, 60, 3])
# torch.Size([54, 7, 1])
# torch.Size([14, 60, 3])
# torch.Size([14, 7, 1])

# %%
loss_list, model = Trainer.Many_to_Many(train_loader, 
                                        test_loader, 
                                        model, 
                                        criterion, 
                                        optimizer, 
                                        num_epochs, 
                                        patience,
                                        device)
# Out:
# epoch: 100 loss: 0.025295
# epoch: 200 loss: 0.024861
# epoch: 300 loss: 0.023710
# epoch: 400 loss: 0.021780
# epoch: 500 loss: 0.019511
# epoch: 600 loss: 0.017326
# epoch: 700 loss: 0.014699
# epoch: 800 loss: 0.007050
# epoch: 900 loss: 0.004556
# epoch: 1000 loss: 0.003907
# epoch: 1100 loss: 0.003302
# epoch: 1200 loss: 0.003001
# epoch: 1300 loss: 0.002840
# epoch: 1400 loss: 0.002804
# epoch: 1500 loss: 0.002033
# epoch: 1600 loss: 0.002203
# epoch: 1700 loss: 0.001971
# epoch: 1800 loss: 0.001895
# epoch: 1900 loss: 0.001523
# epoch: 2000 loss: 0.001566
# epoch: 2100 loss: 0.001241
# epoch: 2200 loss: 0.001412
# epoch: 2300 loss: 0.001294
# epoch: 2400 loss: 0.000996
# epoch: 2500 loss: 0.000885
# epoch: 2600 loss: 0.001052
# epoch: 2700 loss: 0.000945
# epoch: 2800 loss: 0.000910
# epoch: 2900 loss: 0.000734
# epoch: 3000 loss: 0.000747
# epoch: 3100 loss: 0.000657
# epoch: 3200 loss: 0.000515
# epoch: 3300 loss: 0.000603
# epoch: 3400 loss: 0.000602
# epoch: 3500 loss: 0.000501
# epoch: 3600 loss: 0.000565
# epoch: 3700 loss: 0.000460
# epoch: 3800 loss: 0.000383
# epoch: 3900 loss: 0.000417
# epoch: 4000 loss: 0.000378
# epoch: 4100 loss: 0.000420
# epoch: 4200 loss: 0.000356
# epoch: 4300 loss: 0.000362
# epoch: 4400 loss: 0.000364
# epoch: 4500 loss: 0.000374
# epoch: 4600 loss: 0.000282
# epoch: 4700 loss: 0.000300
# epoch: 4800 loss: 0.000335
# epoch: 4900 loss: 0.000287
# epoch: 5000 loss: 0.000248
# epoch: 5100 loss: 0.000293
#
#  Early Stopping / epoch: 5101 loss: 0.000307

# %%
plt.plot(loss_list)

# %%
label_y, predicted, first_label_y, first_predicted = predict_mtm(model, df, x_ss, y_ms, len(x_ss), 7, 0.5, device)

# %%
print(mape(first_label_y, first_predicted))
plotting(first_label_y, first_predicted, 54)
# Out:
# 13.339076936244965

# %%
con_prediction = np.concatenate((predicted[-15].squeeze(-1), predicted[-8].squeeze(-1)), axis = 0)

data_predicted = data[['stdDay']].copy()
data_predicted['predicted_alpha'] = 0
data_predicted.iloc[69:, -1] = first_predicted
data_predicted.iloc[123:, -1] = con_prediction
data_predicted['predicted_23A'] = data['23A_Infected']
for i in range(123, len(data_predicted)):
    data_predicted.iloc[i, -1] = (data_predicted.iloc[i-1, -1]
                                  *(1-data.iloc[i-1, 6]-data.iloc[i-1, 7]
                                    +(data_predicted.iloc[i-1, 1]*data.iloc[i-1, 1]
                                      /dic_SIRs['대구'].iloc[0, 2])))
data_predicted
# Out:
#          stdDay  predicted_alpha  predicted_23A
# 0    2022-12-19         0.000000       9.730000
# 1    2022-12-20         0.000000      45.980000
# 2    2022-12-21         0.000000      82.140000
# 3    2022-12-22         0.000000     114.110000
# 4    2022-12-23         0.000000     140.680000
# ..          ...              ...            ...
# 132  2023-04-30         0.420101    1968.380494
# 133  2023-05-01         0.121016    2200.597644
# 134  2023-05-02         0.507981    1952.892187
# 135  2023-05-03         0.603594    2065.317253
# 136  2023-05-04         0.462379    2298.879188
#
# [137 rows x 3 columns]

# %%
print(mape(data['23A_Infected'], data_predicted['predicted_23A']))
plotting(data['23A_Infected'], data_predicted['predicted_23A'], 123)
# Out:
# 1.5261147269234272

# %%
torch.save(model.state_dict(), 'Capstone/23A_2weeks_seq2seqGRU.pth')

# %%
alpha_df = pd.DataFrame()
alpha_df['Date'] = data_predicted['stdDay']
alpha_df['Actual_Data'] = data['23A_alpha']
alpha_df['Predicted_Data'] = data_predicted['predicted_alpha']
alpha_df.to_csv('Capstone/23A_alpha_seq2seqGRU.csv', encoding = 'cp949', index = False)

# %%
final_df = pd.DataFrame()
final_df['Date'] = data_predicted['stdDay']
final_df['Actual_Data'] = data['23A_Infected']
final_df['Predicted_Data'] = data_predicted['predicted_23A']
final_df.to_csv('Capstone/23A_Infected_seq2seqGRU.csv', encoding = 'cp949', index = False)
