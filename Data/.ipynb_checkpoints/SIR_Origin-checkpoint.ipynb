# %%
import os
os.chdir('D:\\Gnan\\DA\\KMU\\Prediction-COVID-19')
from utils import *

# %%
path = 'Data/Cleaned_deathCnt/*.csv'
dic_files = Load_files.load_files(path, -14, -12)

list_N = [1539277, 13527299, 3311631, 2622174, 
          1440908, 2389150, 1454068, 3353379, 
          9535432, 370439, 1122757, 2952839, 
          1834016, 1786855, 676518, 2121108, 1597774]

dic_files = N_in_dict(dic_files, list_N)

# %%
file = dic_files['서울'][1]
file
# Out:
#       deathCnt   defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0            0        0    서울   Seoul     0.0             0           0
# 1            0        0    서울   Seoul     0.0             0           0
# 2            0        0    서울   Seoul     0.0             0           0
# 3            0        0    서울   Seoul     0.0             0           0
# 4            0        1    서울   Seoul     1.0             0           1
# ...        ...      ...   ...     ...     ...           ...         ...
# 1214      6471  6162486    서울   Seoul  4329.0             0           0
# 1215      6473  6166682    서울   Seoul  4196.0             0           0
# 1216      6476  6167953    서울   Seoul  1271.0             0           0
# 1217      6477  6173315    서울   Seoul  5362.0             0           0
# 1218      6479  6178627    서울   Seoul  5312.0             0           0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# ...

# %%
dic_final = {}
for key, file in dic_files.items():
    df_final = processing_SIR(file[1], file[0], 14)
    dic_final[key] = df_final
    df_final.to_csv(f'Data/SIR_Origin/{key}_SIR_Origin.csv', index = False, encoding = 'cp949')

# %%
path = 'Data/All/All_cleaned.csv'
df = pd.read_csv(path, encoding = 'cp949')
all_N = sum(list_N)
df_all = processing_SIR(df, all_N, 14)
df_all.to_csv(f'Data/SIR_Origin/all_SIR_Origin.csv', index = False, encoding = 'cp949')
