# %%
import os
os.chdir('D:\\Gnan\\DA\\KMU\\Prediction-COVID-19')
from utils import *
#from train import train

# %%
path = 'Data/Cleaned_deathCnt/*.csv'
dic_files = Load_files.load_files(path)

# %%
file = dic_files['서울']
file
# Out:
#       deathCnt   defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0            0        0    서울   Seoul       0             0           0
# 1            0        0    서울   Seoul       0             0           0
# 2            0        0    서울   Seoul       0             0           0
# 3            0        0    서울   Seoul       0             0           0
# 4            0        1    서울   Seoul       1             0           1
# ...        ...      ...   ...     ...     ...           ...         ...
# 1167      6383  5991150    서울   Seoul    2523             0           0
# 1168      6383  5993551    서울   Seoul    2401             0           0
# 1169      6384  5994393    서울   Seoul     842             0           0
# 1170      6387  5997981    서울   Seoul    3588             0           0
# 1171      6390  6001334    서울   Seoul    3353             0           0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# 0               0            0      0.0  2020-01-20
# 1               0            0      0.0  2020-01-21
# 2               0            0      0.0  2020-01-22
# 3               0            0      0.0  2020-01-23
# 4               0            1      0.0  2020-01-24
# ...           ...          ...      ...         ...
# 1167         2522            1  63544.0  2023-04-01
# 1168         2401            0  63569.0  2023-04-02
# 1169          842            0  63578.0  2023-04-03
# 1170         3588            0  63616.0  2023-04-04
# 1171         3353            0  63652.0  2023-04-05
#
# [1172 rows x 11 columns]

# %%
def Processing_SIR(file, city):
    df = pd.DataFrame()

    N = 9776000
    Recover = [7, 14]
    Reinfectable = 90

    df['Date'] = file['stdDay']
    df['city'] = file['gubun']

    # 사망자
    df['Death'] = file['deathCnt']                 # 누적 사망자
    df['Death_n'] = df['Death'].diff().fillna(0)   # 신규 사망자

    df['Inf_AC'] = file['defCnt']                  # 누적 감염자
    df['Inf_n'] = df['Inf_AC'].diff().fillna(0)    # 신규 감염자

    # 감염자
    df['Infected'] = df['Inf_AC']  
    df.iloc[Recover[1]:, -1] = (df.iloc[Recover[1]:, -1]
                               .reset_index(drop = True)
                               .sub(df.iloc[:len(df)-Recover[1], -1]))

    # 회복자
    df['Recovered'] = 0
    df.iloc[Recover[1]:, -1] = df.iloc[:len(df)-Recover[1], 4]
    df.iloc[Recover[1] + Reinfectable:, -1] = (df.iloc[Recover[1]+Reinfectable:, -1]
                                               .reset_index(drop = True)
                                               .sub(df.iloc[:len(df)-(Recover[1]+Reinfectable), 4]))
    df['Recovered'] = df['Recovered']-df['Death']
    df['Recovered_n'] = df['Recovered'].diff().fillna(0)  # 신규 회복자

    # 취약자
    df['Susceptible'] = N - df['Inf_AC']
    df.iloc[Reinfectable:, -1] = (df.iloc[Reinfectable:, -1]
                                  .reset_index(drop = True)
                                  .add(df.iloc[:len(df)-Reinfectable, 8]))
    df['Susceptible_n'] = df['Susceptible'].diff().fillna(0)   # 신규 취약자

    df['alpha'] = df.iloc[1:, 10].reset_index(drop = True)
    df.iloc[Reinfectable-1:, -1] = (df.iloc[Reinfectable-1:, -1]
                                    .reset_index(drop = True)
                                    .sub(df.iloc[:len(df)-(Reinfectable-1), 8]))
    df.iloc[Reinfectable:, -1] = (df.iloc[Reinfectable:, -1]
                                  .reset_index(drop = True)
                                  .add(df.iloc[:len(df)-Reinfectable, 8]))
    df['alpha'] = -1*N*df['alpha']/(df['Susceptible']*df['Infected'])
    df.loc[df['alpha'] == 0, 'alpha'] = 0
    df = df.replace([np.inf, -np.inf], np.nan).fillna(0)
    
    df_final = df[['Date', 'city', 'Death', 'Infected', 'Recovered', 'Susceptible', 'alpha']].copy()
    
    return df_final

def Overlook(df, city):
    print(city, df['alpha'].describe())
    df.head()
    plt.plot(df['alpha'])

# %%
for key, file in dic_files.items():
    df_final = Processing_SIR(file, key)
    df_final.to_csv(f'Data/SIR/{key}_SIR.csv', index = False)
    Overlook(df_final, key)
# Out:
# 강원 count    1172.000000
# mean        0.082929
# std         0.125345
# min         0.000000
# 25%         0.036575
# 50%         0.064892
# 75%         0.097032
# max         2.000046
# Name: alpha, dtype: float64
# 경기 count    1172.000000
# mean        0.137640
# std         0.126942
# min         0.000000
# 25%         0.065459
# 50%         0.091412
# 75%         0.151454
# max         1.000002
# Name: alpha, dtype: float64
# 경남 count    1172.000000
# mean        0.087915
# std         0.120029
# min         0.000000
# 25%         0.040001
# 50%         0.068634
# 75%         0.102018
# max         1.750001
# Name: alpha, dtype: float64
# 경북 count    1172.000000
# mean        0.089331
# std         0.165562
# min         0.000000
# 25%         0.041094
# 50%         0.069785
# 75%         0.102084
# max         4.076934
# Name: alpha, dtype: float64
# 광주 count    1172.000000
# mean        0.084841
# std         0.171980
# min         0.000000
# 25%         0.029463
# 50%         0.064505
# 75%         0.101781
# max         4.000013
# Name: alpha, dtype: float64
# 대구 count    1172.000000
# mean        0.106431
# std         0.791238
# min         0.000000
# 25%         0.042404
# 50%         0.070549
# 75%         0.100285
# max        27.000003
# Name: alpha, dtype: float64
# 대전 count    1172.000000
# mean        0.086387
# std         0.162387
# min         0.000000
# 25%         0.031306
# 50%         0.063242
# 75%         0.098855
# max         2.907259
# Name: alpha, dtype: float64
# 부산 count    1172.000000
# mean        0.088566
# std         0.157845
# min         0.000000
# 25%         0.042090
# 50%         0.069133
# 75%         0.100069
# max         3.500001
# Name: alpha, dtype: float64
# 서울 count    1172.000000
# mean        0.105796
# std         0.120225
# min         0.000000
# 25%         0.060386
# 50%         0.083249
# 75%         0.128389
# max         3.000000
# Name: alpha, dtype: float64
# 세종 count    1172.000000
# mean        0.079317
# std         0.178001
# min         0.000000
# 25%         0.000000
# 50%         0.055183
# 75%         0.090912
# max         3.000027
# Name: alpha, dtype: float64
# 울산 count    1172.000000
# mean        0.086245
# std         0.168639
# min         0.000000
# 25%         0.021346
# 50%         0.060234
# 75%         0.096097
# max         4.000018
# Name: alpha, dtype: float64
# 인천 count    1172.000000
# mean        0.083898
# std         0.081539
# min         0.000000
# 25%         0.048876
# 50%         0.071485
# 75%         0.100692
# max         1.090911
# Name: alpha, dtype: float64
# 전남 count    1172.000000
# mean        0.080911
# std         0.112745
# min         0.000000
# 25%         0.023259
# 50%         0.063239
# 75%         0.098596
# max         1.000094
# Name: alpha, dtype: float64
# 전북 count    1172.000000
# mean        0.080807
# std         0.118335
# min         0.000000
# 25%         0.030213
# 50%         0.064087
# 75%         0.100119
# max         2.000008
# Name: alpha, dtype: float64
# 제주 count    1172.000000
# mean        0.075358
# std         0.153459
# min         0.000000
# 25%         0.000000
# 50%         0.055150
# 75%         0.090836
# max         3.000006
# Name: alpha, dtype: float64
# 충남 count    1172.000000
# mean        0.085157
# std         0.129140
# min         0.000000
# 25%         0.042096
# 50%         0.068853
# 75%         0.099067
# max         2.500001
# Name: alpha, dtype: float64
# 충북 count    1172.000000
# mean        0.082599
# std         0.122377
# min         0.000000
# 25%         0.034650
# 50%         0.065463
# 75%         0.099218
# max         2.000015
# Name: alpha, dtype: float64
