# %%
import os
os.chdir('D:\\Gnan\\DA\\KMU\\Prediction-COVID-19')
from utils import *
from model import *
from trainer import *

from torch.optim.adam import Adam
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 3
#       1 import os
#       2 os.chdir('D:\\Gnan\\DA\\KMU\\Prediction-COVID-19')
# ----> 3 from utils import *
#       4 from model import *
#       5 from trainer import *
#
# File D:\Gnan\DA\KMU\Prediction-COVID-19\utils.py:8
#       5 import pandas as pd
#       6 import matplotlib.pyplot as plt
# ----> 8 import torch
#       9 from torch.utils.data import TensorDataset, DataLoader
#      10 from sklearn.preprocessing import StandardScaler, MinMaxScaler
#
# File ~\anaconda3\envs\KMU_DA\lib\site-packages\torch\__init__.py:129
#     127     err = ctypes.WinError(last_error)
#     128     err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 129     raise err
#     130 elif res is not None:
#     131     is_loaded = True
#
# OSError: [WinError 1455] 이 작업을 완료하기 위한 페이징 파일이 너무 작습니다. Error loading "C:\Users\PC\anaconda3\envs\KMU_DA\lib\site-packages\torch\lib\cudnn_cnn_infer64_8.dll" or one of its dependencies.

# %%
path = 'Data/SIR_Origin/*.csv'
dic_files = Load_files.load_files(path, -17, -15)
data = dic_files['서울']
data

# %%
criterion = nn.MSELoss()
lr = 1e-4
patience = 20
hidden_size = 16
num_layers = 2
batch_size = 32
dropout = 0.25

input_size = 3
sequence_length = 60
num_epochs = 10000

df = Prepare_df.processing(data, 'Date', 'alpha')

x = df.iloc[:, 0:]
y = df.iloc[:,:1]

ms = MinMaxScaler()
ss = StandardScaler()

ss.fit(x)
ms.fit(y)

x, y, x_ss, y_ms, train_loader, test_loader = Prepare_df.split_data(df, 800, 60, 7, batch_size, 'mtm')

model_GRU_seq2seq = GRU_encoder_decoder(input_size = input_size,
                                        hidden_size = hidden_size,
                                        num_layers = num_layers, 
                                        dropout = dropout, 
                                        device = device).to(device)

model = model_GRU_seq2seq

optimizer = Adam(model.parameters(), lr = lr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 criterion = nn.MSELoss()
#       2 lr = 1e-4
#       3 patience = 20
#
# NameError: name 'nn' is not defined

# %%
loss_list, model = Trainer.Many_to_Many(train_loader, 
                                        test_loader, 
                                        model, 
                                        criterion, 
                                        optimizer, 
                                        num_epochs, 
                                        patience,
                                        device)
# Out:
# epoch: 100 loss: 0.000801
# epoch: 200 loss: 0.000690
# epoch: 300 loss: 0.000659
#
#  Early Stopping / epoch: 321 loss: 0.000661

# %%
plt.plot(loss_list)

# %%
first_label_y, first_predicted = predict_mtm(model, df, x_ss, y_ms, 7, 0.5, device)

# %%
print(mape(first_label_y+1, first_predicted))
plotting(first_label_y, first_predicted)
# Out:
# 90.55197834968567

# %%
data_predicted = data.copy()
data_predicted['predicted_alpha'] = 0
data_predicted.iloc[68:, -1] = first_predicted
data_predicted['predicted_Infected'] = data_predicted['Infected']
for i in range(801, len(data_predicted)):
    data_predicted.iloc[i, -1] = (data_predicted.iloc[i-1, -1]
                                  *(1-data_predicted.iloc[i-1, 7] - data_predicted.iloc[i-1, 8]
                                    +(data_predicted.iloc[i-1, 2]*data_predicted.iloc[i-1, 9]
                                      /data_predicted.iloc[0, 2])))
data_predicted
# Out:
#             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
# 0     2020-01-20   서울      9535432         0     0          0  0.000000
# 1     2020-01-21   서울      9535432         0     0          0  0.000000
# 2     2020-01-22   서울      9535432         0     0          0  0.000000
# 3     2020-01-23   서울      9535432         0     0          0  0.000000
# 4     2020-01-24   서울      9535431         1     0          0  0.000000
# ...          ...  ...          ...       ...   ...        ...       ...
# 1167  2023-04-01   서울      3544282     25006  6383    5959761  0.258321
# 1168  2023-04-02   서울      3541881     25537  6383    5961631  0.088766
# 1169  2023-04-03   서울      3541039     25689  6384    5962320  0.376110
# 1170  2023-04-04   서울      3537451     26432  6387    5965162  0.341943
# 1171  2023-04-05   서울      3534098     27059  6390    5967885  0.000000
#
#           beta     gamma  predicted_alpha  predicted_Infected
# 0     0.000000  0.000000         0.000000            0.000000
# 1     0.000000  0.000000         0.000000            0.000000
# 2     0.000000  0.000000         0.000000            0.000000
# 3     0.000000  0.000000         0.000000            0.000000
# 4     0.000000  0.000000         0.000000            1.000000
# ...        ...       ...              ...                 ...
# 1167  0.074782  0.000000         0.238532          518.838811
# 1168  0.026980  0.000039         0.108330          526.039857
# 1169  0.110631  0.000117         0.277808          532.993453
# 1170  0.103019  0.000113         0.369687          528.952172
# 1171  0.000000  0.000000         0.321074          546.943920
#
# [1172 rows x 11 columns]

# %%
plotting(data_predicted['Infected'], data_predicted['predicted_Infected'])
