# %%
import os
os.chdir('D:\\Gnan\\DA\\KMU\\Prediction-COVID-19')
from utils import *
from model import *
from trainer import *

from torch.optim.adam import Adam
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
path = 'Data/SIR_Origin/*.csv'
dic_files = Load_files.load_files(path, -17, -15)
data = dic_files['서울']
data
# Out:
#             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
# 0     2020-01-20   서울      9535432         0     0          0  0.000000
# 1     2020-01-21   서울      9535432         0     0          0  0.000000
# 2     2020-01-22   서울      9535432         0     0          0  0.000000
# 3     2020-01-23   서울      9535432         0     0          0  0.000000
# 4     2020-01-24   서울      9535431         1     0          0  0.000000
# ...          ...  ...          ...       ...   ...        ...       ...
# 1214  2023-05-20   서울      3372946     63591  6471    6092424  0.186540
# 1215  2023-05-21   서울      3368750     57027  6473    6103182  0.063087
# 1216  2023-05-22   서울      3367479     56653  6476    6104824  0.268003
# 1217  2023-05-23   서울      3362117     56269  6477    6110569  0.267742
# 1218  2023-05-24   서울      3356805     55958  6479    6116190  0.000000
#
#           beta     gamma
# 0     0.000000  0.000000
# 1     0.000000  0.000000
# 2     0.000000  0.000000
# 3     0.000000  0.000000
# 4     0.000000  0.000000
# ...        ...       ...
# 1214  0.169175  0.000031
# 1215  0.028793  0.000053
# 1216  0.101407  0.000018
# 1217  0.099895  0.000036
# 1218  0.000000  0.000000
#
# [1219 rows x 9 columns]

# %%
criterion = nn.MSELoss()
lr = 1e-4
patience = 20
hidden_size = 16
num_layers = 2
batch_size = 32
dropout = 0.25

input_size = 3
sequence_length = 60
num_epochs = 10000

df = Prepare_df.processing(data, 'Date', 'alpha')

x = df.iloc[:, 0:]
y = df.iloc[:,:1]

ms = MinMaxScaler()
ss = StandardScaler()

ss.fit(x)
ms.fit(y)

x, y, x_ss, y_ms, train_loader, test_loader = Prepare_df.split_data(df, 800, 60, 1, batch_size, 'mto')

model_LSTM = LSTM(input_size = input_size,
                 hidden_size = hidden_size,
                 sequence_length = sequence_length,
                 num_layers = num_layers, 
                 dropout = dropout, 
                 device = device).to(device)

model = model_LSTM

optimizer = Adam(model.parameters(), lr = lr)
# Out:
# torch.Size([800, 60, 3])
# torch.Size([800, 1])
# torch.Size([357, 60, 3])
# torch.Size([357, 1])

# %%
loss_list, model = Trainer.Many_to_One(train_loader, 
                                       test_loader, 
                                       model, 
                                       criterion, 
                                       optimizer, 
                                       num_epochs, 
                                       patience,
                                       device)
# Out:
# epoch: 100 loss: 0.0004
# epoch: 200 loss: 0.0001
#
#  Early Stopping / epoch: 201 loss: 0.0001

# %%
label_y, predicted = predict_mto(model, df, x_ss, y_ms)

# %%
print(mape(label_y+1, predicted))
plotting(label_y, predicted, 800)
# Out:
# 91.36677980422974

# %%
data_predicted = data.copy()
data_predicted['predicted_alpha'] = 0
data_predicted.iloc[62:, -1] = predicted
data_predicted['predicted_Infected'] = data_predicted['Infected']
for i in range(801, len(data_predicted)):
    data_predicted.iloc[i, -1] = (data_predicted.iloc[i-1, -1]
                                  *(1-data_predicted.iloc[i-1, 7] - data_predicted.iloc[i-1, 8]
                                    +(data_predicted.iloc[i-1, 2]*data_predicted.iloc[i-1, 9]
                                      /data_predicted.iloc[0, 2])))
data_predicted
# Out:
#             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
# 0     2020-01-20   서울      9535432         0     0          0  0.000000
# 1     2020-01-21   서울      9535432         0     0          0  0.000000
# 2     2020-01-22   서울      9535432         0     0          0  0.000000
# 3     2020-01-23   서울      9535432         0     0          0  0.000000
# 4     2020-01-24   서울      9535431         1     0          0  0.000000
# ...          ...  ...          ...       ...   ...        ...       ...
# 1214  2023-05-20   서울      3372946     63591  6471    6092424  0.186540
# 1215  2023-05-21   서울      3368750     57027  6473    6103182  0.063087
# 1216  2023-05-22   서울      3367479     56653  6476    6104824  0.268003
# 1217  2023-05-23   서울      3362117     56269  6477    6110569  0.267742
# 1218  2023-05-24   서울      3356805     55958  6479    6116190  0.000000
#
#           beta     gamma  predicted_alpha  predicted_Infected
# 0     0.000000  0.000000         0.000000            0.000000
# 1     0.000000  0.000000         0.000000            0.000000
# 2     0.000000  0.000000         0.000000            0.000000
# 3     0.000000  0.000000         0.000000            0.000000
# 4     0.000000  0.000000         0.000000            1.000000
# ...        ...       ...              ...                 ...
# 1214  0.169175  0.000031         0.103467            4.339639
# 1215  0.028793  0.000053         0.123645            3.764172
# 1216  0.101407  0.000018         0.084185            3.820018
# 1217  0.099895  0.000036         0.068469            3.546145
# 1218  0.000000  0.000000         0.131842            3.277386
#
# [1219 rows x 11 columns]

# %%
plotting(data_predicted['Infected'], data_predicted['predicted_Infected'], 800)

# %%
dic_files
# Out:
# {'강원':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   강원      1539277         0     0          0  0.000000
#  1     2020-01-21   강원      1539277         0     0          0  0.000000
#  2     2020-01-22   강원      1539277         0     0          0  0.000000
#  3     2020-01-23   강원      1539277         0     0          0  0.000000
#  4     2020-01-24   강원      1539277         0     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   강원       615401      6783  1338     915755  0.130908
#  1215  2023-05-21   강원       615046      5983  1338     916910  0.104576
#  1216  2023-05-22   강원       614796      5916  1338     917227  0.229381
#  1217  2023-05-23   강원       614254      5929  1338     917756  0.285716
#  1218  2023-05-24   강원       613578      5874  1339     918486  0.000000
#
#            beta     gamma
#  0     0.000000  0.000000
#  1     0.000000  0.000000
#  2     0.000000  0.000000
#  3     0.000000  0.000000
#  4     0.000000  0.000000
#  ...        ...       ...
#  1214  0.170279  0.000000
#  1215  0.052983  0.000000
#  1216  0.089419  0.000000
#  1217  0.123124  0.000169
#  1218  0.000000  0.000000
#
#  [1219 rows x 9 columns],
#  '경기':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   경기     13527299         0     0          0  0.000000
#  1     2020-01-21   경기     13527299         0     0          0  0.000000
#  2     2020-01-22   경기     13527299         0     0          0  0.000000
#  3     2020-01-23   경기     13527299         0     0          0  0.000000
#  4     2020-01-24   경기     13527299         0     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   경기      4990848     74057  8431    8453963  0.168063
#  1215  2023-05-21   경기      4986256     65574  8432    8467037  0.083199
#  1216  2023-05-22   경기      4984245     65223  8434    8469397  0.237725
#  1217  2023-05-23   경기      4978532     64759  8438    8475570  0.256780
#  1218  2023-05-24   경기      4972412     64149  8443    8482295  0.000000
#
#            beta     gamma
#  0     0.000000  0.000000
#  1     0.000000  0.000000
#  2     0.000000  0.000000
#  3     0.000000  0.000000
#  4     0.000000  0.000000
#  ...        ...       ...
#  1214  0.176540  0.000014
#  1215  0.035990  0.000030
#  1216  0.094645  0.000061
#  1217  0.103847  0.000077
#  1218  0.000000  0.000000
#
#  [1219 rows x 9 columns],
#  '경남':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   경남      3311631         0     0          0  0.000000
#  1     2020-01-21   경남      3311631         0     0          0  0.000000
#  2     2020-01-22   경남      3311631         0     0          0  0.000000
#  3     2020-01-23   경남      3311631         0     0          0  0.000000
#  4     2020-01-24   경남      3311631         0     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   경남      1435921     11890  1981    1861839  0.134420
#  1215  2023-05-21   경남      1435228     10716  1982    1863705  0.062443
#  1216  2023-05-22   경남      1434938     10612  1982    1864099  0.253360
#  1217  2023-05-23   경남      1433773     10715  1983    1865160  0.247895
#  1218  2023-05-24   경남      1432623     10752  1984    1866272  0.000000
#
#            beta     gamma
#  0     0.000000  0.000000
#  1     0.000000  0.000000
#  2     0.000000  0.000000
#  3     0.000000  0.000000
#  4     0.000000  0.000000
#  ...        ...       ...
#  1214  0.156939  0.000084
#  1215  0.036767  0.000000
#  1216  0.099981  0.000094
#  1217  0.103780  0.000093
#  1218  0.000000  0.000000
#
#  [1219 rows x 9 columns],
#  '경북':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   경북      2622174         0     0          0  0.000000
#  1     2020-01-21   경북      2622174         0     0          0  0.000000
#  2     2020-01-22   경북      2622174         0     0          0  0.000000
#  3     2020-01-23   경북      2622174         0     0          0  0.000000
#  4     2020-01-24   경북      2622174         0     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   경북      1185381      7636  2109    1427048  0.166863
#  1215  2023-05-21   경북      1184805      6735  2109    1428525  0.091024
#  1216  2023-05-22   경북      1184528      6731  2109    1428806  0.213443
#  1217  2023-05-23   경북      1183879      6815  2109    1429371  0.290228
#  1218  2023-05-24   경북      1182986      6890  2109    1430189  0.000000
#
#            beta  gamma
#  0     0.000000    0.0
#  1     0.000000    0.0
#  2     0.000000    0.0
#  3     0.000000    0.0
#  4     0.000000    0.0
#  ...        ...    ...
#  1214  0.193426    0.0
#  1215  0.041722    0.0
#  1216  0.083940    0.0
#  1217  0.120029    0.0
#  1218  0.000000    0.0
#
#  [1219 rows x 9 columns],
#  '광주':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   광주      1440908         0     0          0  0.000000
#  1     2020-01-21   광주      1440908         0     0          0  0.000000
#  2     2020-01-22   광주      1440908         0     0          0  0.000000
#  3     2020-01-23   광주      1440908         0     0          0  0.000000
#  4     2020-01-24   광주      1440908         0     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   광주       522161      7520   832     910395  0.178341
#  1215  2023-05-21   광주       521675      6745   832     911656  0.084357
#  1216  2023-05-22   광주       521469      6611   832     911996  0.205639
#  1217  2023-05-23   광주       520977      6612   832     912487  0.282351
#  1218  2023-05-24   광주       520302      6531   832     913243  0.000000
#
#            beta  gamma
#  0     0.000000    0.0
#  1     0.000000    0.0
#  2     0.000000    0.0
#  3     0.000000    0.0
#  4     0.000000    0.0
#  ...        ...    ...
#  1214  0.167686    0.0
#  1215  0.050408    0.0
#  1216  0.074270    0.0
#  1217  0.114338    0.0
#  1218  0.000000    0.0
#
#  [1219 rows x 9 columns],
#  '대구':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   대구      2389150         0     0          0  0.000000
#  1     2020-01-21   대구      2389150         0     0          0  0.000000
#  2     2020-01-22   대구      2389150         0     0          0  0.000000
#  3     2020-01-23   대구      2389150         0     0          0  0.000000
#  4     2020-01-24   대구      2389150         0     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   대구      1020320      7621  2010    1359199  0.158542
#  1215  2023-05-21   대구      1019804      6775  2010    1360561  0.113420
#  1216  2023-05-22   대구      1019476      6856  2010    1360808  0.297382
#  1217  2023-05-23   대구      1018606      7133  2011    1361400  0.291339
#  1218  2023-05-24   대구      1017720      7342  2012    1362076  0.000000
#
#            beta     gamma
#  0     0.000000  0.000000
#  1     0.000000  0.000000
#  2     0.000000  0.000000
#  3     0.000000  0.000000
#  4     0.000000  0.000000
#  ...        ...       ...
#  1214  0.178717  0.000000
#  1215  0.036458  0.000000
#  1216  0.086348  0.000146
#  1217  0.094771  0.000140
#  1218  0.000000  0.000000
#
#  [1219 rows x 9 columns],
#  '대전':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   대전      1454068         0     0          0  0.000000
#  1     2020-01-21   대전      1454068         0     0          0  0.000000
#  2     2020-01-22   대전      1454068         0     0          0  0.000000
#  3     2020-01-23   대전      1454068         0     0          0  0.000000
#  4     2020-01-24   대전      1454068         0     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   대전       533668      7739   958     911703  0.182020
#  1215  2023-05-21   대전       533151      6905   958     913054  0.093609
#  1216  2023-05-22   대전       532914      6914   958     913282  0.252173
#  1217  2023-05-23   대전       532275      6875   959     913959  0.259074
#  1218  2023-05-24   대전       531623      6823   960     914662  0.000000
#
#            beta     gamma
#  0     0.000000  0.000000
#  1     0.000000  0.000000
#  2     0.000000  0.000000
#  3     0.000000  0.000000
#  4     0.000000  0.000000
#  ...        ...       ...
#  1214  0.174570  0.000000
#  1215  0.033020  0.000000
#  1216  0.097917  0.000145
#  1217  0.102255  0.000145
#  1218  0.000000  0.000000
#
#  [1219 rows x 9 columns],
#  '부산':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   부산      3353379         0     0          0  0.000000
#  1     2020-01-21   부산      3353379         0     0          0  0.000000
#  2     2020-01-22   부산      3353379         0     0          0  0.000000
#  3     2020-01-23   부산      3353379         0     0          0  0.000000
#  4     2020-01-24   부산      3353379         0     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   부산      1496026     10845  2847    1843661  0.171137
#  1215  2023-05-21   부산      1495198      9748  2847    1845586  0.072704
#  1216  2023-05-22   부산      1494882      9795  2848    1845854  0.303908
#  1217  2023-05-23   부산      1493555     10064  2850    1846910  0.301848
#  1218  2023-05-24   부산      1492202     10393  2851    1847933  0.000000
#
#            beta     gamma
#  0     0.000000  0.000000
#  1     0.000000  0.000000
#  2     0.000000  0.000000
#  3     0.000000  0.000000
#  4     0.000000  0.000000
#  ...        ...       ...
#  1214  0.177501  0.000000
#  1215  0.027493  0.000103
#  1216  0.107810  0.000204
#  1217  0.101649  0.000099
#  1218  0.000000  0.000000
#
#  [1219 rows x 9 columns],
#  '서울':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   서울      9535432         0     0          0  0.000000
#  1     2020-01-21   서울      9535432         0     0          0  0.000000
#  2     2020-01-22   서울      9535432         0     0          0  0.000000
#  3     2020-01-23   서울      9535432         0     0          0  0.000000
#  4     2020-01-24   서울      9535431         1     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   서울      3372946     63591  6471    6092424  0.186540
#  1215  2023-05-21   서울      3368750     57027  6473    6103182  0.063087
#  1216  2023-05-22   서울      3367479     56653  6476    6104824  0.268003
#  1217  2023-05-23   서울      3362117     56269  6477    6110569  0.267742
#  1218  2023-05-24   서울      3356805     55958  6479    6116190  0.000000
#
#            beta     gamma
#  0     0.000000  0.000000
#  1     0.000000  0.000000
#  2     0.000000  0.000000
#  3     0.000000  0.000000
#  4     0.000000  0.000000
#  ...        ...       ...
#  1214  0.169175  0.000031
#  1215  0.028793  0.000053
#  1216  0.101407  0.000018
#  1217  0.099895  0.000036
#  1218  0.000000  0.000000
#
#  [1219 rows x 9 columns],
#  '세종':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   세종     370439.0       0.0     0          0  0.000000
#  1     2020-01-21   세종     370439.0       0.0     0          0  0.000000
#  2     2020-01-22   세종     370439.0       0.0     0          0  0.000000
#  3     2020-01-23   세종     370439.0       0.0     0          0  0.000000
#  4     2020-01-24   세종     370439.0       0.0     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   세종     119726.0    2104.0    57     248552  0.183820
#  1215  2023-05-21   세종     119601.0    1883.0    57     248898  0.080599
#  1216  2023-05-22   세종     119552.0    1876.0    57     248954  0.260966
#  1217  2023-05-23   세종     119394.0    1869.0    57     249119  0.253990
#  1218  2023-05-24   세종     119241.0    1864.0    57     249277  0.000000
#
#            beta  gamma
#  0     0.000000    0.0
#  1     0.000000    0.0
#  2     0.000000    0.0
#  3     0.000000    0.0
#  4     0.000000    0.0
#  ...        ...    ...
#  1214  0.164449    0.0
#  1215  0.029740    0.0
#  1216  0.087953    0.0
#  1217  0.084537    0.0
#  1218  0.000000    0.0
#
#  [1219 rows x 9 columns],
#  '울산':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   울산      1122757         0     0          0  0.000000
#  1     2020-01-21   울산      1122757         0     0          0  0.000000
#  2     2020-01-22   울산      1122757         0     0          0  0.000000
#  3     2020-01-23   울산      1122757         0     0          0  0.000000
#  4     2020-01-24   울산      1122757         0     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   울산       456237      3655   532     662333  0.170345
#  1215  2023-05-21   울산       455984      3377   532     662864  0.069997
#  1216  2023-05-22   울산       455888      3380   532     662957  0.308942
#  1217  2023-05-23   울산       455464      3511   532     663250  0.337009
#  1218  2023-05-24   울산       454984      3687   533     663553  0.000000
#
#            beta     gamma
#  0     0.000000  0.000000
#  1     0.000000  0.000000
#  2     0.000000  0.000000
#  3     0.000000  0.000000
#  4     0.000000  0.000000
#  ...        ...       ...
#  1214  0.145280  0.000000
#  1215  0.027539  0.000000
#  1216  0.086686  0.000000
#  1217  0.086300  0.000285
#  1218  0.000000  0.000000
#
#  [1219 rows x 9 columns],
#  '인천':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   인천      2952838         1     0          0  0.000000
#  1     2020-01-21   인천      2952838         1     0          0  0.000000
#  2     2020-01-22   인천      2952838         1     0          0  0.000000
#  3     2020-01-23   인천      2952838         1     0          0  0.000000
#  4     2020-01-24   인천      2952838         1     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   인천      1118923     15432  1919    1816565  0.176823
#  1215  2023-05-21   인천      1117889     13552  1919    1819479  0.064126
#  1216  2023-05-22   인천      1117560     13347  1919    1820013  0.237556
#  1217  2023-05-23   인천      1116360     13112  1920    1821447  0.233198
#  1218  2023-05-24   인천      1115204     12874  1921    1822840  0.000000
#
#            beta     gamma
#  0     0.000000  0.000000
#  1     0.000000  0.000000
#  2     0.000000  0.000000
#  3     0.000000  0.000000
#  4     0.000000  0.000000
#  ...        ...       ...
#  1214  0.188828  0.000000
#  1215  0.039404  0.000000
#  1216  0.107440  0.000075
#  1217  0.106239  0.000076
#  1218  0.000000  0.000000
#
#  [1219 rows x 9 columns],
#  '전남':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   전남      1834016         0     0          0  0.000000
#  1     2020-01-21   전남      1834016         0     0          0  0.000000
#  2     2020-01-22   전남      1834016         0     0          0  0.000000
#  3     2020-01-23   전남      1834016         0     0          0  0.000000
#  4     2020-01-24   전남      1834016         0     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   전남       802190      8716  1008    1022102  0.152925
#  1215  2023-05-21   전남       801607      7678  1009    1023722  0.066153
#  1216  2023-05-22   전남       801385      7613  1010    1024008  0.211330
#  1217  2023-05-23   전남       800682      7631  1010    1024693  0.240133
#  1218  2023-05-24   전남       799882      7612  1012    1025510  0.000000
#
#            beta     gamma
#  0     0.000000  0.000000
#  1     0.000000  0.000000
#  2     0.000000  0.000000
#  3     0.000000  0.000000
#  4     0.000000  0.000000
#  ...        ...       ...
#  1214  0.185865  0.000115
#  1215  0.037249  0.000130
#  1216  0.089978  0.000000
#  1217  0.107063  0.000262
#  1218  0.000000  0.000000
#
#  [1219 rows x 9 columns],
#  '전북':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   전북      1786855         0     0          0  0.000000
#  1     2020-01-21   전북      1786855         0     0          0  0.000000
#  2     2020-01-22   전북      1786855         0     0          0  0.000000
#  3     2020-01-23   전북      1786855         0     0          0  0.000000
#  4     2020-01-24   전북      1786855         0     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   전북       728039      8140  1234    1049442  0.165231
#  1215  2023-05-21   전북       727491      7164  1234    1050966  0.060342
#  1216  2023-05-22   전북       727315      7119  1234    1051187  0.211893
#  1217  2023-05-23   전북       726701      7048  1235    1051871  0.239327
#  1218  2023-05-24   전북       726015      6939  1235    1052666  0.000000
#
#            beta    gamma
#  0     0.000000  0.00000
#  1     0.000000  0.00000
#  2     0.000000  0.00000
#  3     0.000000  0.00000
#  4     0.000000  0.00000
#  ...        ...      ...
#  1214  0.187224  0.00000
#  1215  0.030849  0.00000
#  1216  0.096081  0.00014
#  1217  0.112798  0.00000
#  1218  0.000000  0.00000
#
#  [1219 rows x 9 columns],
#  '제주':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   제주       676518         0     0          0  0.000000
#  1     2020-01-21   제주       676518         0     0          0  0.000000
#  2     2020-01-22   제주       676518         0     0          0  0.000000
#  3     2020-01-23   제주       676518         0     0          0  0.000000
#  4     2020-01-24   제주       676518         0     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   제주       276180      3724   281     396333  0.193386
#  1215  2023-05-21   제주       275886      3462   281     396889  0.130329
#  1216  2023-05-22   제주       275702      3448   281     397087  0.133080
#  1217  2023-05-23   제주       275515      3479   281     397243  0.274555
#  1218  2023-05-24   제주       275126      3545   282     397565  0.000000
#
#            beta     gamma
#  0     0.000000  0.000000
#  1     0.000000  0.000000
#  2     0.000000  0.000000
#  3     0.000000  0.000000
#  4     0.000000  0.000000
#  ...        ...       ...
#  1214  0.149302  0.000000
#  1215  0.057192  0.000000
#  1216  0.045244  0.000000
#  1217  0.092555  0.000287
#  1218  0.000000  0.000000
#
#  [1219 rows x 9 columns],
#  '충남':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   충남      2121108         0     0          0  0.000000
#  1     2020-01-21   충남      2121108         0     0          0  0.000000
#  2     2020-01-22   충남      2121108         0     0          0  0.000000
#  3     2020-01-23   충남      2121108         0     0          0  0.000000
#  4     2020-01-24   충남      2121108         0     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   충남       846080      9659  1600    1263769  0.165333
#  1215  2023-05-21   충남       845443      8313  1600    1265752  0.084806
#  1216  2023-05-22   충남       845162      8283  1601    1266062  0.239366
#  1217  2023-05-23   충남       844372      8226  1602    1266908  0.253465
#  1218  2023-05-24   충남       843542      8218  1602    1267746  0.000000
#
#            beta     gamma
#  0     0.000000  0.000000
#  1     0.000000  0.000000
#  2     0.000000  0.000000
#  3     0.000000  0.000000
#  4     0.000000  0.000000
#  ...        ...       ...
#  1214  0.205301  0.000000
#  1215  0.037291  0.000120
#  1216  0.102137  0.000121
#  1217  0.101872  0.000000
#  1218  0.000000  0.000000
#
#  [1219 rows x 9 columns],
#  '충북':             Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#  0     2020-01-20   충북      1597774         0     0          0  0.000000
#  1     2020-01-21   충북      1597774         0     0          0  0.000000
#  2     2020-01-22   충북      1597774         0     0          0  0.000000
#  3     2020-01-23   충북      1597774         0     0          0  0.000000
#  4     2020-01-24   충북      1597774         0     0          0  0.000000
#  ...          ...  ...          ...       ...   ...        ...       ...
#  1214  2023-05-20   충북       609405      7704  1050     979615  0.188880
#  1215  2023-05-21   충북       608850      7002  1050     980872  0.096320
#  1216  2023-05-22   충북       608593      6886  1051     981244  0.202449
#  1217  2023-05-23   충북       608062      6901  1052     981759  0.280623
#  1218  2023-05-24   충북       607325      6921  1052     982476  0.000000
#
#            beta     gamma
#  0     0.000000  0.000000
#  1     0.000000  0.000000
#  2     0.000000  0.000000
#  3     0.000000  0.000000
#  4     0.000000  0.000000
#  ...        ...       ...
#  1214  0.163162  0.000000
#  1215  0.053128  0.000143
#  1216  0.074789  0.000145
#  1217  0.103898  0.000000
#  1218  0.000000  0.000000
#
#  [1219 rows x 9 columns]}

# %%
learning_rates_list = [1e-3, 1e-4, 1e-5]
criterions_list = [nn.MSELoss(), criterion2, criterion3]
patiences_list = [20, 50, 100]
num_layers_list = [2, 4, 8]
batch_sizes_list = [16, 32, 64]
hidden_sizes_list = [8, 16, 32]
dropout_list = [0.25, 0.5]

# %%
Train_dict = {}
i = 0

for city, data in dic_files.items():
    for model in models_list:
        for lr in learning_rates_list:
            for criterion in criterions_list:
                for patience in patiences_list:
                    for num_layers in num_layers_list:
                        for batch_sizes in batch_sizes_list:
                            for hidden_size in hidden_sizes_list:    
                                for dropout in dropout_list:
                                    Train_dict[city] = [data, model, lr, criterion, patience, num_layers, batch_sizes, hidden_size, dropout]
                                    i += 1

                        
print(i)
# Out:
# 297432

# %%
Train_dict
# Out:
# {'강원': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   강원      1539277         0     0          0  0.000000
#   1     2020-01-21   강원      1539277         0     0          0  0.000000
#   2     2020-01-22   강원      1539277         0     0          0  0.000000
#   3     2020-01-23   강원      1539277         0     0          0  0.000000
#   4     2020-01-24   강원      1539277         0     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   강원       615401      6783  1338     915755  0.130908
#   1215  2023-05-21   강원       615046      5983  1338     916910  0.104576
#   1216  2023-05-22   강원       614796      5916  1338     917227  0.229381
#   1217  2023-05-23   강원       614254      5929  1338     917756  0.285716
#   1218  2023-05-24   강원       613578      5874  1339     918486  0.000000
#
#             beta     gamma
#   0     0.000000  0.000000
#   1     0.000000  0.000000
#   2     0.000000  0.000000
#   3     0.000000  0.000000
#   4     0.000000  0.000000
#   ...        ...       ...
#   1214  0.170279  0.000000
#   1215  0.052983  0.000000
#   1216  0.089419  0.000000
#   1217  0.123124  0.000169
#   1218  0.000000  0.000000
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5],
#  '경기': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   경기     13527299         0     0          0  0.000000
#   1     2020-01-21   경기     13527299         0     0          0  0.000000
#   2     2020-01-22   경기     13527299         0     0          0  0.000000
#   3     2020-01-23   경기     13527299         0     0          0  0.000000
#   4     2020-01-24   경기     13527299         0     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   경기      4990848     74057  8431    8453963  0.168063
#   1215  2023-05-21   경기      4986256     65574  8432    8467037  0.083199
#   1216  2023-05-22   경기      4984245     65223  8434    8469397  0.237725
#   1217  2023-05-23   경기      4978532     64759  8438    8475570  0.256780
#   1218  2023-05-24   경기      4972412     64149  8443    8482295  0.000000
#
#             beta     gamma
#   0     0.000000  0.000000
#   1     0.000000  0.000000
#   2     0.000000  0.000000
#   3     0.000000  0.000000
#   4     0.000000  0.000000
#   ...        ...       ...
#   1214  0.176540  0.000014
#   1215  0.035990  0.000030
#   1216  0.094645  0.000061
#   1217  0.103847  0.000077
#   1218  0.000000  0.000000
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5],
#  '경남': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   경남      3311631         0     0          0  0.000000
#   1     2020-01-21   경남      3311631         0     0          0  0.000000
#   2     2020-01-22   경남      3311631         0     0          0  0.000000
#   3     2020-01-23   경남      3311631         0     0          0  0.000000
#   4     2020-01-24   경남      3311631         0     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   경남      1435921     11890  1981    1861839  0.134420
#   1215  2023-05-21   경남      1435228     10716  1982    1863705  0.062443
#   1216  2023-05-22   경남      1434938     10612  1982    1864099  0.253360
#   1217  2023-05-23   경남      1433773     10715  1983    1865160  0.247895
#   1218  2023-05-24   경남      1432623     10752  1984    1866272  0.000000
#
#             beta     gamma
#   0     0.000000  0.000000
#   1     0.000000  0.000000
#   2     0.000000  0.000000
#   3     0.000000  0.000000
#   4     0.000000  0.000000
#   ...        ...       ...
#   1214  0.156939  0.000084
#   1215  0.036767  0.000000
#   1216  0.099981  0.000094
#   1217  0.103780  0.000093
#   1218  0.000000  0.000000
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5],
#  '경북': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   경북      2622174         0     0          0  0.000000
#   1     2020-01-21   경북      2622174         0     0          0  0.000000
#   2     2020-01-22   경북      2622174         0     0          0  0.000000
#   3     2020-01-23   경북      2622174         0     0          0  0.000000
#   4     2020-01-24   경북      2622174         0     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   경북      1185381      7636  2109    1427048  0.166863
#   1215  2023-05-21   경북      1184805      6735  2109    1428525  0.091024
#   1216  2023-05-22   경북      1184528      6731  2109    1428806  0.213443
#   1217  2023-05-23   경북      1183879      6815  2109    1429371  0.290228
#   1218  2023-05-24   경북      1182986      6890  2109    1430189  0.000000
#
#             beta  gamma
#   0     0.000000    0.0
#   1     0.000000    0.0
#   2     0.000000    0.0
#   3     0.000000    0.0
#   4     0.000000    0.0
#   ...        ...    ...
#   1214  0.193426    0.0
#   1215  0.041722    0.0
#   1216  0.083940    0.0
#   1217  0.120029    0.0
#   1218  0.000000    0.0
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5],
#  '광주': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   광주      1440908         0     0          0  0.000000
#   1     2020-01-21   광주      1440908         0     0          0  0.000000
#   2     2020-01-22   광주      1440908         0     0          0  0.000000
#   3     2020-01-23   광주      1440908         0     0          0  0.000000
#   4     2020-01-24   광주      1440908         0     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   광주       522161      7520   832     910395  0.178341
#   1215  2023-05-21   광주       521675      6745   832     911656  0.084357
#   1216  2023-05-22   광주       521469      6611   832     911996  0.205639
#   1217  2023-05-23   광주       520977      6612   832     912487  0.282351
#   1218  2023-05-24   광주       520302      6531   832     913243  0.000000
#
#             beta  gamma
#   0     0.000000    0.0
#   1     0.000000    0.0
#   2     0.000000    0.0
#   3     0.000000    0.0
#   4     0.000000    0.0
#   ...        ...    ...
#   1214  0.167686    0.0
#   1215  0.050408    0.0
#   1216  0.074270    0.0
#   1217  0.114338    0.0
#   1218  0.000000    0.0
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5],
#  '대구': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   대구      2389150         0     0          0  0.000000
#   1     2020-01-21   대구      2389150         0     0          0  0.000000
#   2     2020-01-22   대구      2389150         0     0          0  0.000000
#   3     2020-01-23   대구      2389150         0     0          0  0.000000
#   4     2020-01-24   대구      2389150         0     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   대구      1020320      7621  2010    1359199  0.158542
#   1215  2023-05-21   대구      1019804      6775  2010    1360561  0.113420
#   1216  2023-05-22   대구      1019476      6856  2010    1360808  0.297382
#   1217  2023-05-23   대구      1018606      7133  2011    1361400  0.291339
#   1218  2023-05-24   대구      1017720      7342  2012    1362076  0.000000
#
#             beta     gamma
#   0     0.000000  0.000000
#   1     0.000000  0.000000
#   2     0.000000  0.000000
#   3     0.000000  0.000000
#   4     0.000000  0.000000
#   ...        ...       ...
#   1214  0.178717  0.000000
#   1215  0.036458  0.000000
#   1216  0.086348  0.000146
#   1217  0.094771  0.000140
#   1218  0.000000  0.000000
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5],
#  '대전': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   대전      1454068         0     0          0  0.000000
#   1     2020-01-21   대전      1454068         0     0          0  0.000000
#   2     2020-01-22   대전      1454068         0     0          0  0.000000
#   3     2020-01-23   대전      1454068         0     0          0  0.000000
#   4     2020-01-24   대전      1454068         0     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   대전       533668      7739   958     911703  0.182020
#   1215  2023-05-21   대전       533151      6905   958     913054  0.093609
#   1216  2023-05-22   대전       532914      6914   958     913282  0.252173
#   1217  2023-05-23   대전       532275      6875   959     913959  0.259074
#   1218  2023-05-24   대전       531623      6823   960     914662  0.000000
#
#             beta     gamma
#   0     0.000000  0.000000
#   1     0.000000  0.000000
#   2     0.000000  0.000000
#   3     0.000000  0.000000
#   4     0.000000  0.000000
#   ...        ...       ...
#   1214  0.174570  0.000000
#   1215  0.033020  0.000000
#   1216  0.097917  0.000145
#   1217  0.102255  0.000145
#   1218  0.000000  0.000000
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5],
#  '부산': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   부산      3353379         0     0          0  0.000000
#   1     2020-01-21   부산      3353379         0     0          0  0.000000
#   2     2020-01-22   부산      3353379         0     0          0  0.000000
#   3     2020-01-23   부산      3353379         0     0          0  0.000000
#   4     2020-01-24   부산      3353379         0     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   부산      1496026     10845  2847    1843661  0.171137
#   1215  2023-05-21   부산      1495198      9748  2847    1845586  0.072704
#   1216  2023-05-22   부산      1494882      9795  2848    1845854  0.303908
#   1217  2023-05-23   부산      1493555     10064  2850    1846910  0.301848
#   1218  2023-05-24   부산      1492202     10393  2851    1847933  0.000000
#
#             beta     gamma
#   0     0.000000  0.000000
#   1     0.000000  0.000000
#   2     0.000000  0.000000
#   3     0.000000  0.000000
#   4     0.000000  0.000000
#   ...        ...       ...
#   1214  0.177501  0.000000
#   1215  0.027493  0.000103
#   1216  0.107810  0.000204
#   1217  0.101649  0.000099
#   1218  0.000000  0.000000
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5],
#  '서울': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   서울      9535432         0     0          0  0.000000
#   1     2020-01-21   서울      9535432         0     0          0  0.000000
#   2     2020-01-22   서울      9535432         0     0          0  0.000000
#   3     2020-01-23   서울      9535432         0     0          0  0.000000
#   4     2020-01-24   서울      9535431         1     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   서울      3372946     63591  6471    6092424  0.186540
#   1215  2023-05-21   서울      3368750     57027  6473    6103182  0.063087
#   1216  2023-05-22   서울      3367479     56653  6476    6104824  0.268003
#   1217  2023-05-23   서울      3362117     56269  6477    6110569  0.267742
#   1218  2023-05-24   서울      3356805     55958  6479    6116190  0.000000
#
#             beta     gamma
#   0     0.000000  0.000000
#   1     0.000000  0.000000
#   2     0.000000  0.000000
#   3     0.000000  0.000000
#   4     0.000000  0.000000
#   ...        ...       ...
#   1214  0.169175  0.000031
#   1215  0.028793  0.000053
#   1216  0.101407  0.000018
#   1217  0.099895  0.000036
#   1218  0.000000  0.000000
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5],
#  '세종': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   세종     370439.0       0.0     0          0  0.000000
#   1     2020-01-21   세종     370439.0       0.0     0          0  0.000000
#   2     2020-01-22   세종     370439.0       0.0     0          0  0.000000
#   3     2020-01-23   세종     370439.0       0.0     0          0  0.000000
#   4     2020-01-24   세종     370439.0       0.0     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   세종     119726.0    2104.0    57     248552  0.183820
#   1215  2023-05-21   세종     119601.0    1883.0    57     248898  0.080599
#   1216  2023-05-22   세종     119552.0    1876.0    57     248954  0.260966
#   1217  2023-05-23   세종     119394.0    1869.0    57     249119  0.253990
#   1218  2023-05-24   세종     119241.0    1864.0    57     249277  0.000000
#
#             beta  gamma
#   0     0.000000    0.0
#   1     0.000000    0.0
#   2     0.000000    0.0
#   3     0.000000    0.0
#   4     0.000000    0.0
#   ...        ...    ...
#   1214  0.164449    0.0
#   1215  0.029740    0.0
#   1216  0.087953    0.0
#   1217  0.084537    0.0
#   1218  0.000000    0.0
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5],
#  '울산': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   울산      1122757         0     0          0  0.000000
#   1     2020-01-21   울산      1122757         0     0          0  0.000000
#   2     2020-01-22   울산      1122757         0     0          0  0.000000
#   3     2020-01-23   울산      1122757         0     0          0  0.000000
#   4     2020-01-24   울산      1122757         0     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   울산       456237      3655   532     662333  0.170345
#   1215  2023-05-21   울산       455984      3377   532     662864  0.069997
#   1216  2023-05-22   울산       455888      3380   532     662957  0.308942
#   1217  2023-05-23   울산       455464      3511   532     663250  0.337009
#   1218  2023-05-24   울산       454984      3687   533     663553  0.000000
#
#             beta     gamma
#   0     0.000000  0.000000
#   1     0.000000  0.000000
#   2     0.000000  0.000000
#   3     0.000000  0.000000
#   4     0.000000  0.000000
#   ...        ...       ...
#   1214  0.145280  0.000000
#   1215  0.027539  0.000000
#   1216  0.086686  0.000000
#   1217  0.086300  0.000285
#   1218  0.000000  0.000000
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5],
#  '인천': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   인천      2952838         1     0          0  0.000000
#   1     2020-01-21   인천      2952838         1     0          0  0.000000
#   2     2020-01-22   인천      2952838         1     0          0  0.000000
#   3     2020-01-23   인천      2952838         1     0          0  0.000000
#   4     2020-01-24   인천      2952838         1     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   인천      1118923     15432  1919    1816565  0.176823
#   1215  2023-05-21   인천      1117889     13552  1919    1819479  0.064126
#   1216  2023-05-22   인천      1117560     13347  1919    1820013  0.237556
#   1217  2023-05-23   인천      1116360     13112  1920    1821447  0.233198
#   1218  2023-05-24   인천      1115204     12874  1921    1822840  0.000000
#
#             beta     gamma
#   0     0.000000  0.000000
#   1     0.000000  0.000000
#   2     0.000000  0.000000
#   3     0.000000  0.000000
#   4     0.000000  0.000000
#   ...        ...       ...
#   1214  0.188828  0.000000
#   1215  0.039404  0.000000
#   1216  0.107440  0.000075
#   1217  0.106239  0.000076
#   1218  0.000000  0.000000
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5],
#  '전남': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   전남      1834016         0     0          0  0.000000
#   1     2020-01-21   전남      1834016         0     0          0  0.000000
#   2     2020-01-22   전남      1834016         0     0          0  0.000000
#   3     2020-01-23   전남      1834016         0     0          0  0.000000
#   4     2020-01-24   전남      1834016         0     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   전남       802190      8716  1008    1022102  0.152925
#   1215  2023-05-21   전남       801607      7678  1009    1023722  0.066153
#   1216  2023-05-22   전남       801385      7613  1010    1024008  0.211330
#   1217  2023-05-23   전남       800682      7631  1010    1024693  0.240133
#   1218  2023-05-24   전남       799882      7612  1012    1025510  0.000000
#
#             beta     gamma
#   0     0.000000  0.000000
#   1     0.000000  0.000000
#   2     0.000000  0.000000
#   3     0.000000  0.000000
#   4     0.000000  0.000000
#   ...        ...       ...
#   1214  0.185865  0.000115
#   1215  0.037249  0.000130
#   1216  0.089978  0.000000
#   1217  0.107063  0.000262
#   1218  0.000000  0.000000
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5],
#  '전북': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   전북      1786855         0     0          0  0.000000
#   1     2020-01-21   전북      1786855         0     0          0  0.000000
#   2     2020-01-22   전북      1786855         0     0          0  0.000000
#   3     2020-01-23   전북      1786855         0     0          0  0.000000
#   4     2020-01-24   전북      1786855         0     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   전북       728039      8140  1234    1049442  0.165231
#   1215  2023-05-21   전북       727491      7164  1234    1050966  0.060342
#   1216  2023-05-22   전북       727315      7119  1234    1051187  0.211893
#   1217  2023-05-23   전북       726701      7048  1235    1051871  0.239327
#   1218  2023-05-24   전북       726015      6939  1235    1052666  0.000000
#
#             beta    gamma
#   0     0.000000  0.00000
#   1     0.000000  0.00000
#   2     0.000000  0.00000
#   3     0.000000  0.00000
#   4     0.000000  0.00000
#   ...        ...      ...
#   1214  0.187224  0.00000
#   1215  0.030849  0.00000
#   1216  0.096081  0.00014
#   1217  0.112798  0.00000
#   1218  0.000000  0.00000
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5],
#  '제주': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   제주       676518         0     0          0  0.000000
#   1     2020-01-21   제주       676518         0     0          0  0.000000
#   2     2020-01-22   제주       676518         0     0          0  0.000000
#   3     2020-01-23   제주       676518         0     0          0  0.000000
#   4     2020-01-24   제주       676518         0     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   제주       276180      3724   281     396333  0.193386
#   1215  2023-05-21   제주       275886      3462   281     396889  0.130329
#   1216  2023-05-22   제주       275702      3448   281     397087  0.133080
#   1217  2023-05-23   제주       275515      3479   281     397243  0.274555
#   1218  2023-05-24   제주       275126      3545   282     397565  0.000000
#
#             beta     gamma
#   0     0.000000  0.000000
#   1     0.000000  0.000000
#   2     0.000000  0.000000
#   3     0.000000  0.000000
#   4     0.000000  0.000000
#   ...        ...       ...
#   1214  0.149302  0.000000
#   1215  0.057192  0.000000
#   1216  0.045244  0.000000
#   1217  0.092555  0.000287
#   1218  0.000000  0.000000
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5],
#  '충남': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   충남      2121108         0     0          0  0.000000
#   1     2020-01-21   충남      2121108         0     0          0  0.000000
#   2     2020-01-22   충남      2121108         0     0          0  0.000000
#   3     2020-01-23   충남      2121108         0     0          0  0.000000
#   4     2020-01-24   충남      2121108         0     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   충남       846080      9659  1600    1263769  0.165333
#   1215  2023-05-21   충남       845443      8313  1600    1265752  0.084806
#   1216  2023-05-22   충남       845162      8283  1601    1266062  0.239366
#   1217  2023-05-23   충남       844372      8226  1602    1266908  0.253465
#   1218  2023-05-24   충남       843542      8218  1602    1267746  0.000000
#
#             beta     gamma
#   0     0.000000  0.000000
#   1     0.000000  0.000000
#   2     0.000000  0.000000
#   3     0.000000  0.000000
#   4     0.000000  0.000000
#   ...        ...       ...
#   1214  0.205301  0.000000
#   1215  0.037291  0.000120
#   1216  0.102137  0.000121
#   1217  0.101872  0.000000
#   1218  0.000000  0.000000
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5],
#  '충북': [            Date City  Susceptible  Infected  Dead  Recovered     alpha  \
#   0     2020-01-20   충북      1597774         0     0          0  0.000000
#   1     2020-01-21   충북      1597774         0     0          0  0.000000
#   2     2020-01-22   충북      1597774         0     0          0  0.000000
#   3     2020-01-23   충북      1597774         0     0          0  0.000000
#   4     2020-01-24   충북      1597774         0     0          0  0.000000
#   ...          ...  ...          ...       ...   ...        ...       ...
#   1214  2023-05-20   충북       609405      7704  1050     979615  0.188880
#   1215  2023-05-21   충북       608850      7002  1050     980872  0.096320
#   1216  2023-05-22   충북       608593      6886  1051     981244  0.202449
#   1217  2023-05-23   충북       608062      6901  1052     981759  0.280623
#   1218  2023-05-24   충북       607325      6921  1052     982476  0.000000
#
#             beta     gamma
#   0     0.000000  0.000000
#   1     0.000000  0.000000
#   2     0.000000  0.000000
#   3     0.000000  0.000000
#   4     0.000000  0.000000
#   ...        ...       ...
#   1214  0.163162  0.000000
#   1215  0.053128  0.000143
#   1216  0.074789  0.000145
#   1217  0.103898  0.000000
#   1218  0.000000  0.000000
#
#   [1219 rows x 9 columns],
#   BiGRU_encoder_decoder(
#     (BiGRU_encoder): BiGRU_encoder(
#       (gru): GRU(3, 16, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#     )
#     (BiGRU_decoder): BiGRU_decoder(
#       (gru): GRU(3, 16, num_layers=4, batch_first=True, dropout=0.25)
#       (linear): Linear(in_features=16, out_features=1, bias=True)
#     )
#   ),
#   1e-05,
#   <function utils.criterion3(actual, predict)>,
#   100,
#   8,
#   64,
#   32,
#   0.5]}

# %%
input_size = 3
sequence_length = 60
num_epochs = 10000
optimizer = Adam(model.parameters(), lr = lr)

model_RNN = RNN(input_size = input_size,
                hidden_size = hidden_size,
                sequence_length = sequence_length,
                num_layers = num_layers, 
                dropout = dropout, 
                device = device).to(device)

model_LSTM = LSTM(input_size = input_size,
                  hidden_size = hidden_size,
                  sequence_length = sequence_length,
                  num_layers = num_layers, 
                  dropout = dropout, 
                  device = device).to(device)

model_GRU = GRU(input_size = input_size,
                hidden_size = hidden_size,
                sequence_length = sequence_length,
                num_layers = num_layers, 
                dropout = dropout, 
                device = device).to(device)

model_BiRNN = BiRNN(input_size = input_size,
                    hidden_size = hidden_size,
                    sequence_length = sequence_length,
                    num_layers = num_layers, 
                    dropout = dropout, 
                    device = device).to(device)

model_BiLSTM = BiLSTM(input_size = input_size,
                      hidden_size = hidden_size,
                      sequence_length = sequence_length,
                      num_layers = num_layers, 
                      dropout = dropout, 
                      device = device).to(device)

model_BiGRU = BiGRU(input_size = input_size,
                    hidden_size = hidden_size,
                    sequence_length = sequence_length,
                    num_layers = num_layers, 
                    dropout = dropout, 
                    device = device).to(device)

model_seq2seq_RNN = RNN_encoder_decoder(input_size = input_size, 
                                        hidden_size = hidden_size,
                                        num_layers = num_layers, 
                                        dropout = dropout,
                                        device = device).to(device)

model_seq2seq_LSTM = LSTM_encoder_decoder(input_size = input_size, 
                                         hidden_size = hidden_size,
                                         num_layers = num_layers, 
                                         dropout = dropout,
                                         device = device).to(device)

model_seq2seq_GRU = GRU_encoder_decoder(input_size = input_size, 
                                        hidden_size = hidden_size,
                                        num_layers = num_layers, 
                                        dropout = dropout,
                                        device = device).to(device)

model_seq2seq_BiRNN = BiRNN_encoder_decoder(input_size = input_size, 
                                            hidden_size = hidden_size,
                                            num_layers = num_layers, 
                                            dropout = dropout,
                                            device = device).to(device)

model_seq2seq_BiLSTM = BiLSTM_encoder_decoder(input_size = input_size, 
                                              hidden_size = hidden_size,
                                              num_layers = num_layers, 
                                              dropout = dropout,
                                              device = device).to(device)

model_seq2seq_BiGRU = BiGRU_encoder_decoder(input_size = input_size, 
                                            hidden_size = hidden_size,
                                            num_layers = num_layers, 
                                            dropout = dropout,
                                            device = device).to(device)

model_dict = {}

keys = ['RNN', 'LSTM', 'GRU', 'BiRNN', 'BiLSTM', 'BiGRU', 
        'seq2seq_RNN', 'seq2seq_LSTM', 'seq2seq_GRU', 'seq2seq_BiRNN', 'seq2seq_BiLSTM', 'seq2seq_BiGRU']

models_list = [model_RNN, model_LSTM, model_GRU, 
              model_BiRNN, model_BiLSTM, model_BiGRU,
              model_seq2seq_RNN, model_seq2seq_LSTM, model_seq2seq_GRU, 
              model_seq2seq_BiRNN, model_seq2seq_BiLSTM, model_seq2seq_BiGRU]

for i, key in enumerate(keys):
    model_dict[key] = models_list[i]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       2 sequence_length = 60
#       3 num_epochs = 10000
#       5 model_RNN = RNN(input_size = input_size,
# ----> 6                 hidden_size = hidden_size,
#       7                 sequence_length = sequence_length,
#       8                 num_layers = num_layers,
#       9                 dropout = dropout,
#      10                 device = device).to(device)
#      12 model_LSTM = LSTM(input_size = input_size,
#      13                   hidden_size = hidden_size,
#      14                   sequence_length = sequence_length,
#      15                   num_layers = num_layers,
#      16                   dropout = dropout,
#      17                   device = device).to(device)
#      19 model_GRU = GRU(input_size = input_size,
#      20                 hidden_size = hidden_size,
#      21                 sequence_length = sequence_length,
#      22                 num_layers = num_layers,
#      23                 dropout = dropout,
#      24                 device = device).to(device)
#
# NameError: name 'hidden_size' is not defined

# %%
model_dict
# Out:
# {'RNN': RNN(
#    (rnn): RNN(3, 64, num_layers=16, batch_first=True, dropout=0.5)
#    (fc1): Linear(in_features=3840, out_features=128, bias=True)
#    (fc2): Linear(in_features=128, out_features=64, bias=True)
#    (fc3): Linear(in_features=64, out_features=1, bias=True)
#    (relu): ReLU()
#  ),
#  'LSTM': LSTM(
#    (lstm): LSTM(3, 64, num_layers=16, batch_first=True, dropout=0.5)
#    (fc1): Linear(in_features=3840, out_features=128, bias=True)
#    (fc2): Linear(in_features=128, out_features=64, bias=True)
#    (fc3): Linear(in_features=64, out_features=1, bias=True)
#    (relu): ReLU()
#  ),
#  'GRU': GRU(
#    (gru): GRU(3, 64, num_layers=16, batch_first=True, dropout=0.5)
#    (fc1): Linear(in_features=3840, out_features=128, bias=True)
#    (fc2): Linear(in_features=128, out_features=64, bias=True)
#    (fc3): Linear(in_features=64, out_features=1, bias=True)
#    (relu): ReLU()
#  ),
#  'BiRNN': BiRNN(
#    (rnn): RNN(3, 64, num_layers=16, batch_first=True, dropout=0.5, bidirectional=True)
#    (fc1): Linear(in_features=7680, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=1, bias=True)
#    (relu): ReLU()
#  ),
#  'BiLSTM': BiLSTM(
#    (lstm): LSTM(3, 64, num_layers=16, batch_first=True, dropout=0.5, bidirectional=True)
#    (fc1): Linear(in_features=7680, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=1, bias=True)
#    (relu): ReLU()
#  ),
#  'BiGRU': BiGRU(
#    (gru): GRU(3, 64, num_layers=16, batch_first=True, dropout=0.5, bidirectional=True)
#    (fc1): Linear(in_features=7680, out_features=256, bias=True)
#    (fc2): Linear(in_features=256, out_features=128, bias=True)
#    (fc3): Linear(in_features=128, out_features=64, bias=True)
#    (fc4): Linear(in_features=64, out_features=1, bias=True)
#    (relu): ReLU()
#  ),
#  'seq2seq_RNN': RNN_encoder_decoder(
#    (RNN_encoder): RNN_encoder(
#      (rnn): RNN(3, 64, num_layers=16, batch_first=True, dropout=0.5)
#    )
#    (RNN_decoder): RNN_decoder(
#      (rnn): RNN(3, 64, num_layers=16, batch_first=True, dropout=0.5)
#      (linear): Linear(in_features=64, out_features=1, bias=True)
#    )
#  ),
#  'seq2seq_LSTM': LSTM_encoder_decoder(
#    (LSTM_encoder): LSTM_encoder(
#      (lstm): LSTM(3, 64, num_layers=16, batch_first=True, dropout=0.5)
#    )
#    (LSTM_decoder): LSTM_decoder(
#      (lstm): LSTM(3, 64, num_layers=16, batch_first=True, dropout=0.3)
#      (linear): Linear(in_features=64, out_features=1, bias=True)
#    )
#  ),
#  'seq2seq_GRU': GRU_encoder_decoder(
#    (GRU_encoder): GRU_encoder(
#      (gru): GRU(3, 64, num_layers=16, batch_first=True, dropout=0.5)
#    )
#    (GRU_decoder): GRU_decoder(
#      (gru): GRU(3, 64, num_layers=16, batch_first=True, dropout=0.3)
#      (linear): Linear(in_features=64, out_features=1, bias=True)
#    )
#  ),
#  'seq2seq_BiRNN': BiRNN_encoder_decoder(
#    (BiRNN_encoder): BiRNN_encoder(
#      (rnn): RNN(3, 64, num_layers=16, batch_first=True, dropout=0.5, bidirectional=True)
#    )
#    (BiRNN_decoder): BiRNN_decoder(
#      (rnn): RNN(3, 64, num_layers=32, batch_first=True, dropout=0.5)
#      (linear): Linear(in_features=64, out_features=1, bias=True)
#    )
#  ),
#  'seq2seq_BiLSTM': BiLSTM_encoder_decoder(
#    (BiLSTM_encoder): BiLSTM_encoder(
#      (lstm): LSTM(3, 64, num_layers=16, batch_first=True, dropout=0.5, bidirectional=True)
#    )
#    (BiLSTM_decoder): BiLSTM_decoder(
#      (lstm): LSTM(3, 64, num_layers=32, batch_first=True, dropout=0.5)
#      (linear): Linear(in_features=64, out_features=1, bias=True)
#    )
#  ),
#  'seq2seq_BiGRU': BiGRU_encoder_decoder(
#    (BiGRU_encoder): BiGRU_encoder(
#      (gru): GRU(3, 64, num_layers=16, batch_first=True, dropout=0.5, bidirectional=True)
#    )
#    (BiGRU_decoder): BiGRU_decoder(
#      (gru): GRU(3, 64, num_layers=32, batch_first=True, dropout=0.5)
#      (linear): Linear(in_features=64, out_features=1, bias=True)
#    )
#  )}
