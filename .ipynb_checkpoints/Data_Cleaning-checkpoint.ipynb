# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 서울

# %%
city = '서울'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    서울   Seoul       0             0           0
# 1         0       0    서울   Seoul       0             0           0
# 2         0       0    서울   Seoul       0             0           0
# 3         0       0    서울   Seoul       0             0           0
# 4         0       1    서울   Seoul       1             0           1
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            1      0.0  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt   defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350       193    20138    서울   Seoul     329         11721        8224
# 351       193    20129    서울   Seoul     329         11710        8226
# 654       802   121843    서울   Seoul    1004        108509       11529
# 655       807   121843    서울   Seoul    1004        109151       11885
# 751      2205   320343    서울   Seoul    6888        224002           0
# 752      2205   313462    서울   Seoul    6888        320343           0
# 753      2205   320343    서울   Seoul    6888        320343           0
# 785      2661  1331263    서울   Seoul   56603        353601           0
# 786      2693  1331263    서울   Seoul   56603        353601           0
# 797      3144  2148186    서울   Seoul   65033        480318           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350          324            5    206.89  2021-01-04
# 351          325            4    206.80  2021-01-04
# 654          997            7   1260.00  2021-11-03
# 655          997            7   1260.00  2021-11-03
# 751         6873           15   3369.00  2022-02-07
# 752         6873           15   3296.00  2022-02-07
# 753         6873           15   3369.00  2022-02-07
# 785        56600            3  13999.00  2022-03-11
# 786        56600            3  13999.00  2022-03-11
# 797        65033            0  22590.00  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 44개
#      deathCnt   defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 813      3742  2922636    서울   Seoul   20894             0           0
# 814      3742  2922636    서울   Seoul   20894             0           0
# 862      4788  3590173    서울   Seoul    3589             0           0
# 863      4788  3590173    서울   Seoul    3589             0           0
# 893      4868  3648259    서울   Seoul     719             0           0
# 894      4868  3648259    서울   Seoul     719             0           0
# 960      5165  4475520    서울   Seoul   17722             0           0
# 961      5165  4475520    서울   Seoul   17722             0           0
# 981      5368  4723634    서울   Seoul   17384             0           0
# 982      5368  4723634    서울   Seoul   17384             0           0
#
#      localOccCnt  overFlowCnt  qurRate      stdDay
# 813        20894            0  30734.0  2022-04-04
# 814        20894            0  30734.0  2022-04-04
# 862         3589            0  37754.0  2022-05-21
# 863         3589            0  37754.0  2022-05-21
# 893          717            2  38365.0  2022-06-20
# 894          717            2  38365.0  2022-06-20
# 960        17707           15  47064.0  2022-08-25
# 961        17707           15  47064.0  2022-08-25
# 981        17368           16  49673.0  2022-09-14
# 982        17368           16  49673.0  2022-09-14

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# 수정해야하는 데이터 개수 : 27개
#      deathCnt   defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350       193    20138    서울   Seoul     329         11721        8224
# 351       193    20129    서울   Seoul     329         11710        8226
# 654       802   121843    서울   Seoul    1004        108509       11529
# 655       807   121843    서울   Seoul    1004        109151       11885
# 751      2205   320343    서울   Seoul    6888        224002           0
# 752      2205   313462    서울   Seoul    6888        320343           0
# 753      2205   320343    서울   Seoul    6888        320343           0
# 785      2661  1331263    서울   Seoul   56603        353601           0
# 786      2693  1331263    서울   Seoul   56603        353601           0
# 797      3144  2148186    서울   Seoul   65033        480318           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350          324            5    206.89  2021-01-04
# 351          325            4    206.80  2021-01-04
# 654          997            7   1260.00  2021-11-03
# 655          997            7   1260.00  2021-11-03
# 751         6873           15   3369.00  2022-02-07
# 752         6873           15   3296.00  2022-02-07
# 753         6873           15   3369.00  2022-02-07
# 785        56600            3  13999.00  2022-03-11
# 786        56600            3  13999.00  2022-03-11
# 797        65033            0  22590.00  2022-03-22

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [350, 654, 751, 785, 797, 801, 807, 835, 1024, 1049, 1091, 1153, 1168]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 12
# 12
#       deathCnt   defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 1164      6364  5955883    서울   Seoul    1979             0           0
# 1165      6364  5957871    서울   Seoul    1988             0           0
# 1166      6365  5959761    서울   Seoul    1927             0           0
# 1167         0  5961631    서울   Seoul    1870             0           0
# 1168      6366  5961631    서울   Seoul    1870             0           0
# 1169      6366  5962320    서울   Seoul     689             0           0
# 1170      6367  5965162    서울   Seoul    2842             0           0
# 1171      6369  5967885    서울   Seoul    2723             0           0
# 1172      6371  5970352    서울   Seoul    2467             0           0
# 1173      6372  5972545    서울   Seoul    2193             0           0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# 1164         1979            0  63170.0  2023-03-16
# 1165         1987            1  63191.0  2023-03-17
# 1166         1927            0  63211.0  2023-03-18
# 1167         1870            0  63231.0  2023-03-19
# 1168         1870            0  63231.0  2023-03-20
# 1169          689            0  63238.0  2023-03-20
# 1170         2840            2  63268.0  2023-03-21
# 1171         2723            0  63297.0  2023-03-22
# 1172         2466            1  63323.0  2023-03-23
# 1173         2191            2  63347.0  2023-03-24

# %%
del_index = [350, 654, 751, 752, 785, 798, 802, 807, 835, 1024, 1050, 1091, 1153, 1168]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    서울   Seoul       0             0           0
# 1         0       0    서울   Seoul       0             0           0
# 2         0       0    서울   Seoul       0             0           0
# 3         0       0    서울   Seoul       0             0           0
# 4         0       1    서울   Seoul       1             0           1
# 5         0       1    서울   Seoul       0             0           1
# 6         0       1    서울   Seoul       0             0           1
# 7         0       1    서울   Seoul       0             0           1
# 8         0       1    서울   Seoul       0             0           1
# 9         0       1    서울   Seoul       0             0           1
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            1      0.0  2020-01-24
# 5            0            0      0.0  2020-01-25
# 6            0            0      0.0  2020-01-26
# 7            0            0      0.0  2020-01-27
# 8            0            0      0.0  2020-01-28
# 9            0            0      0.0  2020-01-29

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### stdDay가 같은 데이터

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df_final.duplicated(['stdDay'], keep = False).sum()) + '개')
df_final[df_final.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 확인

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')

# %% [markdown]
# # 부산

# %%
city = '부산'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    부산   Busan       0             0           0
# 1         0       0    부산   Busan       0             0           0
# 2         0       0    부산   Busan       0             0           0
# 3         0       0    부산   Busan       0             0           0
# 4         0       0    부산   Busan       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350        58    2006    부산   Busan      37          1446         502
# 351        58    2007    부산   Busan      37          1447         502
# 654       165   14074    부산   Busan      80         13413         496
# 655       164   14074    부산   Busan      80         13375         455
# 751       364   45718    부산   Busan    1927         45718           0
# 752       364   43791    부산   Busan    1927         45718           0
# 753       364   45718    부산   Busan    1927         31126           0
# 785       691  436820    부산   Busan   22920         68841           0
# 786       651  436820    부산   Busan   22920         68472           0
# 797      1158  742457    부산   Busan   24707        282459           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350           34            3     58.80  2021-01-04
# 351           34            3     58.82  2021-01-04
# 654           77            3    415.00  2021-11-03
# 655           77            3    415.00  2021-11-03
# 751         1916           11   1365.00  2022-02-07
# 752         1916           11   1307.00  2022-02-07
# 753         1916           11   1365.00  2022-02-07
# 785        22917            3  13038.00  2022-03-11
# 786        22917            3  13038.00  2022-03-11
# 797        24707            0  22160.00  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 44개
#      deathCnt   defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 813      1646   926469    부산   Busan    4080             0           0
# 814      1646   926469    부산   Busan    4080             0           0
# 862      2118  1084656    부산   Busan    1094             0           0
# 863      2118  1084656    부산   Busan    1094             0           0
# 893      2170  1101815    부산   Busan     149             0           0
# 894      2170  1101815    부산   Busan     149             0           0
# 960      2331  1366157    부산   Busan    7164             0           0
# 961      2331  1366157    부산   Busan    7164             0           0
# 981      2406  1446689    부산   Busan    4982             0           0
# 982      2406  1446689    부산   Busan    4982             0           0
#
#      localOccCnt  overFlowCnt  qurRate      stdDay
# 813         4080            0  27653.0  2022-04-04
# 814         4080            0  27653.0  2022-04-04
# 862         1094            0  32374.0  2022-05-21
# 863         1094            0  32374.0  2022-05-21
# 893          148            1  32886.0  2022-06-20
# 894          148            1  32886.0  2022-06-20
# 960         7163            1  40776.0  2022-08-25
# 961         7163            1  40776.0  2022-08-25
# 981         4975            7  43180.0  2022-09-14
# 982         4975            7  43180.0  2022-09-14

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)][:]
# Out:
# 수정해야하는 데이터 개수 : 27개
#       deathCnt   defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350         58     2006    부산   Busan      37          1446         502
# 351         58     2007    부산   Busan      37          1447         502
# 654        165    14074    부산   Busan      80         13413         496
# 655        164    14074    부산   Busan      80         13375         455
# 751        364    45718    부산   Busan    1927         45718           0
# 752        364    43791    부산   Busan    1927         45718           0
# 753        364    45718    부산   Busan    1927         31126           0
# 785        691   436820    부산   Busan   22920         68841           0
# 786        651   436820    부산   Busan   22920         68472           0
# 797       1158   742457    부산   Busan   24707        282459           0
# 798       1158   742457    부산   Busan   24707        282459           0
# 801       1303   803861    부산   Busan   16705        283091           0
# 802       1303   803861    부산   Busan   16705        283091           0
# 807       1479   877689    부산   Busan   16447             0           0
# 808       1479     1479    부산   Busan   16447             0           0
# 835       2012  1041873    부산   Busan    4004             0           0
# 836       2002  1041873    부산   Busan    4004             0           0
# 1024      2500  1510168    부산   Busan     675             0           0
# 1025      2500  1509493    부산   Busan    1561             0           0
# 1049      2561  1572946    부산   Busan    3252             0           0
# 1050      2561  1569694    부산   Busan    3252             0           0
# 1091      2702  1716966    부산   Busan    5370             0           0
# 1092      2702  1734206    부산   Busan    5370             0           0
# 1153      2806  1820903    부산   Busan     174             0           0
# 1154         0  1820729    부산   Busan     553             0           0
# 1168      2814  1826959    부산   Busan     330             0           0
# 1169      2814  1827041    부산   Busan      82             0           0
#
#       localOccCnt  overFlowCnt   qurRate      stdDay
# 350            34            3     58.80  2021-01-04
# 351            34            3     58.82  2021-01-04
# 654            77            3    415.00  2021-11-03
# 655            77            3    415.00  2021-11-03
# 751          1916           11   1365.00  2022-02-07
# 752          1916           11   1307.00  2022-02-07
# 753          1916           11   1365.00  2022-02-07
# 785         22917            3  13038.00  2022-03-11
# 786         22917            3  13038.00  2022-03-11
# 797         24707            0  22160.00  2022-03-22
# 798             0        24707  22160.00  2022-03-22
# 801         16705            0  23993.00  2022-03-25
# 802             0        16705  23993.00  2022-03-25
# 807         16447            0  26197.00  2022-03-30
# 808         16447            0     44.00  2022-03-30
# 835          4004            0  31097.00  2022-04-26
# 836          4004            0  31097.00  2022-04-26
# 1024          674            1  45075.00  2022-10-31
# 1025         1561            0  45054.00  2022-10-31
# 1049         3251            1  46948.00  2022-11-24
# 1050         3251            1  46851.00  2022-11-24
# 1091         5370            0  51247.00  2023-01-04
# 1092         5370            0  51761.00  2023-01-04
# 1153          174            0  54883.00  2023-03-06
# 1154          553            0  54877.00  2023-03-06
# 1168          330            0  55065.00  2023-03-20
# 1169           82            0  55068.00  2023-03-20

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [350, 654, 751, 785, 797, 801, 807, 835, 1024, 1049, 1091, 1153, 1168]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 12
# 12
#       deathCnt   defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 1164      2811  1825932    부산   Busan     437             0           0
# 1165      2812  1826301    부산   Busan     369             0           0
# 1166      2812  1826629    부산   Busan     354             0           0
# 1167         0  1826959    부산   Busan     330             0           0
# 1168      2814  1826959    부산   Busan     330             0           0
# 1169      2814  1827041    부산   Busan      82             0           0
# 1170      2815  1827451    부산   Busan     410             0           0
# 1171      2815  1827878    부산   Busan     427             0           0
# 1172      2816  1828301    부산   Busan     423             0           0
# 1173      2816  1828614    부산   Busan     313             0           0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# 1164          437            0  55034.0  2023-03-16
# 1165          369            0  55045.0  2023-03-17
# 1166          354            0  55055.0  2023-03-18
# 1167          330            0  55065.0  2023-03-19
# 1168          330            0  55065.0  2023-03-20
# 1169           82            0  55068.0  2023-03-20
# 1170          409            1  55080.0  2023-03-21
# 1171          426            1  55093.0  2023-03-22
# 1172          422            1  55106.0  2023-03-23
# 1173          313            0  55115.0  2023-03-24

# %%
del_index = [351, 655, 751, 752, 786, 798, 802, 808, 836, 1025, 1050, 1091, 1154, 1168]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    부산   Busan       0             0           0
# 1         0       0    부산   Busan       0             0           0
# 2         0       0    부산   Busan       0             0           0
# 3         0       0    부산   Busan       0             0           0
# 4         0       0    부산   Busan       0             0           0
# 5         0       0    부산   Busan       0             0           0
# 6         0       0    부산   Busan       0             0           0
# 7         0       0    부산   Busan       0             0           0
# 8         0       0    부산   Busan       0             0           0
# 9         0       0    부산   Busan       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24
# 5            0            0      0.0  2020-01-25
# 6            0            0      0.0  2020-01-26
# 7            0            0      0.0  2020-01-27
# 8            0            0      0.0  2020-01-28
# 9            0            0      0.0  2020-01-29

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### stdDay가 같은 데이터

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df_final.duplicated(['stdDay'], keep = False).sum()) + '개')
df_final[df_final.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 check

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')

# %% [markdown]
# # 대구

# %%
city = '대구'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    대구   Daegu       0             0           0
# 1         0       0    대구   Daegu       0             0           0
# 2         0       0    대구   Daegu       0             0           0
# 3         0       0    대구   Daegu       0             0           0
# 4         0       0    대구   Daegu       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350       203    7924    대구   Daegu      29          7357         364
# 351       203    7924    대구   Daegu      29          7359         362
# 654       265   17307    대구   Daegu      66         16297         679
# 655       268   17307    대구   Daegu      66         16334         705
# 751       399   41756    대구   Daegu    1971         43726           0
# 752       399   43726    대구   Daegu    1971         30877           0
# 753       399   43726    대구   Daegu    1971         43726           0
# 785       587  230261    대구   Daegu   10307        136100           0
# 786       607  230261    대구   Daegu   10307        151483           0
# 797       783  392298    대구   Daegu   17360        259941           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350           29            0    325.22  2021-01-04
# 351           29            0    325.22  2021-01-04
# 654           66            0    716.00  2021-11-03
# 655           66            0    716.00  2021-11-03
# 751         1967            4   1750.00  2022-02-07
# 752         1967            4   1833.00  2022-02-07
# 753         1967            4   1833.00  2022-02-07
# 785        10307            0   9653.00  2022-03-11
# 786        10307            0   9653.00  2022-03-11
# 797            0        17360  16446.00  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 44개
#      deathCnt   defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 813       991   559685    대구   Daegu    3452             0           0
# 814       991   559685    대구   Daegu    3452             0           0
# 862      1310   747162    대구   Daegu    1316             0           0
# 863      1310   747162    대구   Daegu    1316             0           0
# 893      1343   768964    대구   Daegu     139             0           0
# 894      1343   768964    대구   Daegu     139             0           0
# 960      1430   967218    대구   Daegu    6307             0           0
# 961      1430   967218    대구   Daegu    6307             0           0
# 981      1579  1048878    대구   Daegu    5360             0           0
# 982      1579  1048878    대구   Daegu    5360             0           0
#
#      localOccCnt  overFlowCnt  qurRate      stdDay
# 813         3452            0  23463.0  2022-04-04
# 814         3452            0  23463.0  2022-04-04
# 862         1316            0  31322.0  2022-05-21
# 863         1316            0  31322.0  2022-05-21
# 893          137            2  32236.0  2022-06-20
# 894          137            2  32236.0  2022-06-20
# 960         6293           14  40547.0  2022-08-25
# 961         6293           14  40547.0  2022-08-25
# 981         5351            9  43971.0  2022-09-14
# 982         5351            9  43971.0  2022-09-14

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# 수정해야하는 데이터 개수 : 27개
#      deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350       203    7924    대구   Daegu      29          7357         364
# 351       203    7924    대구   Daegu      29          7359         362
# 654       265   17307    대구   Daegu      66         16297         679
# 655       268   17307    대구   Daegu      66         16334         705
# 751       399   41756    대구   Daegu    1971         43726           0
# 752       399   43726    대구   Daegu    1971         30877           0
# 753       399   43726    대구   Daegu    1971         43726           0
# 785       587  230261    대구   Daegu   10307        136100           0
# 786       607  230261    대구   Daegu   10307        151483           0
# 797       783  392298    대구   Daegu   17360        259941           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350           29            0    325.22  2021-01-04
# 351           29            0    325.22  2021-01-04
# 654           66            0    716.00  2021-11-03
# 655           66            0    716.00  2021-11-03
# 751         1967            4   1750.00  2022-02-07
# 752         1967            4   1833.00  2022-02-07
# 753         1967            4   1833.00  2022-02-07
# 785        10307            0   9653.00  2022-03-11
# 786        10307            0   9653.00  2022-03-11
# 797            0        17360  16446.00  2022-03-22

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [350, 654, 751, 785, 797, 801, 807, 835, 1024, 1049, 1091, 1153, 1168]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 12
# 12
#       deathCnt   defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 1164      1986  1341289    대구   Daegu     386             0           0
# 1165      1987  1341684    대구   Daegu     395             0           0
# 1166      1987  1342062    대구   Daegu     389             0           0
# 1167         0  1342491    대구   Daegu     429             0           0
# 1168      1989  1342603    대구   Daegu     112             0           0
# 1169      1989  1342491    대구   Daegu     429             0           0
# 1170      1989  1343138    대구   Daegu     535             0           0
# 1171      1989  1343638    대구   Daegu     500             0           0
# 1172      1989  1344037    대구   Daegu     399             0           0
# 1173      1989  1344437    대구   Daegu     400             0           0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# 1164          386            0  56746.0  2023-03-16
# 1165          394            1  56762.0  2023-03-17
# 1166          386            3  56778.0  2023-03-18
# 1167          426            3  56796.0  2023-03-19
# 1168          112            0  56801.0  2023-03-20
# 1169          426            3  56796.0  2023-03-20
# 1170          534            1  56824.0  2023-03-21
# 1171          499            1  56845.0  2023-03-22
# 1172          396            3  56862.0  2023-03-23
# 1173          400            0  56879.0  2023-03-24

# %%
del_index = [350, 654, 751, 753, 785, 797, 802, 807, 835, 1024, 1049, 1092, 1154, 1169]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    대구   Daegu       0             0           0
# 1         0       0    대구   Daegu       0             0           0
# 2         0       0    대구   Daegu       0             0           0
# 3         0       0    대구   Daegu       0             0           0
# 4         0       0    대구   Daegu       0             0           0
# 5         0       0    대구   Daegu       0             0           0
# 6         0       0    대구   Daegu       0             0           0
# 7         0       0    대구   Daegu       0             0           0
# 8         0       0    대구   Daegu       0             0           0
# 9         0       0    대구   Daegu       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24
# 5            0            0      0.0  2020-01-25
# 6            0            0      0.0  2020-01-26
# 7            0            0      0.0  2020-01-27
# 8            0            0      0.0  2020-01-28
# 9            0            0      0.0  2020-01-29

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 check

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')

# %% [markdown]
# # 인천

# %%
city = '인천'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       1    인천  Incheon       0             0           1
# 1         0       1    인천  Incheon       0             0           1
# 2         0       1    인천  Incheon       0             0           1
# 3         0       1    인천  Incheon       0             0           1
# 4         0       1    인천  Incheon       0             0           1
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            1      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350        30    3126    인천  Incheon     103          2249         847
# 351        30    3126    인천  Incheon     103          2249         847
# 654       109   19796    인천  Incheon     183         17742        1945
# 655       109   19796    인천  Incheon     183         17676        1828
# 751       342   62492    인천  Incheon    2376         64867           0
# 752       342   64867    인천  Incheon    2376         64867           0
# 753       342   64867    인천  Incheon    2376         42802           0
# 785       595  395433    인천  Incheon   17458        115210           0
# 786       577  395433    인천  Incheon   17458        103745           0
# 797       838  634945    인천  Incheon   17568        167661           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350          101            2    105.75  2021-01-04
# 351          101            2    105.75  2021-01-04
# 654          181            2    673.00  2021-11-03
# 655          181            2    673.00  2021-11-03
# 751         2366           10   2120.00  2022-02-07
# 752         2366           10   2200.00  2022-02-07
# 753         2366           10   2200.00  2022-02-07
# 785        17457            1  13412.00  2022-03-11
# 786        17457            1  13412.00  2022-03-11
# 797            1        17569  21535.00  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 46개
#      deathCnt   defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350        30     3126    인천  Incheon     103          2249         847
# 351        30     3126    인천  Incheon     103          2249         847
# 813      1094   864639    인천  Incheon    5545             0           0
# 814      1094   864639    인천  Incheon    5545             0           0
# 862      1383  1065504    인천  Incheon    1064             0           0
# 863      1383  1065504    인천  Incheon    1064             0           0
# 893      1405  1079315    인천  Incheon     222             0           0
# 894      1405  1079315    인천  Incheon     222             0           0
# 960      1468  1308817    인천  Incheon    5796             0           0
# 961      1468  1308817    인천  Incheon    5796             0           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350          101            2    105.75  2021-01-04
# 351          101            2    105.75  2021-01-04
# 813         5545            0  29326.00  2022-04-04
# 814         5545            0  29326.00  2022-04-04
# 862         1064            0  36139.00  2022-05-21
# 863         1064            0  36139.00  2022-05-21
# 893          188           34  36607.00  2022-06-20
# 894          188           34  36607.00  2022-06-20
# 960         5729           67  44391.00  2022-08-25
# 961         5729           67  44391.00  2022-08-25

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)][:]
# Out:
# 수정해야하는 데이터 개수 : 25개
#       deathCnt   defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 653        109    19796    인천  Incheon     183         17742        1945
# 654        109    19796    인천  Incheon     183         17676        1828
# 750        342    62492    인천  Incheon    2376         64867           0
# 751        342    64867    인천  Incheon    2376         64867           0
# 752        342    64867    인천  Incheon    2376         42802           0
# 784        595   395433    인천  Incheon   17458        115210           0
# 785        577   395433    인천  Incheon   17458        103745           0
# 796        838   634945    인천  Incheon   17568        167661           0
# 797        838   634945    인천  Incheon   17569        167661           0
# 800        903   706346    인천  Incheon   21773        190339           0
# 801        903   706346    인천  Incheon   21773        190339           0
# 806       1001   798508    인천  Incheon   23261             0           0
# 807       1001     1001    인천  Incheon   23261             0           0
# 834       1313  1021782    인천  Incheon    4282             0           0
# 835       1312  1021782    인천  Incheon    4282             0           0
# 1023      1564  1476151    인천  Incheon    1188             0           0
# 1024      1564  1474963    인천  Incheon    2209             0           0
# 1048      1619  1549974    인천  Incheon    3558             0           0
# 1049      1619  1546416    인천  Incheon    3558             0           0
# 1090      1759  1686864    인천  Incheon    4808             0           0
# 1091      1759  1701842    인천  Incheon    4808             0           0
# 1152         0  1775201    인천  Incheon     507             0           0
# 1153      1878  1775425    인천  Incheon     224             0           0
# 1167      1890  1782454    인천  Incheon     226             0           0
# 1168      1890  1782228    인천  Incheon     504             0           0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# 653           181            2    673.0  2021-11-03
# 654           181            2    673.0  2021-11-03
# 750          2366           10   2120.0  2022-02-07
# 751          2366           10   2200.0  2022-02-07
# 752          2366           10   2200.0  2022-02-07
# 784         17457            1  13412.0  2022-03-11
# 785         17457            1  13412.0  2022-03-11
# 796             1        17569  21535.0  2022-03-22
# 797         17568            1  21535.0  2022-03-22
# 800         21773            0  23957.0  2022-03-25
# 801             0        21773  23957.0  2022-03-25
# 806         23261            0  27083.0  2022-03-30
# 807         23261            0     34.0  2022-03-30
# 834          4282            0  34656.0  2022-04-26
# 835          4282            0  34656.0  2022-04-26
# 1023         1185            3  50067.0  2022-10-31
# 1024         2209            0  50026.0  2022-10-31
# 1048         3550            8  52570.0  2022-11-24
# 1049         3550            8  52450.0  2022-11-24
# 1090         4732           76  57213.0  2023-01-04
# 1091         4732           76  57721.0  2023-01-04
# 1152          507            0  59825.0  2023-03-06
# 1153          222            2  59833.0  2023-03-06
# 1167          222            4  60070.0  2023-03-20
# 1168          504            0  60062.0  2023-03-20

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [653, 750, 784, 796, 800, 806, 834, 1023, 1048, 1090, 1152, 1167]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 11
# 11
#       deathCnt   defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 1163      1889  1780892    인천  Incheon     528             0           0
# 1164      1890  1781380    인천  Incheon     488             0           0
# 1165      1890  1781724    인천  Incheon     473             0           0
# 1166         0  1782228    인천  Incheon     504             0           0
# 1167      1890  1782454    인천  Incheon     226             0           0
# 1168      1890  1782228    인천  Incheon     504             0           0
# 1169      1889  1783169    인천  Incheon     715             0           0
# 1170      1889  1783917    인천  Incheon     748             0           0
# 1171      1890  1784541    인천  Incheon     624             0           0
# 1172      1891  1785137    인천  Incheon     596             0           0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# 1163          525            3  60017.0  2023-03-16
# 1164          488            0  60033.0  2023-03-17
# 1165          472            1  60045.0  2023-03-18
# 1166          504            0  60062.0  2023-03-19
# 1167          222            4  60070.0  2023-03-20
# 1168          504            0  60062.0  2023-03-20
# 1169          714            1  60094.0  2023-03-21
# 1170          747            1  60119.0  2023-03-22
# 1171          621            3  60140.0  2023-03-23
# 1172          594            2  60160.0  2023-03-24

# %%
del_index = [654, 750, 751, 785, 796, 801, 807, 835, 1024, 1049, 1090, 1152, 1168]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       1    인천  Incheon       0             0           1
# 1         0       1    인천  Incheon       0             0           1
# 2         0       1    인천  Incheon       0             0           1
# 3         0       1    인천  Incheon       0             0           1
# 4         0       1    인천  Incheon       0             0           1
# 5         0       1    인천  Incheon       0             0           1
# 6         0       1    인천  Incheon       0             0           1
# 7         0       1    인천  Incheon       0             0           1
# 8         0       1    인천  Incheon       0             0           1
# 9         0       1    인천  Incheon       0             0           1
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            1      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24
# 5            0            0      0.0  2020-01-25
# 6            0            0      0.0  2020-01-26
# 7            0            0      0.0  2020-01-27
# 8            0            0      0.0  2020-01-28
# 9            0            0      0.0  2020-01-29

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### stdDay가 같은 데이터

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df_final.duplicated(['stdDay'], keep = False).sum()) + '개')
df_final[df_final.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 check

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')

# %% [markdown]
# # 광주

# %%
city = '광주'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    광주  Gwangju       0             0           0
# 1         0       0    광주  Gwangju       0             0           0
# 2         0       0    광주  Gwangju       0             0           0
# 3         0       0    광주  Gwangju       0             0           0
# 4         0       0    광주  Gwangju       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350         7    1211    광주  Gwangju      74           888         316
# 351         7    1211    광주  Gwangju      74           889         315
# 654        29    5405    광주  Gwangju      12          5274          90
# 655        29    5405    광주  Gwangju      12          5280          96
# 751        99   21288    광주  Gwangju    1209         11548           0
# 752        99   21288    광주  Gwangju    1209         21288           0
# 753        99   20079    광주  Gwangju    1209         21288           0
# 785       160  151646    광주  Gwangju    8848         14807           0
# 786       150  151646    광주  Gwangju    8848         14727           0
# 797       271  267168    광주  Gwangju    6985         15090           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350           74            0     83.13  2021-01-04
# 351           74            0     83.13  2021-01-04
# 654           11            1    373.00  2021-11-03
# 655           11            1    373.00  2021-11-03
# 751         1205            4   1477.00  2022-02-07
# 752         1205            4   1477.00  2022-02-07
# 753         1205            4   1393.00  2022-02-07
# 785         8836           12  10519.00  2022-03-11
# 786         8836           12  10519.00  2022-03-11
# 797            1         6986  18533.00  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 44개
#      deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 813       386  390095    광주  Gwangju    5801             0           0
# 814       386  390095    광주  Gwangju    5801             0           0
# 862       549  526562    광주  Gwangju     751             0           0
# 863       549  526562    광주  Gwangju     751             0           0
# 893       564  536126    광주  Gwangju     116             0           0
# 894       564  536126    광주  Gwangju     116             0           0
# 960       607  668865    광주  Gwangju    4140             0           0
# 961       607  668865    광주  Gwangju    4140             0           0
# 981       637  715090    광주  Gwangju    2532             0           0
# 982       637  715090    광주  Gwangju    2532             0           0
#
#      localOccCnt  overFlowCnt  qurRate      stdDay
# 813         5801            0  27060.0  2022-04-04
# 814         5801            0  27060.0  2022-04-04
# 862          749            2  36526.0  2022-05-21
# 863          749            2  36526.0  2022-05-21
# 893          107            9  37189.0  2022-06-20
# 894          107            9  37189.0  2022-06-20
# 960         4124           16  46397.0  2022-08-25
# 961         4124           16  46397.0  2022-08-25
# 981         2519           13  49604.0  2022-09-14
# 982         2519           13  49604.0  2022-09-14

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# 수정해야하는 데이터 개수 : 27개
#      deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350         7    1211    광주  Gwangju      74           888         316
# 351         7    1211    광주  Gwangju      74           889         315
# 654        29    5405    광주  Gwangju      12          5274          90
# 655        29    5405    광주  Gwangju      12          5280          96
# 751        99   21288    광주  Gwangju    1209         11548           0
# 752        99   21288    광주  Gwangju    1209         21288           0
# 753        99   20079    광주  Gwangju    1209         21288           0
# 785       160  151646    광주  Gwangju    8848         14807           0
# 786       150  151646    광주  Gwangju    8848         14727           0
# 797       271  267168    광주  Gwangju    6985         15090           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350           74            0     83.13  2021-01-04
# 351           74            0     83.13  2021-01-04
# 654           11            1    373.00  2021-11-03
# 655           11            1    373.00  2021-11-03
# 751         1205            4   1477.00  2022-02-07
# 752         1205            4   1477.00  2022-02-07
# 753         1205            4   1393.00  2022-02-07
# 785         8836           12  10519.00  2022-03-11
# 786         8836           12  10519.00  2022-03-11
# 797            1         6986  18533.00  2022-03-22

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [350, 654, 751, 785, 797, 801, 807, 835, 1024, 1049, 1091, 1153, 1168]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 12
# 12
#       deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 1164       818  893182    광주  Gwangju     268             0           0
# 1165       818  893415    광주  Gwangju     233             0           0
# 1166       818  893700    광주  Gwangju     285             0           0
# 1167         0  893946    광주  Gwangju     246             0           0
# 1168       818  894081    광주  Gwangju     135             0           0
# 1169       818  893946    광주  Gwangju     246             0           0
# 1170       818  894363    광주  Gwangju     282             0           0
# 1171       821  894772    광주  Gwangju     409             0           0
# 1172       821  895125    광주  Gwangju     353             0           0
# 1173       821  895395    광주  Gwangju     270             0           0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# 1164          268            0  62414.0  2023-03-16
# 1165          233            0  62431.0  2023-03-17
# 1166          285            0  62451.0  2023-03-18
# 1167          246            0  62468.0  2023-03-19
# 1168          135            0  62477.0  2023-03-20
# 1169          246            0  62468.0  2023-03-20
# 1170          282            0  62497.0  2023-03-21
# 1171          408            1  62526.0  2023-03-22
# 1172          353            0  62550.0  2023-03-23
# 1173          270            0  62569.0  2023-03-24

# %%
del_index = [350, 654, 752, 753, 786, 797, 801, 807, 836, 1024, 1050, 1091, 1154, 1169]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    광주  Gwangju       0             0           0
# 1         0       0    광주  Gwangju       0             0           0
# 2         0       0    광주  Gwangju       0             0           0
# 3         0       0    광주  Gwangju       0             0           0
# 4         0       0    광주  Gwangju       0             0           0
# 5         0       0    광주  Gwangju       0             0           0
# 6         0       0    광주  Gwangju       0             0           0
# 7         0       0    광주  Gwangju       0             0           0
# 8         0       0    광주  Gwangju       0             0           0
# 9         0       0    광주  Gwangju       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24
# 5            0            0      0.0  2020-01-25
# 6            0            0      0.0  2020-01-26
# 7            0            0      0.0  2020-01-27
# 8            0            0      0.0  2020-01-28
# 9            0            0      0.0  2020-01-29

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### stdDay가 같은 데이터

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df_final.duplicated(['stdDay'], keep = False).sum()) + '개')
df_final[df_final.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 check

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')

# %% [markdown]
# # 대전

# %%
city = '대전'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    대전  Daejeon       0             0           0
# 1         0       0    대전  Daejeon       0             0           0
# 2         0       0    대전  Daejeon       0             0           0
# 3         0       0    대전  Daejeon       0             0           0
# 4         0       0    대전  Daejeon       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350         7     874    대전  Daejeon       6           720         147
# 351         7     874    대전  Daejeon       6           725         142
# 654        55    7588    대전  Daejeon      19          7372         142
# 655        55    7588    대전  Daejeon      19          7392         141
# 751       199   22181    대전  Daejeon     969         13096           0
# 752       199   22181    대전  Daejeon     969         22181           0
# 753       199   21212    대전  Daejeon     969         22181           0
# 785       292  144788    대전  Daejeon    7212         34669           0
# 786       291  144788    대전  Daejeon    7212         34668           0
# 797       340  251780    대전  Daejeon    9873         59220           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350            6            0     59.29  2021-01-04
# 351            6            0     59.29  2021-01-04
# 654           19            0    518.00  2021-11-03
# 655           19            0    518.00  2021-11-03
# 751          968            1   1527.00  2022-02-07
# 752          968            1   1527.00  2022-02-07
# 753          968            1   1461.00  2022-02-07
# 785         7212            0   9970.00  2022-03-11
# 786         7212            0   9970.00  2022-03-11
# 797         9873            0  17337.00  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 46개
#      deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 813       447  371332    대전  Daejeon    4586             0           0
# 814       447  371332    대전  Daejeon    4586             0           0
# 836       612  472793    대전  Daejeon    2478             0           0
# 837       612  472793    대전  Daejeon    2478             0           0
# 862       682  504389    대전  Daejeon     743             0           0
# 863       682  504389    대전  Daejeon     743             0           0
# 893       706  515168    대전  Daejeon      91             0           0
# 894       706  515168    대전  Daejeon      91             0           0
# 960       757  652618    대전  Daejeon    3661             0           0
# 961       757  652618    대전  Daejeon    3661             0           0
#
#      localOccCnt  overFlowCnt  qurRate      stdDay
# 813         4586            0  25569.0  2022-04-04
# 814         4586            0  25569.0  2022-04-04
# 836         2477            1  32556.0  2022-04-26
# 837         2477            1  32556.0  2022-04-26
# 862          743            0  34732.0  2022-05-21
# 863          743            0  34732.0  2022-05-21
# 893           87            4  35474.0  2022-06-20
# 894           87            4  35474.0  2022-06-20
# 960         3645           16  44938.0  2022-08-25
# 961         3645           16  44938.0  2022-08-25

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)][:]
# Out:
# 수정해야하는 데이터 개수 : 25개
#       deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350          7     874    대전  Daejeon       6           720         147
# 351          7     874    대전  Daejeon       6           725         142
# 654         55    7588    대전  Daejeon      19          7372         142
# 655         55    7588    대전  Daejeon      19          7392         141
# 751        199   22181    대전  Daejeon     969         13096           0
# 752        199   22181    대전  Daejeon     969         22181           0
# 753        199   21212    대전  Daejeon     969         22181           0
# 785        292  144788    대전  Daejeon    7212         34669           0
# 786        291  144788    대전  Daejeon    7212         34668           0
# 797        340  251780    대전  Daejeon    9873         59220           0
# 798        340  251780    대전  Daejeon    9873         59220           0
# 801        372  285834    대전  Daejeon    8258        118864           0
# 802        372  285834    대전  Daejeon    8258        118864           0
# 807        409     409    대전  Daejeon   11252             0           0
# 808        409  333638    대전  Daejeon   11252             0           0
# 1023       796  740552    대전  Daejeon    1035             0           0
# 1024       798  741125    대전  Daejeon     573             0           0
# 1048       831  781223    대전  Daejeon    1878             0           0
# 1049       831  779345    대전  Daejeon    1878             0           0
# 1090       892  855569    대전  Daejeon    2191             0           0
# 1091       892  848620    대전  Daejeon    2191             0           0
# 1152       939  890729    대전  Daejeon     122             0           0
# 1153         0  890607    대전  Daejeon     304             0           0
# 1167       943  895066    대전  Daejeon     142             0           0
# 1168       943  894924    대전  Daejeon     269             0           0
#
#       localOccCnt  overFlowCnt   qurRate      stdDay
# 350             6            0     59.29  2021-01-04
# 351             6            0     59.29  2021-01-04
# 654            19            0    518.00  2021-11-03
# 655            19            0    518.00  2021-11-03
# 751           968            1   1527.00  2022-02-07
# 752           968            1   1527.00  2022-02-07
# 753           968            1   1461.00  2022-02-07
# 785          7212            0   9970.00  2022-03-11
# 786          7212            0   9970.00  2022-03-11
# 797          9873            0  17337.00  2022-03-22
# 798             0         9873  17337.00  2022-03-22
# 801             0         8258  19682.00  2022-03-25
# 802          8258            0  19682.00  2022-03-25
# 807         11252            0     28.00  2022-03-30
# 808         11252            0  22974.00  2022-03-30
# 1023         1033            2  50993.00  2022-10-31
# 1024          570            3  51033.00  2022-10-31
# 1048         1878            0  53794.00  2022-11-24
# 1049         1878            0  53665.00  2022-11-24
# 1090         2138           53  58913.00  2023-01-04
# 1091         2138           53  58435.00  2023-01-04
# 1152          122            0  61596.00  2023-03-06
# 1153          304            0  61588.00  2023-03-06
# 1167          142            0  61896.00  2023-03-20
# 1168          268            1  61887.00  2023-03-20

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [350, 654, 751, 785, 797, 801, 807, 1023, 1048, 1090, 1152, 1167]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 11
# 11
#       deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 1163       943  894036    대전  Daejeon     323             0           0
# 1164       943  894336    대전  Daejeon     300             0           0
# 1165       943  894655    대전  Daejeon     325             0           0
# 1166         0  894924    대전  Daejeon     269             0           0
# 1167       943  895066    대전  Daejeon     142             0           0
# 1168       943  894924    대전  Daejeon     269             0           0
# 1169       943  895546    대전  Daejeon     480             0           0
# 1170       944  895965    대전  Daejeon     419             0           0
# 1171       944  896356    대전  Daejeon     391             0           0
# 1172       944  896781    대전  Daejeon     425             0           0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# 1163          323            0  61825.0  2023-03-16
# 1164          300            0  61846.0  2023-03-17
# 1165          325            0  61868.0  2023-03-18
# 1166          268            1  61887.0  2023-03-19
# 1167          142            0  61896.0  2023-03-20
# 1168          268            1  61887.0  2023-03-20
# 1169          480            0  61930.0  2023-03-21
# 1170          418            1  61959.0  2023-03-22
# 1171          391            0  61986.0  2023-03-23
# 1172          425            0  62015.0  2023-03-24

# %%
del_index = [351, 654, 752, 753, 786, 798, 801, 807, 1023, 1049, 1091, 1153, 1168]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun  gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    대전  Daejeon       0             0           0
# 1         0       0    대전  Daejeon       0             0           0
# 2         0       0    대전  Daejeon       0             0           0
# 3         0       0    대전  Daejeon       0             0           0
# 4         0       0    대전  Daejeon       0             0           0
# 5         0       0    대전  Daejeon       0             0           0
# 6         0       0    대전  Daejeon       0             0           0
# 7         0       0    대전  Daejeon       0             0           0
# 8         0       0    대전  Daejeon       0             0           0
# 9         0       0    대전  Daejeon       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24
# 5            0            0      0.0  2020-01-25
# 6            0            0      0.0  2020-01-26
# 7            0            0      0.0  2020-01-27
# 8            0            0      0.0  2020-01-28
# 9            0            0      0.0  2020-01-29

# %% [markdown]
# ##### 2022-02-07 isoClearCnt 값이 이상함

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### stdDay가 같은 데이터

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df_final.duplicated(['stdDay'], keep = False).sum()) + '개')
df_final[df_final.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 check

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')

# %% [markdown]
# # 울산

# %%
city = '울산'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    울산   Ulsan       0             0           0
# 1         0       0    울산   Ulsan       0             0           0
# 2         0       0    울산   Ulsan       0             0           0
# 3         0       0    울산   Ulsan       0             0           0
# 4         0       0    울산   Ulsan       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350        30     745    울산   Ulsan       5           498         217
# 351        30     745    울산   Ulsan       5           498         217
# 654        56    5447    울산   Ulsan       7          5331          60
# 655        56    5447    울산   Ulsan       7          5329          55
# 751        66   11999    울산   Ulsan     593          8152           0
# 752        66   11406    울산   Ulsan     593         11999           0
# 753        66   11999    울산   Ulsan     593         11999           0
# 785       113  106586    울산   Ulsan    5261         57385           0
# 786       118  106586    울산   Ulsan    5261         57384           0
# 797       188  199065    울산   Ulsan    8224        140460           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350            5            0     64.95  2021-01-04
# 351            5            0     64.95  2021-01-04
# 654            6            1    479.00  2021-11-03
# 655            6            1    479.00  2021-11-03
# 751          592            1   1070.00  2022-02-07
# 752          592            1   1017.00  2022-02-07
# 753          592            1   1070.00  2022-02-07
# 785         5261            0   9503.00  2022-03-11
# 786         5261            0   9503.00  2022-03-11
# 797            0         8224  17748.00  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 48개
#      deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350        30     745    울산   Ulsan       5           498         217
# 351        30     745    울산   Ulsan       5           498         217
# 813       268  285853    울산   Ulsan    2481             0           0
# 814       268  285853    울산   Ulsan    2481             0           0
# 836       322  349482    울산   Ulsan    1753             0           0
# 837       322  349482    울산   Ulsan    1753             0           0
# 862       336  372720    울산   Ulsan     626             0           0
# 863       336  372720    울산   Ulsan     626             0           0
# 893       342  383183    울산   Ulsan     115             0           0
# 894       342  383183    울산   Ulsan     115             0           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350            5            0     64.95  2021-01-04
# 351            5            0     64.95  2021-01-04
# 813         2481            0  25486.00  2022-04-04
# 814         2481            0  25486.00  2022-04-04
# 836         1753            0  31159.00  2022-04-26
# 837         1753            0  31159.00  2022-04-26
# 862          626            0  33231.00  2022-05-21
# 863          626            0  33231.00  2022-05-21
# 893          115            0  34164.00  2022-06-20
# 894          115            0  34164.00  2022-06-20

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)][:]
# Out:
# 수정해야하는 데이터 개수 : 23개
#       deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 653         56    5447    울산   Ulsan       7          5331          60
# 654         56    5447    울산   Ulsan       7          5329          55
# 750         66   11999    울산   Ulsan     593          8152           0
# 751         66   11406    울산   Ulsan     593         11999           0
# 752         66   11999    울산   Ulsan     593         11999           0
# 784        113  106586    울산   Ulsan    5261         57385           0
# 785        118  106586    울산   Ulsan    5261         57384           0
# 796        188  199065    울산   Ulsan    8224        140460           0
# 797        188  199065    울산   Ulsan    8224        140460           0
# 800        210  225881    울산   Ulsan    7433        167090           0
# 801        210  225881    울산   Ulsan    7433        167090           0
# 806        236     236    울산   Ulsan    9094             0           0
# 807        236  260612    울산   Ulsan    9094             0           0
# 1022       431  547135    울산   Ulsan     637             0           0
# 1023       431  547531    울산   Ulsan     396             0           0
# 1047       462  570154    울산   Ulsan    1117             0           0
# 1048       462  569037    울산   Ulsan    1117             0           0
# 1089       503  624027    울산   Ulsan    2182             0           0
# 1090       503  618200    울산   Ulsan    2182             0           0
# 1151       529  655551    울산   Ulsan      49             0           0
# 1152         0  655502    울산   Ulsan     198             0           0
# 1166       531  657448    울산   Ulsan      94             0           0
# 1167       531  657491    울산   Ulsan      43             0           0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# 653             6            1    479.0  2021-11-03
# 654             6            1    479.0  2021-11-03
# 750           592            1   1070.0  2022-02-07
# 751           592            1   1017.0  2022-02-07
# 752           592            1   1070.0  2022-02-07
# 784          5261            0   9503.0  2022-03-11
# 785          5261            0   9503.0  2022-03-11
# 796             0         8224  17748.0  2022-03-22
# 797          8224            0  17748.0  2022-03-22
# 800          7433            0  20139.0  2022-03-25
# 801             0         7433  20139.0  2022-03-25
# 806          9094            0     21.0  2022-03-30
# 807          9094            0  23236.0  2022-03-30
# 1022          636            1  48782.0  2022-10-31
# 1023          395            1  48817.0  2022-10-31
# 1047         1117            0  50834.0  2022-11-24
# 1048         1117            0  50735.0  2022-11-24
# 1089         2180            2  55638.0  2023-01-04
# 1090         2180            2  55118.0  2023-01-04
# 1151           49            0  59023.0  2023-03-06
# 1152          198            0  59019.0  2023-03-06
# 1166           93            1  59194.0  2023-03-20
# 1167           43            0  59198.0  2023-03-20

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [653, 750, 784, 796, 800, 806, 1022, 1047, 1089, 1151, 1166]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 10
# 10
#       deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 1162       531  657128    울산   Ulsan     148             0           0
# 1163       531  657244    울산   Ulsan     116             0           0
# 1164       531  657354    울산   Ulsan     110             0           0
# 1165         0  657448    울산   Ulsan      94             0           0
# 1166       531  657448    울산   Ulsan      94             0           0
# 1167       531  657491    울산   Ulsan      43             0           0
# 1168       531  657610    울산   Ulsan     119             0           0
# 1169       531  657763    울산   Ulsan     153             0           0
# 1170       531  657881    울산   Ulsan     118             0           0
# 1171       531  658005    울산   Ulsan     124             0           0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# 1162          148            0  59165.0  2023-03-16
# 1163          115            1  59176.0  2023-03-17
# 1164          110            0  59186.0  2023-03-18
# 1165           93            1  59194.0  2023-03-19
# 1166           93            1  59194.0  2023-03-20
# 1167           43            0  59198.0  2023-03-20
# 1168          119            0  59209.0  2023-03-21
# 1169          153            0  59223.0  2023-03-22
# 1170          118            0  59233.0  2023-03-23
# 1171          123            1  59244.0  2023-03-24

# %%
del_index = [654, 751, 752, 784, 796, 801, 806, 1022, 1048, 1090, 1152, 1166]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    울산   Ulsan       0             0           0
# 1         0       0    울산   Ulsan       0             0           0
# 2         0       0    울산   Ulsan       0             0           0
# 3         0       0    울산   Ulsan       0             0           0
# 4         0       0    울산   Ulsan       0             0           0
# 5         0       0    울산   Ulsan       0             0           0
# 6         0       0    울산   Ulsan       0             0           0
# 7         0       0    울산   Ulsan       0             0           0
# 8         0       0    울산   Ulsan       0             0           0
# 9         0       0    울산   Ulsan       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24
# 5            0            0      0.0  2020-01-25
# 6            0            0      0.0  2020-01-26
# 7            0            0      0.0  2020-01-27
# 8            0            0      0.0  2020-01-28
# 9            0            0      0.0  2020-01-29

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### stdDay가 같은 데이터

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df_final.duplicated(['stdDay'], keep = False).sum()) + '개')
df_final[df_final.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 check

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')

# %% [markdown]
# # 세종

# %%
city = '세종'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0     0.0    세종  Sejong     0.0             0         0.0
# 1         0     0.0    세종  Sejong     0.0             0         0.0
# 2         0     0.0    세종  Sejong     0.0             0         0.0
# 3         0     0.0    세종  Sejong     0.0             0         0.0
# 4         0     0.0    세종  Sejong     0.0             0         0.0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt   defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350         1    154.0    세종  Sejong     0.0           132        21.0
# 351         1    154.0    세종  Sejong     0.0           132        21.0
# 654         2   1373.0    세종  Sejong     1.0          1345        25.0
# 655         2   1373.0    세종  Sejong     1.0          1346        25.0
# 751         4   4189.0    세종  Sejong   262.0          4451         0.0
# 752         4   4451.0    세종  Sejong   262.0          4451         0.0
# 753         4   4451.0    세종  Sejong   262.0          2804         0.0
# 785         6  33965.0    세종  Sejong  1840.0         19962         0.0
# 786         6  33965.0    세종  Sejong  1840.0         19962         0.0
# 797        14  64613.0    세종  Sejong  3334.0         42724         0.0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350            0            0     44.99  2021-01-04
# 351            0            0     44.99  2021-01-04
# 654            1            0    386.00  2021-11-03
# 655            1            0    386.00  2021-11-03
# 751          261            1   1126.00  2022-02-07
# 752          261            1   1197.00  2022-02-07
# 753          261            1   1197.00  2022-02-07
# 785         1840            0   9133.00  2022-03-11
# 786         1840            0   9133.00  2022-03-11
# 797         3334            0  17374.00  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 50개
#      deathCnt    defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350         1     154.0    세종  Sejong     0.0           132        21.0
# 351         1     154.0    세종  Sejong     0.0           132        21.0
# 785         6   33965.0    세종  Sejong  1840.0         19962         0.0
# 786         6   33965.0    세종  Sejong  1840.0         19962         0.0
# 813        29  102167.0    세종  Sejong  1630.0             0         0.0
# 814        29  102167.0    세종  Sejong  1630.0             0         0.0
# 836        34  128936.0    세종  Sejong   666.0             0         0.0
# 837        34  128936.0    세종  Sejong   666.0             0         0.0
# 862        35  136806.0    세종  Sejong   209.0             0         0.0
# 863        35  136806.0    세종  Sejong   209.0             0         0.0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350            0            0     44.99  2021-01-04
# 351            0            0     44.99  2021-01-04
# 785         1840            0   9133.00  2022-03-11
# 786         1840            0   9133.00  2022-03-11
# 813         1630            0  27472.00  2022-04-04
# 814         1630            0  27472.00  2022-04-04
# 836          666            0  34670.00  2022-04-26
# 837          666            0  34670.00  2022-04-26
# 862          209            0  36786.00  2022-05-21
# 863          209            0  36786.00  2022-05-21

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)][:]
# Out:
# 수정해야하는 데이터 개수 : 21개
#       deathCnt    defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 653          2    1373.0    세종  Sejong     1.0          1345        25.0
# 654          2    1373.0    세종  Sejong     1.0          1346        25.0
# 750          4    4189.0    세종  Sejong   262.0          4451         0.0
# 751          4    4451.0    세종  Sejong   262.0          4451         0.0
# 752          4    4451.0    세종  Sejong   262.0          2804         0.0
# 795         14   64613.0    세종  Sejong  3334.0         42724         0.0
# 796         14   64613.0    세종  Sejong  3334.0         42724         0.0
# 799         18   75297.0    세종  Sejong  3486.0         52514         0.0
# 800         18   75297.0    세종  Sejong  3486.0         52514         0.0
# 805         21   89587.0    세종  Sejong  4248.0             0         0.0
# 806         21      21.0    세종  Sejong  4248.0             0         0.0
# 1021        45  200511.0    세종  Sejong   329.0             0         0.0
# 1022        45  200690.0    세종  Sejong   179.0             0         0.0
# 1046        48  210871.0    세종  Sejong   424.0             0         0.0
# 1047        48  211295.0    세종  Sejong   424.0             0         0.0
# 1088        50  230222.0    세종  Sejong   623.0             0         0.0
# 1089        50  232236.0    세종  Sejong   623.0             0         0.0
# 1150         0  242028.0    세종  Sejong    65.0             0         0.0
# 1151        56  242080.0    세종  Sejong    52.0             0         0.0
# 1165        56  243382.0    세종  Sejong    99.0             0         0.0
# 1166        56  243412.0    세종  Sejong    30.0             0         0.0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# 653             1            0    386.0  2021-11-03
# 654             1            0    386.0  2021-11-03
# 750           261            1   1126.0  2022-02-07
# 751           261            1   1197.0  2022-02-07
# 752           261            1   1197.0  2022-02-07
# 795          3334            0  17374.0  2022-03-22
# 796             0         3334  17374.0  2022-03-22
# 799          3486            0  20247.0  2022-03-25
# 800             0         3486  20247.0  2022-03-25
# 805          4248            0  24089.0  2022-03-30
# 806          4248            0      6.0  2022-03-30
# 1021          328            1  53916.0  2022-10-31
# 1022          179            0  53964.0  2022-10-31
# 1046          424            0  56702.0  2022-11-24
# 1047          424            0  56816.0  2022-11-24
# 1088          622            1  61905.0  2023-01-04
# 1089          622            1  62447.0  2023-01-04
# 1150           65            0  63095.0  2023-03-06
# 1151           52            0  63109.0  2023-03-06
# 1165           99            0  63448.0  2023-03-20
# 1166           30            0  63456.0  2023-03-20

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [653, 750, 795, 799, 805, 1021, 1046, 1088, 1150, 1165]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 9
# 9
#       deathCnt    defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 1161        56  243088.0    세종  Sejong    86.0             0         0.0
# 1162        56  243174.0    세종  Sejong    86.0             0         0.0
# 1163        56  243283.0    세종  Sejong   109.0             0         0.0
# 1164         0  243382.0    세종  Sejong    99.0             0         0.0
# 1165        56  243382.0    세종  Sejong    99.0             0         0.0
# 1166        56  243412.0    세종  Sejong    30.0             0         0.0
# 1167        56  243564.0    세종  Sejong   152.0             0         0.0
# 1168        56  243701.0    세종  Sejong   137.0             0         0.0
# 1169        56  243822.0    세종  Sejong   121.0             0         0.0
# 1170        56  243963.0    세종  Sejong   141.0             0         0.0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# 1161           86            0  63372.0  2023-03-16
# 1162           86            0  63394.0  2023-03-17
# 1163          109            0  63422.0  2023-03-18
# 1164           99            0  63448.0  2023-03-19
# 1165           99            0  63448.0  2023-03-20
# 1166           30            0  63456.0  2023-03-20
# 1167          152            0  63496.0  2023-03-21
# 1168          137            0  63531.0  2023-03-22
# 1169          121            0  63563.0  2023-03-23
# 1170          141            0  63600.0  2023-03-24

# %%
del_index = [653, 750, 751, 796, 800, 806, 1021, 1046, 1088, 1150, 1165]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0     0.0    세종  Sejong     0.0             0         0.0
# 1         0     0.0    세종  Sejong     0.0             0         0.0
# 2         0     0.0    세종  Sejong     0.0             0         0.0
# 3         0     0.0    세종  Sejong     0.0             0         0.0
# 4         0     0.0    세종  Sejong     0.0             0         0.0
# 5         0     0.0    세종  Sejong     0.0             0         0.0
# 6         0     0.0    세종  Sejong     0.0             0         0.0
# 7         0     0.0    세종  Sejong     0.0             0         0.0
# 8         0     0.0    세종  Sejong     0.0             0         0.0
# 9         0     0.0    세종  Sejong     0.0             0         0.0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24
# 5            0            0      0.0  2020-01-25
# 6            0            0      0.0  2020-01-26
# 7            0            0      0.0  2020-01-27
# 8            0            0      0.0  2020-01-28
# 9            0            0      0.0  2020-01-29

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### stdDay가 같은 데이터

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df_final.duplicated(['stdDay'], keep = False).sum()) + '개')
df_final[df_final.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 check

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
#      deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 590         1   100.3    세종  Sejong  -892.7             0        99.3
#
#      localOccCnt  overFlowCnt  qurRate      stdDay
# 590           10            0    28.19  2021-09-01

# %%
df_final.iloc[586: 596]
# Out:
#      deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 586         1   975.0    세종  Sejong    12.0           877        97.0
# 587         1   977.0    세종  Sejong     2.0           883        93.0
# 588         1   985.0    세종  Sejong     8.0           888        96.0
# 589         1   993.0    세종  Sejong     8.0           891       101.0
# 590         1   100.3    세종  Sejong  -892.7             0        99.3
# 591         1  1010.0    세종  Sejong   909.7           906       103.0
# 592         1  1014.0    세종  Sejong     4.0           915        98.0
# 593         1  1022.0    세종  Sejong     8.0           937        84.0
# 594         1  1025.0    세종  Sejong     3.0           949        75.0
# 595         1  1029.0    세종  Sejong     4.0           952        76.0
#
#      localOccCnt  overFlowCnt  qurRate      stdDay
# 586           12            0   274.01  2021-08-28
# 587            2            0   274.57  2021-08-29
# 588            8            0   276.82  2021-08-30
# 589            8            0   279.07  2021-08-31
# 590           10            0    28.19  2021-09-01
# 591            7            0   283.84  2021-09-02
# 592            4            0   284.97  2021-09-03
# 593            8            0   287.21  2021-09-04
# 594            3            0   288.06  2021-09-05
# 595            4            0   289.18  2021-09-06

# %%
df_final.loc[590, ['defCnt', 'incDec']] = [1003, 10]
df_final.loc[591, 'incDec'] = 7
df_final.iloc[589:593]
# Out:
#      deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 589         1   993.0    세종  Sejong     8.0           891       101.0
# 590         1  1003.0    세종  Sejong    10.0             0        99.3
# 591         1  1010.0    세종  Sejong     7.0           906       103.0
# 592         1  1014.0    세종  Sejong     4.0           915        98.0
#
#      localOccCnt  overFlowCnt  qurRate      stdDay
# 589            8            0   279.07  2021-08-31
# 590           10            0    28.19  2021-09-01
# 591            7            0   283.84  2021-09-02
# 592            4            0   284.97  2021-09-03

# %% [markdown]
# ##### 2021-09-01 defCnt 값이 1003인데 100.3으로 오기입 된 것으로 판단
# => 데이터를 저장할 때 defCnt를 입력하고 차분하여 incDec를 구하여서 -892.7, 909.7이 나온 것으로 판단
# => 데이터를 수정

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')

# %% [markdown]
# # 경기

# %%
city = '경기'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun      gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    경기  Gyeonggi-do       0             0           0
# 1         0       0    경기  Gyeonggi-do       0             0           0
# 2         0       0    경기  Gyeonggi-do       0             0           0
# 3         0       0    경기  Gyeonggi-do       0             0           0
# 4         0       0    경기  Gyeonggi-do       0             0           0
#
#    localOccCnt  overFlowCnt qurRate      stdDay
# 0            0            0    0.00  2020-01-20
# 1            0            0    0.00  2020-01-21
# 2            0            0    0.00  2020-01-22
# 3            0            0    0.00  2020-01-23
# 4            0            0    0.00  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt   defCnt gubun      gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350       292    15434    경기  Gyeonggi-do     268         11190        3952
# 351       292    15433    경기  Gyeonggi-do     268         11181        3960
# 654       939   110427    경기  Gyeonggi-do     899        100173        8416
# 655       946   110427    경기  Gyeonggi-do     899        100698        8783
# 751      2195   316684    경기  Gyeonggi-do    9805        316684           0
# 752      2195   306879    경기  Gyeonggi-do    9805        316684           0
# 753      2195   316684    경기  Gyeonggi-do    9805        173276           0
# 785      2837  1675373    경기  Gyeonggi-do   72427        233464           0
# 786      2883  1675373    경기  Gyeonggi-do   72427        233813           0
# 797      3609  2788761    경기  Gyeonggi-do   96256        439083           0
#
#      localOccCnt  overFlowCnt qurRate      stdDay
# 350          260            8  116.48  2021-01-04
# 351          260            8  116.47  2021-01-04
# 654          895            4     822  2021-11-03
# 655          895            4     822  2021-11-03
# 751         9780           25    2334  2022-02-07
# 752         9780           25    2262  2022-02-07
# 753         9780           25    2334  2022-02-07
# 785        72420            7   12350  2022-03-11
# 786        72420            7   12350  2022-03-11
# 797            1        96257   20558  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 42개
#      deathCnt   defCnt gubun      gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 813      4588  3883961    경기  Gyeonggi-do   36937             0           0
# 814      4588  3883961    경기  Gyeonggi-do   36937             0           0
# 862      6174  4887196    경기  Gyeonggi-do    5693             0           0
# 863      6174  4887196    경기  Gyeonggi-do    5693             0           0
# 893      6255  4965875    경기  Gyeonggi-do     886             0           0
# 894      6255  4965875    경기  Gyeonggi-do     886             0           0
# 960      6715  6109867    경기  Gyeonggi-do   27032             0           0
# 961      6715  6109867    경기  Gyeonggi-do   27032             0           0
# 981      6963  6495551    경기  Gyeonggi-do   26133             0           0
# 982      6963  6495551    경기  Gyeonggi-do   26133             0           0
#
#      localOccCnt  overFlowCnt qurRate      stdDay
# 813        36937            0   28631  2022-04-04
# 814        36937            0   28631  2022-04-04
# 862         5693            0   36027  2022-05-21
# 863         5693            0   36027  2022-05-21
# 893          884            2   36607  2022-06-20
# 894          884            2   36607  2022-06-20
# 960        27007           25   45040  2022-08-25
# 961        27007           25   45040  2022-08-25
# 981        26110           23   47883  2022-09-14
# 982        26110           23   47883  2022-09-14

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)][:]
# Out:
# 수정해야하는 데이터 개수 : 29개
#       deathCnt   defCnt gubun      gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350        292    15434    경기  Gyeonggi-do     268         11190        3952
# 351        292    15433    경기  Gyeonggi-do     268         11181        3960
# 654        939   110427    경기  Gyeonggi-do     899        100173        8416
# 655        946   110427    경기  Gyeonggi-do     899        100698        8783
# 751       2195   316684    경기  Gyeonggi-do    9805        316684           0
# 752       2195   306879    경기  Gyeonggi-do    9805        316684           0
# 753       2195   316684    경기  Gyeonggi-do    9805        173276           0
# 785       2837  1675373    경기  Gyeonggi-do   72427        233464           0
# 786       2883  1675373    경기  Gyeonggi-do   72427        233813           0
# 797       3609  2788761    경기  Gyeonggi-do   96256        439083           0
# 798       3609  2788761    경기  Gyeonggi-do   96257        439083           0
# 801       3883  3120770    경기  Gyeonggi-do   87705        439984           0
# 802       3883  3120770    경기  Gyeonggi-do   87703        439984           0
# 807       4256     4256    경기  Gyeonggi-do  117029             0           0
# 808       4256  3553139    경기  Gyeonggi-do  117029             0           0
# 835       5736  4665892    경기  Gyeonggi-do   19363             0           0
# 836       5757  4665892    경기  Gyeonggi-do   19363             0           0
# 1024      7297  6881862    경기  Gyeonggi-do    5938             0           0
# 1025      7296  6875924    경기  Gyeonggi-do    9691             0           0
# 1049      7547  7234734    경기  Gyeonggi-do   16473             0           0
# 1050      7547  7218261    경기  Gyeonggi-do   16473             0           0
# 1091      8008  7868406    경기  Gyeonggi-do   20975             0           0
# 1092      8008  7934066    경기  Gyeonggi-do   20975             0           0
# 1100      8092  8041231    경기  Gyeonggi-do   11606             0           0
# 1101      8097  8041231    경기  Gyeonggi-do   11606             0           0
# 1154      8328  8260922    경기  Gyeonggi-do    1299             0           0
# 1155         0  8259623    경기  Gyeonggi-do    2607             0           0
# 1169      8349  8298093    경기  Gyeonggi-do    1206             0           0
# 1170      8349  8296887    경기  Gyeonggi-do    2454             0           0
#
#       localOccCnt  overFlowCnt qurRate      stdDay
# 350           260            8  116.48  2021-01-04
# 351           260            8  116.47  2021-01-04
# 654           895            4     822  2021-11-03
# 655           895            4     822  2021-11-03
# 751          9780           25    2334  2022-02-07
# 752          9780           25    2262  2022-02-07
# 753          9780           25    2334  2022-02-07
# 785         72420            7   12350  2022-03-11
# 786         72420            7   12350  2022-03-11
# 797             1        96257   20558  2022-03-22
# 798         96256            1   20558  2022-03-22
# 801         87703            2   23005  2022-03-25
# 802             2        87705   23005  2022-03-25
# 807        117029            0      31  2022-03-30
# 808        117029            0   26193  2022-03-30
# 835         19362            1   34395  2022-04-26
# 836         19362            1   34395  2022-04-26
# 1024         5933            5   50731  2022-10-31
# 1025         9688            3   50687  2022-10-31
# 1049        16468            5   53332  2022-11-24
# 1050        16468            5   53211  2022-11-24
# 1091        20974            1   58003  2023-01-04
# 1092        20974            1   58487  2023-01-04
# 1100        11600            6   59277  2023-01-12
# 1101        11600            6   59277  2023-01-12
# 1154         1299            0   60789  2023-03-06
# 1155         2604            3   60780  2023-03-06
# 1169         1206            0   61063  2023-03-20
# 1170         2453            1   61054  2023-03-20

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [350, 654, 751, 785, 797, 801, 807, 835, 1024, 1049, 1091, 1100, 1154, 1169]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 13
# 13
#       deathCnt   defCnt gubun      gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 1165      8346  8289348    경기  Gyeonggi-do    2776             0           0
# 1166      8346  8291839    경기  Gyeonggi-do    2491             0           0
# 1167      8347  8294433    경기  Gyeonggi-do    2637             0           0
# 1168         0  8296887    경기  Gyeonggi-do    2454             0           0
# 1169      8349  8298093    경기  Gyeonggi-do    1206             0           0
# 1170      8349  8296887    경기  Gyeonggi-do    2454             0           0
# 1171      8351  8301571    경기  Gyeonggi-do    3478             0           0
# 1172      8351  8305416    경기  Gyeonggi-do    3845             0           0
# 1173      8354  8308732    경기  Gyeonggi-do    3316             0           0
# 1174      8357  8311777    경기  Gyeonggi-do    3045             0           0
#
#       localOccCnt  overFlowCnt qurRate      stdDay
# 1165         2774            2   60998  2023-03-16
# 1166         2491            0   61017  2023-03-17
# 1167         2633            4   61036  2023-03-18
# 1168         2453            1   61054  2023-03-19
# 1169         1206            0   61063  2023-03-20
# 1170         2453            1   61054  2023-03-20
# 1171         3476            2   61088  2023-03-21
# 1172         3838            7   61117  2023-03-22
# 1173         3311            5   61141  2023-03-23
# 1174         3045            0   61164  2023-03-24

# %%
del_index = [351, 654, 751, 752, 785, 797, 802, 807, 835, 1025, 1050, 1091, 1101, 1155, 1170]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun      gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    경기  Gyeonggi-do       0             0           0
# 1         0       0    경기  Gyeonggi-do       0             0           0
# 2         0       0    경기  Gyeonggi-do       0             0           0
# 3         0       0    경기  Gyeonggi-do       0             0           0
# 4         0       0    경기  Gyeonggi-do       0             0           0
# 5         0       0    경기  Gyeonggi-do       0             0           0
# 6         0       1    경기  Gyeonggi-do       1             0           1
# 7         0       2    경기  Gyeonggi-do       1             0           2
# 8         0       2    경기  Gyeonggi-do       0             0           2
# 9         0       2    경기  Gyeonggi-do       0             0           2
#
#    localOccCnt  overFlowCnt qurRate      stdDay
# 0            0            0    0.00  2020-01-20
# 1            0            0    0.00  2020-01-21
# 2            0            0    0.00  2020-01-22
# 3            0            0    0.00  2020-01-23
# 4            0            0    0.00  2020-01-24
# 5            0            0    0.00  2020-01-25
# 6            0            1    0.00  2020-01-26
# 7            0            1    0.00  2020-01-27
# 8            0            0    0.00  2020-01-28
# 9            0            0    0.00  2020-01-29

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### stdDay가 같은 데이터

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df_final.duplicated(['stdDay'], keep = False).sum()) + '개')
df_final[df_final.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 check

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')

# %% [markdown]
# # 강원

# %%
city = '강원'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun     gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    강원  Gangwon-do       0             0           0
# 1         0       0    강원  Gangwon-do       0             0           0
# 2         0       0    강원  Gangwon-do       0             0           0
# 3         0       0    강원  Gangwon-do       0             0           0
# 4         0       0    강원  Gangwon-do       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt  defCnt gubun     gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350        17    1329    강원  Gangwon-do      28           938         374
# 351        17    1329    강원  Gangwon-do      28           937         375
# 654        67    7270    강원  Gangwon-do      29          6964         239
# 655        67    7270    강원  Gangwon-do      29          6943         231
# 751       122   19916    강원  Gangwon-do     740         19916           0
# 752       122   19177    강원  Gangwon-do     740         19916           0
# 753       122   19916    강원  Gangwon-do     740         15079           0
# 785       225  126407    강원  Gangwon-do    7482         46484           0
# 786       219  126407    강원  Gangwon-do    7482         37461           0
# 797       344  237251    강원  Gangwon-do   10428         92225           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350           28            0     86.27  2021-01-04
# 351           28            0     86.27  2021-01-04
# 654           29            0    471.00  2021-11-03
# 655           29            0    471.00  2021-11-03
# 751          738            2   1295.00  2022-02-07
# 752          738            2   1246.00  2022-02-07
# 753          738            2   1295.00  2022-02-07
# 785         7480            2   8216.00  2022-03-11
# 786         7480            2   8216.00  2022-03-11
# 797        10428            0  15421.00  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 44개
#      deathCnt  defCnt gubun     gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 813       515  364982    강원  Gangwon-do    5217             0           0
# 814       515  364982    강원  Gangwon-do    5217             0           0
# 862       828  507450    강원  Gangwon-do    1103             0           0
# 863       828  507450    강원  Gangwon-do    1103             0           0
# 893       869  522477    강원  Gangwon-do     154             0           0
# 894       869  522477    강원  Gangwon-do     154             0           0
# 960       942  661677    강원  Gangwon-do    3329             0           0
# 961       942  661677    강원  Gangwon-do    3329             0           0
# 981      1017  707376    강원  Gangwon-do    2917             0           0
# 982      1017  707376    강원  Gangwon-do    2917             0           0
#
#      localOccCnt  overFlowCnt  qurRate      stdDay
# 813         5216            1  23723.0  2022-04-04
# 814         5216            1  23723.0  2022-04-04
# 862         1103            0  32984.0  2022-05-21
# 863         1103            0  32984.0  2022-05-21
# 893          154            0  33960.0  2022-06-20
# 894          154            0  33960.0  2022-06-20
# 960         3311           18  43008.0  2022-08-25
# 961         3311           18  43008.0  2022-08-25
# 981         2916            1  45979.0  2022-09-14
# 982         2916            1  45979.0  2022-09-14

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# 수정해야하는 데이터 개수 : 27개
#      deathCnt  defCnt gubun     gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350        17    1329    강원  Gangwon-do      28           938         374
# 351        17    1329    강원  Gangwon-do      28           937         375
# 654        67    7270    강원  Gangwon-do      29          6964         239
# 655        67    7270    강원  Gangwon-do      29          6943         231
# 751       122   19916    강원  Gangwon-do     740         19916           0
# 752       122   19177    강원  Gangwon-do     740         19916           0
# 753       122   19916    강원  Gangwon-do     740         15079           0
# 785       225  126407    강원  Gangwon-do    7482         46484           0
# 786       219  126407    강원  Gangwon-do    7482         37461           0
# 797       344  237251    강원  Gangwon-do   10428         92225           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350           28            0     86.27  2021-01-04
# 351           28            0     86.27  2021-01-04
# 654           29            0    471.00  2021-11-03
# 655           29            0    471.00  2021-11-03
# 751          738            2   1295.00  2022-02-07
# 752          738            2   1246.00  2022-02-07
# 753          738            2   1295.00  2022-02-07
# 785         7480            2   8216.00  2022-03-11
# 786         7480            2   8216.00  2022-03-11
# 797        10428            0  15421.00  2022-03-22

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [350, 654, 751, 785, 797, 801, 807, 835, 1024, 1049, 1091, 1153, 1168]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 12
# 12
#       deathCnt  defCnt gubun     gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 1164      1312  901560    강원  Gangwon-do     293             0           0
# 1165      1313  901786    강원  Gangwon-do     226             0           0
# 1166      1314  902035    강원  Gangwon-do     251             0           0
# 1167         0  902233    강원  Gangwon-do     198             0           0
# 1168      1315  902233    강원  Gangwon-do     198             0           0
# 1169      1315  902355    강원  Gangwon-do     122             0           0
# 1170      1316  902596    강원  Gangwon-do     241             0           0
# 1171      1316  902970    강원  Gangwon-do     374             0           0
# 1172      1317  903239    강원  Gangwon-do     269             0           0
# 1173      1318  903498    강원  Gangwon-do     259             0           0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# 1164          293            0  58676.0  2023-03-16
# 1165          225            1  58691.0  2023-03-17
# 1166          250            1  58707.0  2023-03-18
# 1167          198            0  58720.0  2023-03-19
# 1168          198            0  58720.0  2023-03-20
# 1169          122            0  58728.0  2023-03-20
# 1170          240            1  58744.0  2023-03-21
# 1171          374            0  58768.0  2023-03-22
# 1172          269            0  58786.0  2023-03-23
# 1173          258            1  58802.0  2023-03-24

# %%
del_index = [351, 655, 751, 752, 786, 798, 802, 808, 836, 1024, 1050, 1092, 1154, 1168]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun     gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    강원  Gangwon-do       0             0           0
# 1         0       0    강원  Gangwon-do       0             0           0
# 2         0       0    강원  Gangwon-do       0             0           0
# 3         0       0    강원  Gangwon-do       0             0           0
# 4         0       0    강원  Gangwon-do       0             0           0
# 5         0       0    강원  Gangwon-do       0             0           0
# 6         0       0    강원  Gangwon-do       0             0           0
# 7         0       0    강원  Gangwon-do       0             0           0
# 8         0       0    강원  Gangwon-do       0             0           0
# 9         0       0    강원  Gangwon-do       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24
# 5            0            0      0.0  2020-01-25
# 6            0            0      0.0  2020-01-26
# 7            0            0      0.0  2020-01-27
# 8            0            0      0.0  2020-01-28
# 9            0            0      0.0  2020-01-29

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 check

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')

# %% [markdown]
# # 충북

# %%
city = '충북'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun            gubunEn  incDec  isolClearCnt  \
# 0         0       0    충북  Chungcheongbuk-do       0             0
# 1         0       0    충북  Chungcheongbuk-do       0             0
# 2         0       0    충북  Chungcheongbuk-do       0             0
# 3         0       0    충북  Chungcheongbuk-do       0             0
# 4         0       0    충북  Chungcheongbuk-do       0             0
#
#    isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
# 0           0            0            0      0.0  2020-01-20
# 1           0            0            0      0.0  2020-01-21
# 2           0            0            0      0.0  2020-01-22
# 3           0            0            0      0.0  2020-01-23
# 4           0            0            0      0.0  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt  defCnt gubun            gubunEn  incDec  isolClearCnt  \
# 350        28    1271    충북  Chungcheongbuk-do      23           676
# 351        28    1271    충북  Chungcheongbuk-do      23           675
# 654        84    7993    충북  Chungcheongbuk-do      48          7502
# 655        83    7993    충북  Chungcheongbuk-do      48          7473
# 751       131   19081    충북  Chungcheongbuk-do     885         19966
# 752       131   19966    충북  Chungcheongbuk-do     885         19966
# 753       131   19966    충북  Chungcheongbuk-do     885         14248
# 785       219  138784    충북  Chungcheongbuk-do    7914         82735
# 786       214  138784    충북  Chungcheongbuk-do    7914         72084
# 797       344  262002    충북  Chungcheongbuk-do   11828        164491
#
#      isolIngCnt  localOccCnt  overFlowCnt   qurRate      stdDay
# 350         567           23            0     79.47  2021-01-04
# 351         568           23            0     79.47  2021-01-04
# 654         407           47            1    499.00  2021-11-03
# 655         389           47            1    499.00  2021-11-03
# 751           0          884            1   1194.00  2022-02-07
# 752           0          884            1   1250.00  2022-02-07
# 753           0          884            1   1250.00  2022-02-07
# 785           0         7910            4   8688.00  2022-03-11
# 786           0         7910            4   8688.00  2022-03-11
# 797           0            1        11829  16402.00  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 44개
#      deathCnt  defCnt gubun            gubunEn  incDec  isolClearCnt  \
# 813       496  403201    충북  Chungcheongbuk-do    3956             0
# 814       496  403201    충북  Chungcheongbuk-do    3956             0
# 862       714  547584    충북  Chungcheongbuk-do     795             0
# 863       714  547584    충북  Chungcheongbuk-do     795             0
# 893       729  559160    충북  Chungcheongbuk-do      83             0
# 894       729  559160    충북  Chungcheongbuk-do      83             0
# 960       798  702559    충북  Chungcheongbuk-do    3811             0
# 961       798  702559    충북  Chungcheongbuk-do    3811             0
# 981       830  755791    충북  Chungcheongbuk-do    3166             0
# 982       830  755791    충북  Chungcheongbuk-do    3166             0
#
#      isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
# 813           0         3956            0  25241.0  2022-04-04
# 814           0         3956            0  25241.0  2022-04-04
# 862           0          794            1  34279.0  2022-05-21
# 863           0          794            1  34279.0  2022-05-21
# 893           0           82            1  35004.0  2022-06-20
# 894           0           82            1  35004.0  2022-06-20
# 960           0         3797           14  43981.0  2022-08-25
# 961           0         3797           14  43981.0  2022-08-25
# 981           0         3143           23  47313.0  2022-09-14
# 982           0         3143           23  47313.0  2022-09-14

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# 수정해야하는 데이터 개수 : 27개
#      deathCnt  defCnt gubun            gubunEn  incDec  isolClearCnt  \
# 350        28    1271    충북  Chungcheongbuk-do      23           676
# 351        28    1271    충북  Chungcheongbuk-do      23           675
# 654        84    7993    충북  Chungcheongbuk-do      48          7502
# 655        83    7993    충북  Chungcheongbuk-do      48          7473
# 751       131   19081    충북  Chungcheongbuk-do     885         19966
# 752       131   19966    충북  Chungcheongbuk-do     885         19966
# 753       131   19966    충북  Chungcheongbuk-do     885         14248
# 785       219  138784    충북  Chungcheongbuk-do    7914         82735
# 786       214  138784    충북  Chungcheongbuk-do    7914         72084
# 797       344  262002    충북  Chungcheongbuk-do   11828        164491
#
#      isolIngCnt  localOccCnt  overFlowCnt   qurRate      stdDay
# 350         567           23            0     79.47  2021-01-04
# 351         568           23            0     79.47  2021-01-04
# 654         407           47            1    499.00  2021-11-03
# 655         389           47            1    499.00  2021-11-03
# 751           0          884            1   1194.00  2022-02-07
# 752           0          884            1   1250.00  2022-02-07
# 753           0          884            1   1250.00  2022-02-07
# 785           0         7910            4   8688.00  2022-03-11
# 786           0         7910            4   8688.00  2022-03-11
# 797           0            1        11829  16402.00  2022-03-22

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [350, 654, 751, 785, 797, 801, 807, 835, 1024, 1049, 1091, 1153, 1168]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 12
# 12
#       deathCnt  defCnt gubun            gubunEn  incDec  isolClearCnt  \
# 1164      1029  961841    충북  Chungcheongbuk-do     324             0
# 1165      1029  962167    충북  Chungcheongbuk-do     326             0
# 1166      1029  962470    충북  Chungcheongbuk-do     303             0
# 1167         0  962760    충북  Chungcheongbuk-do     290             0
# 1168      1029  962760    충북  Chungcheongbuk-do     290             0
# 1169      1029  962953    충북  Chungcheongbuk-do     193             0
# 1170      1029  963278    충북  Chungcheongbuk-do     325             0
# 1171      1030  963779    충북  Chungcheongbuk-do     501             0
# 1172      1030  964171    충북  Chungcheongbuk-do     392             0
# 1173      1031  964513    충북  Chungcheongbuk-do     342             0
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
# 1164           0          324            0  60301.0  2023-03-16
# 1165           0          326            0  60322.0  2023-03-17
# 1166           0          302            1  60341.0  2023-03-18
# 1167           0          290            0  60359.0  2023-03-19
# 1168           0          290            0  60359.0  2023-03-20
# 1169           0          193            0  60371.0  2023-03-20
# 1170           0          325            0  60391.0  2023-03-21
# 1171           0          501            0  60423.0  2023-03-22
# 1172           0          392            0  60447.0  2023-03-23
# 1173           0          342            0  60469.0  2023-03-24

# %%
del_index = [351, 655, 751, 752, 786, 797, 801, 807, 835, 1024, 1049, 1092, 1153, 1168]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun            gubunEn  incDec  isolClearCnt  \
# 0         0       0    충북  Chungcheongbuk-do       0             0
# 1         0       0    충북  Chungcheongbuk-do       0             0
# 2         0       0    충북  Chungcheongbuk-do       0             0
# 3         0       0    충북  Chungcheongbuk-do       0             0
# 4         0       0    충북  Chungcheongbuk-do       0             0
# 5         0       0    충북  Chungcheongbuk-do       0             0
# 6         0       0    충북  Chungcheongbuk-do       0             0
# 7         0       0    충북  Chungcheongbuk-do       0             0
# 8         0       0    충북  Chungcheongbuk-do       0             0
# 9         0       0    충북  Chungcheongbuk-do       0             0
#
#    isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
# 0           0            0            0      0.0  2020-01-20
# 1           0            0            0      0.0  2020-01-21
# 2           0            0            0      0.0  2020-01-22
# 3           0            0            0      0.0  2020-01-23
# 4           0            0            0      0.0  2020-01-24
# 5           0            0            0      0.0  2020-01-25
# 6           0            0            0      0.0  2020-01-26
# 7           0            0            0      0.0  2020-01-27
# 8           0            0            0      0.0  2020-01-28
# 9           0            0            0      0.0  2020-01-29

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### stdDay가 같은 데이터

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df_final.duplicated(['stdDay'], keep = False).sum()) + '개')
df_final[df_final.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 check

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')

# %% [markdown]
# # 충남

# %%
city = '충남'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun            gubunEn  incDec  isolClearCnt  \
# 0         0       0    충남  Chungcheongnam-do       0             0
# 1         0       0    충남  Chungcheongnam-do       0             0
# 2         0       0    충남  Chungcheongnam-do       0             0
# 3         0       0    충남  Chungcheongnam-do       0             0
# 4         0       0    충남  Chungcheongnam-do       0             0
#
#    isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
# 0           0            0            0      0.0  2020-01-20
# 1           0            0            0      0.0  2020-01-21
# 2           0            0            0      0.0  2020-01-22
# 3           0            0            0      0.0  2020-01-23
# 4           0            0            0      0.0  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt  defCnt gubun            gubunEn  incDec  isolClearCnt  \
# 350        25    1707    충남  Chungcheongnam-do      23          1207
# 351        25    1707    충남  Chungcheongnam-do      23          1210
# 654        61   10807    충남  Chungcheongnam-do      91          9917
# 655        61   10807    충남  Chungcheongnam-do      91          9962
# 751       205   32736    충남  Chungcheongnam-do    1473         18824
# 752       205   32736    충남  Chungcheongnam-do    1473         32736
# 753       205   31263    충남  Chungcheongnam-do    1473         32736
# 785       330  190871    충남  Chungcheongnam-do   10798         39065
# 786       323  190871    충남  Chungcheongnam-do   10798         35669
# 797       466  346953    충남  Chungcheongnam-do   15152        165990
#
#      isolIngCnt  localOccCnt  overFlowCnt   qurRate      stdDay
# 350         475           22            1     80.43  2021-01-04
# 351         472           22            1     80.43  2021-01-04
# 654         738           91            0    510.00  2021-11-03
# 655         784           91            0    510.00  2021-11-03
# 751           0         1467            6   1545.00  2022-02-07
# 752           0         1467            6   1545.00  2022-02-07
# 753           0         1467            6   1475.00  2022-02-07
# 785           0        10798            0   9007.00  2022-03-11
# 786           0        10798            0   9007.00  2022-03-11
# 797           0        15152            0  16371.00  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 44개
#      deathCnt  defCnt gubun            gubunEn  incDec  isolClearCnt  \
# 813       626  520140    충남  Chungcheongnam-do    5642             0
# 814       626  520140    충남  Chungcheongnam-do    5642             0
# 862       946  705567    충남  Chungcheongnam-do     989             0
# 863       946  705567    충남  Chungcheongnam-do     989             0
# 893       963  720015    충남  Chungcheongnam-do     134             0
# 894       963  720015    충남  Chungcheongnam-do     134             0
# 960      1081  905743    충남  Chungcheongnam-do    5241             0
# 961      1081  905743    충남  Chungcheongnam-do    5241             0
# 981      1149  974079    충남  Chungcheongnam-do    3725             0
# 982      1149  974079    충남  Chungcheongnam-do    3725             0
#
#      isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
# 813           0         5642            0  24544.0  2022-04-04
# 814           0         5642            0  24544.0  2022-04-04
# 862           0          989            0  33293.0  2022-05-21
# 863           0          989            0  33293.0  2022-05-21
# 893           0          127            7  33975.0  2022-06-20
# 894           0          127            7  33975.0  2022-06-20
# 960           0         5206           35  42739.0  2022-08-25
# 961           0         5206           35  42739.0  2022-08-25
# 981           0         3699           26  45963.0  2022-09-14
# 982           0         3699           26  45963.0  2022-09-14

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# 수정해야하는 데이터 개수 : 27개
#      deathCnt  defCnt gubun            gubunEn  incDec  isolClearCnt  \
# 350        25    1707    충남  Chungcheongnam-do      23          1207
# 351        25    1707    충남  Chungcheongnam-do      23          1210
# 654        61   10807    충남  Chungcheongnam-do      91          9917
# 655        61   10807    충남  Chungcheongnam-do      91          9962
# 751       205   32736    충남  Chungcheongnam-do    1473         18824
# 752       205   32736    충남  Chungcheongnam-do    1473         32736
# 753       205   31263    충남  Chungcheongnam-do    1473         32736
# 785       330  190871    충남  Chungcheongnam-do   10798         39065
# 786       323  190871    충남  Chungcheongnam-do   10798         35669
# 797       466  346953    충남  Chungcheongnam-do   15152        165990
#
#      isolIngCnt  localOccCnt  overFlowCnt   qurRate      stdDay
# 350         475           22            1     80.43  2021-01-04
# 351         472           22            1     80.43  2021-01-04
# 654         738           91            0    510.00  2021-11-03
# 655         784           91            0    510.00  2021-11-03
# 751           0         1467            6   1545.00  2022-02-07
# 752           0         1467            6   1545.00  2022-02-07
# 753           0         1467            6   1475.00  2022-02-07
# 785           0        10798            0   9007.00  2022-03-11
# 786           0        10798            0   9007.00  2022-03-11
# 797           0        15152            0  16371.00  2022-03-22

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [350, 654, 751, 785, 797, 801, 807, 835, 1024, 1049, 1091, 1153, 1168]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 12
# 12
#       deathCnt   defCnt gubun            gubunEn  incDec  isolClearCnt  \
# 1164      1563  1241107    충남  Chungcheongnam-do     398             0
# 1165      1563  1241462    충남  Chungcheongnam-do     355             0
# 1166      1563  1241765    충남  Chungcheongnam-do     309             0
# 1167         0  1242113    충남  Chungcheongnam-do     348             0
# 1168      1563  1242258    충남  Chungcheongnam-do     145             0
# 1169      1563  1242113    충남  Chungcheongnam-do     348             0
# 1170      1564  1242736    충남  Chungcheongnam-do     478             0
# 1171      1564  1243215    충남  Chungcheongnam-do     479             0
# 1172      1565  1243695    충남  Chungcheongnam-do     480             0
# 1173      1565  1244083    충남  Chungcheongnam-do     388             0
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
# 1164           0          398            0  58459.0  2023-03-16
# 1165           0          355            0  58476.0  2023-03-17
# 1166           0          309            0  58490.0  2023-03-18
# 1167           0          348            0  58506.0  2023-03-19
# 1168           0          145            0  58513.0  2023-03-20
# 1169           0          348            0  58506.0  2023-03-20
# 1170           0          478            0  58536.0  2023-03-21
# 1171           0          479            0  58558.0  2023-03-22
# 1172           0          480            0  58581.0  2023-03-23
# 1173           0          388            0  58599.0  2023-03-24

# %%
del_index = [350, 654, 752, 753, 786, 798, 802, 808, 836, 1025, 1049, 1091, 1153, 1169]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun            gubunEn  incDec  isolClearCnt  \
# 0         0       0    충남  Chungcheongnam-do       0             0
# 1         0       0    충남  Chungcheongnam-do       0             0
# 2         0       0    충남  Chungcheongnam-do       0             0
# 3         0       0    충남  Chungcheongnam-do       0             0
# 4         0       0    충남  Chungcheongnam-do       0             0
# 5         0       0    충남  Chungcheongnam-do       0             0
# 6         0       0    충남  Chungcheongnam-do       0             0
# 7         0       0    충남  Chungcheongnam-do       0             0
# 8         0       0    충남  Chungcheongnam-do       0             0
# 9         0       0    충남  Chungcheongnam-do       0             0
#
#    isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
# 0           0            0            0      0.0  2020-01-20
# 1           0            0            0      0.0  2020-01-21
# 2           0            0            0      0.0  2020-01-22
# 3           0            0            0      0.0  2020-01-23
# 4           0            0            0      0.0  2020-01-24
# 5           0            0            0      0.0  2020-01-25
# 6           0            0            0      0.0  2020-01-26
# 7           0            0            0      0.0  2020-01-27
# 8           0            0            0      0.0  2020-01-28
# 9           0            0            0      0.0  2020-01-29

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### stdDay가 같은 데이터

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df_final.duplicated(['stdDay'], keep = False).sum()) + '개')
df_final[df_final.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 check

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')

# %% [markdown]
# # 전북

# %%
city = '전북'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun       gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    전북  Jeollabuk-do       0             0           0
# 1         0       0    전북  Jeollabuk-do       0             0           0
# 2         0       0    전북  Jeollabuk-do       0             0           0
# 3         0       0    전북  Jeollabuk-do       0             0           0
# 4         0       0    전북  Jeollabuk-do       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt  defCnt gubun       gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350        16     874    전북  Jeollabuk-do      13           664         194
# 351        16     874    전북  Jeollabuk-do      13           664         194
# 654        66    5269    전북  Jeollabuk-do      43          4875         328
# 655        66    5269    전북  Jeollabuk-do      43          4864         296
# 751       130   20486    전북  Jeollabuk-do    1271         21756           0
# 752       130   21756    전북  Jeollabuk-do    1271         21756           0
# 753       130   21756    전북  Jeollabuk-do    1271         13377           0
# 785       244  153843    전북  Jeollabuk-do    8852         82010           0
# 786       255  153843    전북  Jeollabuk-do    8852         82010           0
# 797       380  283511    전북  Jeollabuk-do   12584        164593           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350            9            4     48.09  2021-01-04
# 351            9            4     48.09  2021-01-04
# 654           43            0    292.00  2021-11-03
# 655           43            0    292.00  2021-11-03
# 751         1269            2   1146.00  2022-02-07
# 752         1269            2   1218.00  2022-02-07
# 753         1269            2   1218.00  2022-02-07
# 785         8841           11   8610.00  2022-03-11
# 786         8841           11   8610.00  2022-03-11
# 797        12584            0  15866.00  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 46개
#      deathCnt  defCnt gubun       gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350        16     874    전북  Jeollabuk-do      13           664         194
# 351        16     874    전북  Jeollabuk-do      13           664         194
# 813       595  428485    전북  Jeollabuk-do    5088             0           0
# 814       595  428485    전북  Jeollabuk-do    5088             0           0
# 862       863  591277    전북  Jeollabuk-do    1021             0           0
# 863       863  591277    전북  Jeollabuk-do    1021             0           0
# 893       880  603630    전북  Jeollabuk-do      72             0           0
# 894       880  603630    전북  Jeollabuk-do      72             0           0
# 960       927  763330    전북  Jeollabuk-do    4533             0           0
# 961       927  763330    전북  Jeollabuk-do    4533             0           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350            9            4     48.09  2021-01-04
# 351            9            4     48.09  2021-01-04
# 813         5086            2  23980.00  2022-04-04
# 814         5086            2  23980.00  2022-04-04
# 862         1021            0  33090.00  2022-05-21
# 863         1021            0  33090.00  2022-05-21
# 893           68            4  33782.00  2022-06-20
# 894           68            4  33782.00  2022-06-20
# 960         4482           51  42719.00  2022-08-25
# 961         4482           51  42719.00  2022-08-25

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# 수정해야하는 데이터 개수 : 25개
#      deathCnt  defCnt gubun       gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 653        66    5269    전북  Jeollabuk-do      43          4875         328
# 654        66    5269    전북  Jeollabuk-do      43          4864         296
# 750       130   20486    전북  Jeollabuk-do    1271         21756           0
# 751       130   21756    전북  Jeollabuk-do    1271         21756           0
# 752       130   21756    전북  Jeollabuk-do    1271         13377           0
# 784       244  153843    전북  Jeollabuk-do    8852         82010           0
# 785       255  153843    전북  Jeollabuk-do    8852         82010           0
# 796       380  283511    전북  Jeollabuk-do   12584        164593           0
# 797       380  283511    전북  Jeollabuk-do   12584        164593           0
# 800       450  325155    전북  Jeollabuk-do   12824        207927           0
#
#      localOccCnt  overFlowCnt  qurRate      stdDay
# 653           43            0    292.0  2021-11-03
# 654           43            0    292.0  2021-11-03
# 750         1269            2   1146.0  2022-02-07
# 751         1269            2   1218.0  2022-02-07
# 752         1269            2   1218.0  2022-02-07
# 784         8841           11   8610.0  2022-03-11
# 785         8841           11   8610.0  2022-03-11
# 796        12584            0  15866.0  2022-03-22
# 797            0        12584  15866.0  2022-03-22
# 800            2        12826  18197.0  2022-03-25

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [653, 750, 784, 796, 800, 806, 834, 1023, 1048, 1090, 1152, 1167]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 11
# 11
#       deathCnt   defCnt gubun       gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 1163      1215  1029205    전북  Jeollabuk-do     448             0           0
# 1164      1217  1029553    전북  Jeollabuk-do     348             0           0
# 1165      1217  1029931    전북  Jeollabuk-do     379             0           0
# 1166         0  1030299    전북  Jeollabuk-do     368             0           0
# 1167      1219  1030497    전북  Jeollabuk-do     198             0           0
# 1168      1219  1030299    전북  Jeollabuk-do     368             0           0
# 1169      1219  1030979    전북  Jeollabuk-do     482             0           0
# 1170      1220  1031505    전북  Jeollabuk-do     526             0           0
# 1171      1220  1031987    전북  Jeollabuk-do     482             0           0
# 1172      1220  1032445    전북  Jeollabuk-do     458             0           0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# 1163          448            0  58160.0  2023-03-16
# 1164          348            0  58180.0  2023-03-17
# 1165          379            0  58201.0  2023-03-18
# 1166          368            0  58222.0  2023-03-19
# 1167          198            0  58233.0  2023-03-20
# 1168          368            0  58222.0  2023-03-20
# 1169          482            0  58260.0  2023-03-21
# 1170          523            3  58290.0  2023-03-22
# 1171          481            1  58317.0  2023-03-23
# 1172          458            0  58343.0  2023-03-24

# %%
del_index = [654, 750, 751, 784, 797, 800, 807, 835, 1023, 1048, 1090, 1153, 1168]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun       gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    전북  Jeollabuk-do       0             0           0
# 1         0       0    전북  Jeollabuk-do       0             0           0
# 2         0       0    전북  Jeollabuk-do       0             0           0
# 3         0       0    전북  Jeollabuk-do       0             0           0
# 4         0       0    전북  Jeollabuk-do       0             0           0
# 5         0       0    전북  Jeollabuk-do       0             0           0
# 6         0       0    전북  Jeollabuk-do       0             0           0
# 7         0       0    전북  Jeollabuk-do       0             0           0
# 8         0       0    전북  Jeollabuk-do       0             0           0
# 9         0       0    전북  Jeollabuk-do       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24
# 5            0            0      0.0  2020-01-25
# 6            0            0      0.0  2020-01-26
# 7            0            0      0.0  2020-01-27
# 8            0            0      0.0  2020-01-28
# 9            0            0      0.0  2020-01-29

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### stdDay가 같은 데이터

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df_final.duplicated(['stdDay'], keep = False).sum()) + '개')
df_final[df_final.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 check

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')

# %% [markdown]
# # 전남

# %%
city = '전남'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun       gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    전남  Jeollanam-do       0             0           0
# 1         0       0    전남  Jeollanam-do       0             0           0
# 2         0       0    전남  Jeollanam-do       0             0           0
# 3         0       0    전남  Jeollanam-do       0             0           0
# 4         0       0    전남  Jeollanam-do       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt  defCnt gubun       gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350         5     592    전남  Jeollanam-do       3           487         100
# 351         5     592    전남  Jeollanam-do       3           486         101
# 654        22    3616    전남  Jeollanam-do      21          3403         170
# 655        22    3616    전남  Jeollanam-do      21          3416         178
# 751        47   16300    전남  Jeollanam-do    1133         16300           0
# 752        47   16300    전남  Jeollanam-do    1133          6921           0
# 753        47   15167    전남  Jeollanam-do    1133         16300           0
# 785        77  128930    전남  Jeollanam-do    8987          6958           0
# 786        76  128930    전남  Jeollanam-do    8987          6956           0
# 797       140  251499    전남  Jeollanam-do   12280          6970           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350            3            0     31.75  2021-01-04
# 351            3            0     31.75  2021-01-04
# 654           21            0    195.00  2021-11-03
# 655           21            0    195.00  2021-11-03
# 751         1129            4    889.00  2022-02-07
# 752         1129            4    889.00  2022-02-07
# 753         1129            4    828.00  2022-02-07
# 785         8984            3   7035.00  2022-03-11
# 786         8984            3   7035.00  2022-03-11
# 797        12279            1  13722.00  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 44개
#      deathCnt  defCnt gubun       gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 813       239  410998    전남  Jeollanam-do    5959             0           0
# 814       239  410998    전남  Jeollanam-do    5959             0           0
# 862       439  587623    전남  Jeollanam-do     907             0           0
# 863       439  587623    전남  Jeollanam-do     907             0           0
# 893       477  599795    전남  Jeollanam-do     111             0           0
# 894       477  599795    전남  Jeollanam-do     111             0           0
# 960       577  751438    전남  Jeollanam-do    5081             0           0
# 961       577  751438    전남  Jeollanam-do    5081             0           0
# 981       655  806148    전남  Jeollanam-do    2744             0           0
# 982       655  806148    전남  Jeollanam-do    2744             0           0
#
#      localOccCnt  overFlowCnt  qurRate      stdDay
# 813         5959            0  22425.0  2022-04-04
# 814         5959            0  22425.0  2022-04-04
# 862          907            0  32061.0  2022-05-21
# 863          907            0  32061.0  2022-05-21
# 893          110            1  32726.0  2022-06-20
# 894          110            1  32726.0  2022-06-20
# 960         5074            7  40999.0  2022-08-25
# 961         5074            7  40999.0  2022-08-25
# 981         2739            5  43984.0  2022-09-14
# 982         2739            5  43984.0  2022-09-14

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# 수정해야하는 데이터 개수 : 27개
#      deathCnt  defCnt gubun       gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350         5     592    전남  Jeollanam-do       3           487         100
# 351         5     592    전남  Jeollanam-do       3           486         101
# 654        22    3616    전남  Jeollanam-do      21          3403         170
# 655        22    3616    전남  Jeollanam-do      21          3416         178
# 751        47   16300    전남  Jeollanam-do    1133         16300           0
# 752        47   16300    전남  Jeollanam-do    1133          6921           0
# 753        47   15167    전남  Jeollanam-do    1133         16300           0
# 785        77  128930    전남  Jeollanam-do    8987          6958           0
# 786        76  128930    전남  Jeollanam-do    8987          6956           0
# 797       140  251499    전남  Jeollanam-do   12280          6970           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350            3            0     31.75  2021-01-04
# 351            3            0     31.75  2021-01-04
# 654           21            0    195.00  2021-11-03
# 655           21            0    195.00  2021-11-03
# 751         1129            4    889.00  2022-02-07
# 752         1129            4    889.00  2022-02-07
# 753         1129            4    828.00  2022-02-07
# 785         8984            3   7035.00  2022-03-11
# 786         8984            3   7035.00  2022-03-11
# 797        12279            1  13722.00  2022-03-22

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [350, 654, 751, 785, 797, 801, 807, 835, 1024, 1049, 1091, 1153, 1168]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 12
# 12
#       deathCnt   defCnt gubun       gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 1164       981  1003544    전남  Jeollanam-do     315             0           0
# 1165       981  1003822    전남  Jeollanam-do     278             0           0
# 1166       981  1004106    전남  Jeollanam-do     284             0           0
# 1167         0  1004376    전남  Jeollanam-do     270             0           0
# 1168       981  1004476    전남  Jeollanam-do     100             0           0
# 1169       981  1004376    전남  Jeollanam-do     270             0           0
# 1170       982  1004778    전남  Jeollanam-do     302             0           0
# 1171       982  1005086    전남  Jeollanam-do     308             0           0
# 1172       985  1005402    전남  Jeollanam-do     316             0           0
# 1173       987  1005671    전남  Jeollanam-do     269             0           0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# 1164          315            0  55210.0  2023-03-16
# 1165          278            0  55225.0  2023-03-17
# 1166          284            0  55241.0  2023-03-18
# 1167          270            0  55255.0  2023-03-19
# 1168          100            0  55261.0  2023-03-20
# 1169          270            0  55255.0  2023-03-20
# 1170          302            0  55278.0  2023-03-21
# 1171          308            0  55294.0  2023-03-22
# 1172          315            1  55312.0  2023-03-23
# 1173          269            0  55327.0  2023-03-24

# %%
del_index = [351, 654, 751, 753, 786, 798, 801, 808, 835, 1024, 1050, 1091, 1153, 1169]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun       gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    전남  Jeollanam-do       0             0           0
# 1         0       0    전남  Jeollanam-do       0             0           0
# 2         0       0    전남  Jeollanam-do       0             0           0
# 3         0       0    전남  Jeollanam-do       0             0           0
# 4         0       0    전남  Jeollanam-do       0             0           0
# 5         0       0    전남  Jeollanam-do       0             0           0
# 6         0       0    전남  Jeollanam-do       0             0           0
# 7         0       0    전남  Jeollanam-do       0             0           0
# 8         0       0    전남  Jeollanam-do       0             0           0
# 9         0       0    전남  Jeollanam-do       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24
# 5            0            0      0.0  2020-01-25
# 6            0            0      0.0  2020-01-26
# 7            0            0      0.0  2020-01-27
# 8            0            0      0.0  2020-01-28
# 9            0            0      0.0  2020-01-29

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### stdDay가 같은 데이터

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df_final.duplicated(['stdDay'], keep = False).sum()) + '개')
df_final[df_final.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 check

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')

# %% [markdown]
# # 경북

# %%
city = '경북'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun           gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    경북  Gyeongsangbuk-do       0             0           0
# 1         0       0    경북  Gyeongsangbuk-do       0             0           0
# 2         0       0    경북  Gyeongsangbuk-do       0             0           0
# 3         0       0    경북  Gyeongsangbuk-do       0             0           0
# 4         0       0    경북  Gyeongsangbuk-do       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt  defCnt gubun           gubunEn  incDec  isolClearCnt  \
# 350        62    2507    경북  Gyeongsangbuk-do      25          1999
# 351        62    2507    경북  Gyeongsangbuk-do      25          2003
# 654        95    9788    경북  Gyeongsangbuk-do      31          9314
# 655        95    9788    경북  Gyeongsangbuk-do      31          9290
# 751       228   28488    경북  Gyeongsangbuk-do    1686         30174
# 752       228   30174    경북  Gyeongsangbuk-do    1686         30174
# 753       228   30174    경북  Gyeongsangbuk-do    1686         16455
# 785       418  190593    경북  Gyeongsangbuk-do   10315         62715
# 786       432  190593    경북  Gyeongsangbuk-do   10315         65808
# 797       562  351205    경북  Gyeongsangbuk-do   14432        148289
#
#      isolIngCnt  localOccCnt  overFlowCnt   qurRate      stdDay
# 350         446           25            0     94.16  2021-01-04
# 351         442           25            0     94.16  2021-01-04
# 654         379           31            0    371.00  2021-11-03
# 655         372           31            0    371.00  2021-11-03
# 751           0         1684            2   1085.00  2022-02-07
# 752           0         1684            2   1149.00  2022-02-07
# 753           0         1684            2   1149.00  2022-02-07
# 785           0        10306            9   7256.00  2022-03-11
# 786           0        10306            9   7256.00  2022-03-11
# 797           0        14429            3  13371.00  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 44개
#      deathCnt   defCnt gubun           gubunEn  incDec  isolClearCnt  \
# 813       831   538220    경북  Gyeongsangbuk-do    6270             0
# 814       831   538220    경북  Gyeongsangbuk-do    6270             0
# 862      1341   762885    경북  Gyeongsangbuk-do    1663             0
# 863      1341   762885    경북  Gyeongsangbuk-do    1663             0
# 893      1390   788144    경북  Gyeongsangbuk-do     228             0
# 894      1390   788144    경북  Gyeongsangbuk-do     228             0
# 960      1527  1007099    경북  Gyeongsangbuk-do    6422             0
# 961      1527  1007099    경북  Gyeongsangbuk-do    6422             0
# 981      1605  1089380    경북  Gyeongsangbuk-do    4329             0
# 982      1605  1089380    경북  Gyeongsangbuk-do    4329             0
#
#      isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
# 813           0         6266            4  20491.0  2022-04-04
# 814           0         6266            4  20491.0  2022-04-04
# 862           0         1661            2  29044.0  2022-05-21
# 863           0         1661            2  29044.0  2022-05-21
# 893           0          222            6  30006.0  2022-06-20
# 894           0          222            6  30006.0  2022-06-20
# 960           0         6400           22  38342.0  2022-08-25
# 961           0         6400           22  38342.0  2022-08-25
# 981           0         4306           23  41475.0  2022-09-14
# 982           0         4306           23  41475.0  2022-09-14

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# 수정해야하는 데이터 개수 : 27개
#      deathCnt  defCnt gubun           gubunEn  incDec  isolClearCnt  \
# 350        62    2507    경북  Gyeongsangbuk-do      25          1999
# 351        62    2507    경북  Gyeongsangbuk-do      25          2003
# 654        95    9788    경북  Gyeongsangbuk-do      31          9314
# 655        95    9788    경북  Gyeongsangbuk-do      31          9290
# 751       228   28488    경북  Gyeongsangbuk-do    1686         30174
# 752       228   30174    경북  Gyeongsangbuk-do    1686         30174
# 753       228   30174    경북  Gyeongsangbuk-do    1686         16455
# 785       418  190593    경북  Gyeongsangbuk-do   10315         62715
# 786       432  190593    경북  Gyeongsangbuk-do   10315         65808
# 797       562  351205    경북  Gyeongsangbuk-do   14432        148289
#
#      isolIngCnt  localOccCnt  overFlowCnt   qurRate      stdDay
# 350         446           25            0     94.16  2021-01-04
# 351         442           25            0     94.16  2021-01-04
# 654         379           31            0    371.00  2021-11-03
# 655         372           31            0    371.00  2021-11-03
# 751           0         1684            2   1085.00  2022-02-07
# 752           0         1684            2   1149.00  2022-02-07
# 753           0         1684            2   1149.00  2022-02-07
# 785           0        10306            9   7256.00  2022-03-11
# 786           0        10306            9   7256.00  2022-03-11
# 797           0        14429            3  13371.00  2022-03-22

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [350, 654, 751, 785, 797, 801, 807, 835, 1024, 1049, 1091, 1153, 1168]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 12
# 12
#       deathCnt   defCnt gubun           gubunEn  incDec  isolClearCnt  \
# 1164      2085  1406732    경북  Gyeongsangbuk-do     569             0
# 1165      2086  1407212    경북  Gyeongsangbuk-do     480             0
# 1166      2086  1407691    경북  Gyeongsangbuk-do     480             0
# 1167         0  1408110    경북  Gyeongsangbuk-do     419             0
# 1168      2086  1408346    경북  Gyeongsangbuk-do     236             0
# 1169      2086  1408110    경북  Gyeongsangbuk-do     419             0
# 1170      2087  1408857    경북  Gyeongsangbuk-do     511             0
# 1171      2088  1409582    경북  Gyeongsangbuk-do     725             0
# 1172      2088  1410099    경북  Gyeongsangbuk-do     517             0
# 1173      2088  1410578    경북  Gyeongsangbuk-do     479             0
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
# 1164           0          569            0  54095.0  2023-03-16
# 1165           0          479            1  54113.0  2023-03-17
# 1166           0          480            0  54132.0  2023-03-18
# 1167           0          418            1  54148.0  2023-03-19
# 1168           0          236            0  54157.0  2023-03-20
# 1169           0          418            1  54148.0  2023-03-20
# 1170           0          511            0  54177.0  2023-03-21
# 1171           0          722            3  54204.0  2023-03-22
# 1172           0          515            2  54224.0  2023-03-23
# 1173           0          479            0  54243.0  2023-03-24

# %%
del_index = [350, 655, 751, 752, 785, 798, 802, 807, 836, 1024, 1050, 1092, 1154, 1169]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun           gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    경북  Gyeongsangbuk-do       0             0           0
# 1         0       0    경북  Gyeongsangbuk-do       0             0           0
# 2         0       0    경북  Gyeongsangbuk-do       0             0           0
# 3         0       0    경북  Gyeongsangbuk-do       0             0           0
# 4         0       0    경북  Gyeongsangbuk-do       0             0           0
# 5         0       0    경북  Gyeongsangbuk-do       0             0           0
# 6         0       0    경북  Gyeongsangbuk-do       0             0           0
# 7         0       0    경북  Gyeongsangbuk-do       0             0           0
# 8         0       0    경북  Gyeongsangbuk-do       0             0           0
# 9         0       0    경북  Gyeongsangbuk-do       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24
# 5            0            0      0.0  2020-01-25
# 6            0            0      0.0  2020-01-26
# 7            0            0      0.0  2020-01-27
# 8            0            0      0.0  2020-01-28
# 9            0            0      0.0  2020-01-29

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### stdDay가 같은 데이터

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df_final.duplicated(['stdDay'], keep = False).sum()) + '개')
df_final[df_final.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 check

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')

# %% [markdown]
# # 경남

# %%
city = '경남'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun           gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    경남  Gyeongsangnam-do       0             0           0
# 1         0       0    경남  Gyeongsangnam-do       0             0           0
# 2         0       0    경남  Gyeongsangnam-do       0             0           0
# 3         0       0    경남  Gyeongsangnam-do       0             0           0
# 4         0       0    경남  Gyeongsangnam-do       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt  defCnt gubun           gubunEn  incDec  isolClearCnt  \
# 350         5    1442    경남  Gyeongsangnam-do      33          1089
# 351         5    1442    경남  Gyeongsangnam-do      33          1089
# 654        42   13220    경남  Gyeongsangnam-do     108         12539
# 655        41   13220    경남  Gyeongsangnam-do     108         12508
# 751       121   36949    경남  Gyeongsangnam-do    1672         25659
# 752       121   36949    경남  Gyeongsangnam-do    1672         36949
# 753       121   35277    경남  Gyeongsangnam-do    1672         36949
# 785       243  309731    경남  Gyeongsangnam-do   21428        135967
# 786       233  309731    경남  Gyeongsangnam-do   21428        135970
# 797       477  581709    경남  Gyeongsangnam-do   24703        296516
#
#      isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
# 350         348           33            0     42.9  2021-01-04
# 351         348           33            0     42.9  2021-01-04
# 654         639          108            0    396.0  2021-11-03
# 655         563          108            0    396.0  2021-11-03
# 751           0         1664            8   1115.0  2022-02-07
# 752           0         1664            8   1115.0  2022-02-07
# 753           0         1664            8   1064.0  2022-02-07
# 785           0        21422            6   9346.0  2022-03-11
# 786           0        21422            6   9346.0  2022-03-11
# 797           0            4        24707  17552.0  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 46개
#      deathCnt   defCnt gubun           gubunEn  incDec  isolClearCnt  \
# 350         5     1442    경남  Gyeongsangnam-do      33          1089
# 351         5     1442    경남  Gyeongsangnam-do      33          1089
# 813       830   840006    경남  Gyeongsangnam-do    7385             0
# 814       830   840006    경남  Gyeongsangnam-do    7385             0
# 862      1215  1077670    경남  Gyeongsangnam-do    1515             0
# 863      1215  1077670    경남  Gyeongsangnam-do    1515             0
# 893      1256  1099030    경남  Gyeongsangnam-do     194             0
# 894      1256  1099030    경남  Gyeongsangnam-do     194             0
# 960      1369  1363835    경남  Gyeongsangnam-do    7982             0
# 961      1369  1363835    경남  Gyeongsangnam-do    7982             0
#
#      isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
# 350         348           33            0     42.9  2021-01-04
# 351         348           33            0     42.9  2021-01-04
# 813           0         7383            2  25346.0  2022-04-04
# 814           0         7383            2  25346.0  2022-04-04
# 862           0         1513            2  32517.0  2022-05-21
# 863           0         1513            2  32517.0  2022-05-21
# 893           0          184           10  33161.0  2022-06-20
# 894           0          184           10  33161.0  2022-06-20
# 960           0         7950           32  41151.0  2022-08-25
# 961           0         7950           32  41151.0  2022-08-25

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# 수정해야하는 데이터 개수 : 25개
#      deathCnt  defCnt gubun           gubunEn  incDec  isolClearCnt  \
# 653        42   13220    경남  Gyeongsangnam-do     108         12539
# 654        41   13220    경남  Gyeongsangnam-do     108         12508
# 750       121   36949    경남  Gyeongsangnam-do    1672         25659
# 751       121   36949    경남  Gyeongsangnam-do    1672         36949
# 752       121   35277    경남  Gyeongsangnam-do    1672         36949
# 784       243  309731    경남  Gyeongsangnam-do   21428        135967
# 785       233  309731    경남  Gyeongsangnam-do   21428        135970
# 796       477  581709    경남  Gyeongsangnam-do   24703        296516
# 797       477  581709    경남  Gyeongsangnam-do   24707        296516
# 800       579  660619    경남  Gyeongsangnam-do   21666        460063
#
#      isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
# 653         639          108            0    396.0  2021-11-03
# 654         563          108            0    396.0  2021-11-03
# 750           0         1664            8   1115.0  2022-02-07
# 751           0         1664            8   1115.0  2022-02-07
# 752           0         1664            8   1064.0  2022-02-07
# 784           0        21422            6   9346.0  2022-03-11
# 785           0        21422            6   9346.0  2022-03-11
# 796           0            4        24707  17552.0  2022-03-22
# 797           0        24703            4  17552.0  2022-03-22
# 800           0        21664            2  19933.0  2022-03-25

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [653, 750, 784, 796, 800, 806, 834, 1023, 1048, 1090, 1152, 1167]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 11
# 11
#       deathCnt   defCnt gubun           gubunEn  incDec  isolClearCnt  \
# 1163      1932  1840873    경남  Gyeongsangnam-do     420             0
# 1164      1932  1841296    경남  Gyeongsangnam-do     423             0
# 1165      1932  1841710    경남  Gyeongsangnam-do     416             0
# 1166         0  1842112    경남  Gyeongsangnam-do     402             0
# 1167      1934  1842240    경남  Gyeongsangnam-do     128             0
# 1168      1934  1842112    경남  Gyeongsangnam-do     402             0
# 1169      1934  1842755    경남  Gyeongsangnam-do     515             0
# 1170      1934  1843288    경남  Gyeongsangnam-do     533             0
# 1171      1936  1843817    경남  Gyeongsangnam-do     529             0
# 1172      1937  1844193    경남  Gyeongsangnam-do     376             0
#
#       isolIngCnt  localOccCnt  overFlowCnt  qurRate      stdDay
# 1163           0          420            0  56116.0  2023-03-16
# 1164           0          423            0  56129.0  2023-03-17
# 1165           0          416            0  56141.0  2023-03-18
# 1166           0          402            0  56154.0  2023-03-19
# 1167           0          128            0  56157.0  2023-03-20
# 1168           0          402            0  56154.0  2023-03-20
# 1169           0          515            0  56173.0  2023-03-21
# 1170           0          533            0  56189.0  2023-03-22
# 1171           0          529            0  56205.0  2023-03-23
# 1172           0          376            0  56217.0  2023-03-24

# %%
del_index = [654, 751, 752, 785, 796, 801, 806, 834, 1023, 1048, 1091, 1152, 1168]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun           gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    경남  Gyeongsangnam-do       0             0           0
# 1         0       0    경남  Gyeongsangnam-do       0             0           0
# 2         0       0    경남  Gyeongsangnam-do       0             0           0
# 3         0       0    경남  Gyeongsangnam-do       0             0           0
# 4         0       0    경남  Gyeongsangnam-do       0             0           0
# 5         0       0    경남  Gyeongsangnam-do       0             0           0
# 6         0       0    경남  Gyeongsangnam-do       0             0           0
# 7         0       0    경남  Gyeongsangnam-do       0             0           0
# 8         0       0    경남  Gyeongsangnam-do       0             0           0
# 9         0       0    경남  Gyeongsangnam-do       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24
# 5            0            0      0.0  2020-01-25
# 6            0            0      0.0  2020-01-26
# 7            0            0      0.0  2020-01-27
# 8            0            0      0.0  2020-01-28
# 9            0            0      0.0  2020-01-29

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### stdDay가 같은 데이터

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df_final.duplicated(['stdDay'], keep = False).sum()) + '개')
df_final[df_final.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 check

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')

# %% [markdown]
# # 제주

# %%
city = '제주'
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', 
# '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주'


df = pd.read_csv(f'Data/Rawdata/{city}_Raw.csv', encoding = 'cp949')
df.head()
# Out:
#    deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    제주    Jeju       0             0           0
# 1         0       0    제주    Jeju       0             0           0
# 2         0       0    제주    Jeju       0             0           0
# 3         0       0    제주    Jeju       0             0           0
# 4         0       0    제주    Jeju       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# deathCnt        0
# defCnt          0
# gubun           0
# gubunEn         0
# incDec          0
# isolClearCnt    0
# isolIngCnt      0
# localOccCnt     0
# overFlowCnt     0
# qurRate         0
# stdDay          0
# dtype: int64

# %% [markdown]
# ## 이상치 확인

# %%
plt.plot(df['defCnt'])

# %% [markdown]
# ## stdDay가 같은 데이터 추출

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df.duplicated(['stdDay'], keep = False).sum()) + '개')
df[df.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 68개
#      deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350         0     448    제주    Jeju      10           285         163
# 351         0     448    제주    Jeju      10           287         161
# 654         2    3121    제주    Jeju      17          3053          66
# 655         2    3121    제주    Jeju      17          3047          55
# 751        13    6544    제주    Jeju     369          6913           0
# 752        13    6913    제주    Jeju     369          5288           0
# 753        13    6913    제주    Jeju     369          6913           0
# 785        30   67199    제주    Jeju    4289         36235           0
# 786        33   67199    제주    Jeju    4289         39852           0
# 797        67  122662    제주    Jeju    3191         94088           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350            9            1     66.79  2021-01-04
# 351            9            1     66.79  2021-01-04
# 654           17            0    463.00  2021-11-03
# 655           17            0    463.00  2021-11-03
# 751          368            1    967.00  2022-02-07
# 752          368            1   1021.00  2022-02-07
# 753          368            1   1021.00  2022-02-07
# 785         4289            0   9930.00  2022-03-11
# 786         4289            0   9930.00  2022-03-11
# 797            0         3191  18125.00  2022-03-22

# %% [markdown]
# ## 완전히 같은 데이터 추출

# %%
print('모든 행이 동일한 데이터 개수 : ' + str(df.duplicated(keep = False).sum()) + '개')
df[df.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 44개
#      deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 813       114  177775    제주    Jeju    2261             0           0
# 814       114  177775    제주    Jeju    2261             0           0
# 862       174  232053    제주    Jeju     380             0           0
# 863       174  232053    제주    Jeju     380             0           0
# 893       182  237894    제주    Jeju      77             0           0
# 894       182  237894    제주    Jeju      77             0           0
# 960       207  313644    제주    Jeju    1634             0           0
# 961       207  313644    제주    Jeju    1634             0           0
# 981       216  329390    제주    Jeju     470             0           0
# 982       216  329390    제주    Jeju     470             0           0
#
#      localOccCnt  overFlowCnt  qurRate      stdDay
# 813         2261            0  26269.0  2022-04-04
# 814         2261            0  26269.0  2022-04-04
# 862          380            0  34289.0  2022-05-21
# 863          380            0  34289.0  2022-05-21
# 893           72            5  35152.0  2022-06-20
# 894           72            5  35152.0  2022-06-20
# 960         1622           12  46345.0  2022-08-25
# 961         1622           12  46345.0  2022-08-25
# 981          466            4  48672.0  2022-09-14
# 982          466            4  48672.0  2022-09-14

# %%
df2 = df.drop_duplicates().reset_index(drop = True)    # 완전히 같은 데이터 제거
print('모든 행이 동일한 데이터 개수 : ' + str(df2.duplicated(keep = False).sum()) + '개')
df2[df2.duplicated(keep = False)].head(10)
# Out:
# 모든 행이 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ## 수정해야하는 데이터만 추출

# %%
print('수정해야하는 데이터 개수 : ' + str(df2.duplicated(['stdDay'], keep = False).sum()) + '개')
df2[df2.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# 수정해야하는 데이터 개수 : 27개
#      deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 350         0     448    제주    Jeju      10           285         163
# 351         0     448    제주    Jeju      10           287         161
# 654         2    3121    제주    Jeju      17          3053          66
# 655         2    3121    제주    Jeju      17          3047          55
# 751        13    6544    제주    Jeju     369          6913           0
# 752        13    6913    제주    Jeju     369          5288           0
# 753        13    6913    제주    Jeju     369          6913           0
# 785        30   67199    제주    Jeju    4289         36235           0
# 786        33   67199    제주    Jeju    4289         39852           0
# 797        67  122662    제주    Jeju    3191         94088           0
#
#      localOccCnt  overFlowCnt   qurRate      stdDay
# 350            9            1     66.79  2021-01-04
# 351            9            1     66.79  2021-01-04
# 654           17            0    463.00  2021-11-03
# 655           17            0    463.00  2021-11-03
# 751          368            1    967.00  2022-02-07
# 752          368            1   1021.00  2022-02-07
# 753          368            1   1021.00  2022-02-07
# 785         4289            0   9930.00  2022-03-11
# 786         4289            0   9930.00  2022-03-11
# 797            0         3191  18125.00  2022-03-22

# %% [markdown]
# ## 데이터 수정

# %%
dup_index = list(df2[df2.duplicated(['stdDay'], keep = False)].index)
repair_index = []
for i in range(len(dup_index)):
    if dup_index[i] - dup_index[i-1] == 1:
        pass
    else:
        repair_index.append(dup_index[i])

repair_index
# Out:
# [350, 654, 751, 785, 797, 801, 807, 835, 1024, 1049, 1091, 1153, 1168]

# %%
print('n : 0 ~ ' + str(len(repair_index)-1))
n = int(input())
df2.iloc[repair_index[n]-4:repair_index[n]+6]
# Out:
# n : 0 ~ 12
# 12
#       deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 1164       271  388855    제주    Jeju     230             0           0
# 1165       271  389013    제주    Jeju     158             0           0
# 1166       272  389235    제주    Jeju     222             0           0
# 1167         0  389447    제주    Jeju     212             0           0
# 1168       272  389580    제주    Jeju     133             0           0
# 1169       272  389447    제주    Jeju     212             0           0
# 1170       272  389720    제주    Jeju     140             0           0
# 1171       272  389989    제주    Jeju     269             0           0
# 1172       272  390188    제주    Jeju     199             0           0
# 1173       272  390385    제주    Jeju     197             0           0
#
#       localOccCnt  overFlowCnt  qurRate      stdDay
# 1164          230            0  57340.0  2023-03-16
# 1165          157            1  57363.0  2023-03-17
# 1166          222            0  57396.0  2023-03-18
# 1167          212            0  57427.0  2023-03-19
# 1168          133            0  57447.0  2023-03-20
# 1169          212            0  57427.0  2023-03-20
# 1170          140            0  57467.0  2023-03-21
# 1171          269            0  57507.0  2023-03-22
# 1172          199            0  57536.0  2023-03-23
# 1173          197            0  57565.0  2023-03-24

# %%
del_index = [350, 655, 751, 753, 785, 797, 801, 807, 835, 1025, 1049, 1092, 1154, 1169]
df_final = df2.drop(index = del_index)
df_final.reset_index(drop = True, inplace = True)
df_final.head(10)
# Out:
#    deathCnt  defCnt gubun gubunEn  incDec  isolClearCnt  isolIngCnt  \
# 0         0       0    제주    Jeju       0             0           0
# 1         0       0    제주    Jeju       0             0           0
# 2         0       0    제주    Jeju       0             0           0
# 3         0       0    제주    Jeju       0             0           0
# 4         0       0    제주    Jeju       0             0           0
# 5         0       0    제주    Jeju       0             0           0
# 6         0       0    제주    Jeju       0             0           0
# 7         0       0    제주    Jeju       0             0           0
# 8         0       0    제주    Jeju       0             0           0
# 9         0       0    제주    Jeju       0             0           0
#
#    localOccCnt  overFlowCnt  qurRate      stdDay
# 0            0            0      0.0  2020-01-20
# 1            0            0      0.0  2020-01-21
# 2            0            0      0.0  2020-01-22
# 3            0            0      0.0  2020-01-23
# 4            0            0      0.0  2020-01-24
# 5            0            0      0.0  2020-01-25
# 6            0            0      0.0  2020-01-26
# 7            0            0      0.0  2020-01-27
# 8            0            0      0.0  2020-01-28
# 9            0            0      0.0  2020-01-29

# %% [markdown]
# ## 최종 확인

# %% [markdown]
# ### stdDay가 같은 데이터

# %%
print('stdDay가 동일한 데이터 개수 : ' + str(df_final.duplicated(['stdDay'], keep = False).sum()) + '개')
df_final[df_final.duplicated(['stdDay'], keep = False)].head(10)
# Out:
# stdDay가 동일한 데이터 개수 : 0개
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %% [markdown]
# ### 누적 확진자 수가 감소하는지 check

# %%
df_final[df_final['defCnt'].diff() < 0]
# Out:
# Empty DataFrame
# Columns: [deathCnt, defCnt, gubun, gubunEn, incDec, isolClearCnt, isolIngCnt, localOccCnt, overFlowCnt, qurRate, stdDay]
# Index: []

# %%
plt.plot(df_final['defCnt'])

# %% [markdown]
# ## 수정 후 데이터 저장

# %%
cleaned_df = df_final.copy()
cleaned_df.to_csv(f'Data/CleanedData/{city}_Cleaned.csv')
