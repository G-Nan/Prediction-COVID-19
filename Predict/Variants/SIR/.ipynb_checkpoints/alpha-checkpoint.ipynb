# %%
import os
os.chdir('D:\\Gnan\\DA\\KMU\\Prediction-COVID-19')
from utils import *
from model import *
from trainer import *

from tqdm.notebook import tqdm
from torch.optim.adam import Adam
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

import warnings
warnings.filterwarnings('ignore')

# %%
path = 'Data/Variants/SIR/alpha_delta/*.csv'
dic_files = Load_files.load_files(path, -18, -16)
data = dic_files['대구']
data
# Out:
#          stdDay  Susceptible  Alpha_Infected  Alpha_Recovered  Alpha_Dead  \
# 0    2021-04-12      2380065           39.65           163.36        2.00
# 1    2021-04-13      2380056           39.47           165.67        2.21
# 2    2021-04-14      2380045           39.18           168.82        2.21
# 3    2021-04-15      2380027           42.39           170.29        2.21
# 4    2021-04-16      2380023           39.86           173.86        2.21
# ..          ...          ...             ...              ...         ...
# 121  2021-08-11      2376752           12.67           486.64        3.05
# 122  2021-08-12      2376713           11.38           488.32        3.05
# 123  2021-08-13      2376656           10.09           490.18        3.05
# 124  2021-08-14      2376574            9.53           491.56        3.05
# 125  2021-08-15      2376517            9.41           492.25        3.05
#
#      Alpha_alpha  Alpha_beta  Alpha_gamma  Delta_Infected  Delta_Recovered  \
# 0       0.059242    0.058260     0.005296            0.32             0.00
# 1       0.072737    0.079807     0.000000            0.50             0.00
# 2       0.119906    0.037519     0.000000            0.72             0.00
# 3       0.024628    0.084218     0.000000            1.08             0.00
# 4       0.078574    0.052684     0.000000            1.16             0.00
# ..           ...         ...          ...             ...              ...
# 121     0.030942    0.132597     0.000000          814.69           726.09
# 122     0.050350    0.163445     0.000000          808.62           769.21
# 123     0.081696    0.136769     0.000000          815.03           816.95
# 124     0.060128    0.072403     0.000000          857.51           852.37
# 125     0.000000    0.000000     0.000000          893.95           870.08
#
#      Delta_Dead  Delta_alpha  Delta_beta  Delta_gamma
# 0          0.00     0.564647    0.000000          0.0
# 1          0.00     0.441681    0.000000          0.0
# 2          0.00     0.501913    0.000000          0.0
# 3          0.00     0.074358    0.000000          0.0
# 4          0.00     0.207690    0.000000          0.0
# ..          ...          ...         ...          ...
# 121        0.84     0.045715    0.052928          0.0
# 122        0.84     0.067316    0.059039          0.0
# 123        0.84     0.096082    0.043459          0.0
# 124        0.84     0.063482    0.020653          0.0
# 125        0.84     0.000000    0.000000          0.0
#
# [126 rows x 14 columns]

# %%
plt.plot(data['Alpha_alpha'])

# %%
path = 'hyperparameter/SIR/alpha/*.pkl'
files = glob.glob(path)
dic_hyperparameter = {}
for file in files:
    dic_hyperparameter[file[25:-4]] = load_hyperparameter(file)
    
dic_hyperparameter
# Out:
# {'BiGRU': [444, 0.001, 50, 8, 64, 16, 0.25],
#  'BiLSTM': [671, 0.001, 50, 4, 64, 16, 0.25],
#  'BiRNN': [507, 0.001, 50, 8, 64, 8, 0.25],
#  'GRU': [168, 0.001, 20, 8, 64, 32, 0.25],
#  'LSTM': [478, 0.001, 50, 4, 32, 16, 0.25],
#  'RNN': [477, 0.001, 50, 8, 32, 16, 0.25],
#  'seq2seq_BiGRU': [93,
#   0.001,
#   20,
#   2,
#   64,
#   16,
#   0.25,
#   <function utils.criterion2(actual, predict)>],
#  'seq2seq_BiLSTM': [198,
#   0.001,
#   20,
#   4,
#   32,
#   32,
#   0.25,
#   <function utils.criterion3(actual, predict)>],
#  'seq2seq_BiRNN': [561, 0.001, 50, 2, 64, 16, 0.25, MSELoss()],
#  'seq2seq_GRU': [636, 0.001, 50, 2, 64, 8, 0.25, MSELoss()],
#  'seq2seq_LSTM': [400, 0.001, 20, 2, 64, 16, 0.25, MSELoss()],
#  'seq2seq_RNN': [607, 0.001, 50, 2, 64, 8, 0.25, MSELoss()]}

# %%
dic_model = load_model_multiple(dic_hyperparameter, 'SIR', 'alpha')

# %%
df = Prepare_df.processing(data, 'stdDay', 'Alpha_alpha')

x = df.iloc[:, 0:]
y = df.iloc[:,:1]

ms = MinMaxScaler()
ss = StandardScaler()

ss.fit(x)
ms.fit(y)

predicted_values = {}
num_model = 0
for name, state in dic_model.items():
    batch_size = dic_hyperparameter[name][4]
    if num_model < 6:
        x, y, x_ss, y_ms, train_loader, test_loader = Prepare_df.split_data(df, 57, 60, 1, batch_size, 'mto')
        label_y, predicted = predict_mto(state, df, x_ss, y_ms)
        predicted_values[name] = [label_y, predicted]
    else:
        x, y, x_ss, y_ms, train_loader, test_loader = Prepare_df.split_data(df, 51, 60, 14, batch_size, 'mtm')
        label_y, predicted, first_label_y, first_predicted, all_predicted = predict_mtm(state, df, x_ss, y_ms, 7, 0.5, device)
        predicted_values[name] = [label_y, predicted, first_label_y, first_predicted, all_predicted]
        
    
    num_model += 1
# Out:
# torch.Size([57, 60, 3])
# torch.Size([57, 1])
# torch.Size([7, 60, 3])
# torch.Size([7, 1])
# torch.Size([57, 60, 3])
# torch.Size([57, 1])
# torch.Size([7, 60, 3])
# torch.Size([7, 1])
# torch.Size([57, 60, 3])
# torch.Size([57, 1])
# torch.Size([7, 60, 3])
# torch.Size([7, 1])
# torch.Size([57, 60, 3])
# torch.Size([57, 1])
# torch.Size([7, 60, 3])
# torch.Size([7, 1])
# torch.Size([57, 60, 3])
# torch.Size([57, 1])
# torch.Size([7, 60, 3])
# torch.Size([7, 1])
# torch.Size([57, 60, 3])
# torch.Size([57, 1])
# torch.Size([7, 60, 3])
# torch.Size([7, 1])
# torch.Size([51, 60, 3])
# torch.Size([51, 14, 1])
# torch.Size([0, 60, 3])
# torch.Size([0, 14, 1])
# torch.Size([51, 60, 3])
# torch.Size([51, 14, 1])
# torch.Size([0, 60, 3])
# torch.Size([0, 14, 1])
# torch.Size([51, 60, 3])
# torch.Size([51, 14, 1])
# torch.Size([0, 60, 3])
# torch.Size([0, 14, 1])
# torch.Size([51, 60, 3])
# torch.Size([51, 14, 1])
# torch.Size([0, 60, 3])
# torch.Size([0, 14, 1])
# torch.Size([51, 60, 3])
# torch.Size([51, 14, 1])
# torch.Size([0, 60, 3])
# torch.Size([0, 14, 1])
# torch.Size([51, 60, 3])
# torch.Size([51, 14, 1])
# torch.Size([0, 60, 3])
# torch.Size([0, 14, 1])

# %%
df = Prepare_df.processing(data, 'stdDay', 'Alpha_alpha')

x, y, x_ss, y_ms, train_loader, test_loader = Prepare_df.split_data(df, 37, 60, 14, 64, 'mtm')
print(x.shape)
print(y.shape)
print(x_ss.shape)
print(y_ms.shape)
# Out:
# torch.Size([37, 60, 3])
# torch.Size([37, 14, 1])
# torch.Size([14, 60, 3])
# torch.Size([14, 14, 1])
# torch.Size([51, 60, 3])
# torch.Size([51, 14, 1])
# torch.Size([51, 60, 3])
# torch.Size([51, 14, 1])

# %%
x = df.iloc[:, 0:]
y = df.iloc[:,:1]

ms = MinMaxScaler()
ss = StandardScaler()

ss.fit(x)
ms.fit(y)

model = dic_model['seq2seq_GRU']

train_predict = model(x_ss, y_ms, 14, 0.5, device)
predicted = train_predict.cpu().detach().numpy()
label_y = y_ms.cpu().detach().numpy()

predicted = predicted.reshape(-1, 1)
label_y = label_y.reshape(-1, 1)

predicted = ms.inverse_transform(predicted)
label_y = ms.inverse_transform(label_y)

predicted = predicted.reshape(-1, 14, 1)
label_y = label_y.reshape(-1, 14, 1)

first_predicted = predicted[:, 0, 0].reshape(-1, 1)
first_label_y = label_y[:, 0, :].reshape(-1, 1)

all_predicted = np.concatenate((first_predicted[:-1], predicted[-1]))

all_predicted.shape
# Out:
# (64, 1)

# %%
first_label_y.shape
# Out:
# (51, 1)

# %%
print(x.shape)
print(y.shape)
# Out:
# torch.Size([51, 60, 3])
# torch.Size([51, 14, 1])

# %%
actual_data2 = data['Alpha_Infected'][-64:]

# %%
actual_data = predicted_values['RNN'][0]
len(actual_data)
# Out:
# 64

# %%
actual_data2
# Out:
# 62     40.30
# 63     41.15
# 64     40.97
# 65     40.94
# 66     38.08
#        ...
# 121    12.67
# 122    11.38
# 123    10.09
# 124     9.53
# 125     9.41
# Name: Alpha_Infected, Length: 64, dtype: float64

# %%
print(rmse(actual_data[-14:], predicted_values['RNN'][1][-14:]))
plotting(actual_data, predicted_values['RNN'][1], 49)
# Out:
# 0.01618194310297532

# %%
print(rmse(actual_data[-7:], predicted_values['LSTM'][1][-7:]))
plotting(actual_data, predicted_values['LSTM'][1], 56)
# Out:
# 0.014153552982115833

# %%
print(rmse(actual_data[-7:], predicted_values['GRU'][1][-7:]))
plotting(actual_data, predicted_values['GRU'][1], 56)
# Out:
# 0.018524238265789722

# %%
print(rmse(actual_data[-7:], predicted_values['BiRNN'][1][-7:]))
plotting(actual_data, predicted_values['BiRNN'][1], 56)
# Out:
# 0.018049246461398143

# %%
print(rmse(actual_data[-7:], predicted_values['BiLSTM'][1][-7:]))
plotting(actual_data, predicted_values['BiLSTM'][1], 56)
# Out:
# 0.014274426412860867

# %%
print(rmse(actual_data[-7:], predicted_values['BiGRU'][1][-7:]))
plotting(actual_data, predicted_values['BiGRU'][1], 56)
# Out:
# 0.015937011720912195

# %%
print(rmse(actual_data[-7:], predicted_values['seq2seq_RNN'][4][-7:]))
plotting(actual_data, predicted_values['seq2seq_RNN'][4], 56)
# Out:
# 0.024629352943293183

# %%
print(rmse(actual_data[-7:], predicted_values['seq2seq_LSTM'][4][-7:]))
plotting(actual_data, predicted_values['seq2seq_LSTM'][4], 56)
# Out:
# 0.02381288156163025

# %%
print(rmse(actual_data[-7:], predicted_values['seq2seq_GRU'][4][-7:]))
plotting(actual_data, predicted_values['seq2seq_GRU'][4], 56)
# Out:
# 0.024783616944422958

# %%
print(rmse(actual_data[-7:], predicted_values['seq2seq_BiRNN'][4][-7:]))
plotting(actual_data, predicted_values['seq2seq_BiRNN'][4], 56)
# Out:
# 0.02401422919208014

# %%
print(rmse(actual_data[-7:], predicted_values['seq2seq_BiLSTM'][4][-7:]))
plotting(actual_data, predicted_values['seq2seq_BiLSTM'][4], 56)
# Out:
# 0.024046204360470915

# %%
print(rmse(actual_data[-7:], predicted_values['seq2seq_BiGRU'][4][-7:]))
plotting(actual_data, predicted_values['seq2seq_BiGRU'][4], 56)
# Out:
# 0.027439885080334257

# %%
best_model = 'BiLSTM'
datetime_index = data['stdDay'][-1*len(actual_data):]
df_predicted = pd.DataFrame()
df_predicted = pd.DataFrame(np.concatenate([actual_data, predicted_values[best_model][1]], axis = 1), 
                            index = datetime_index, 
                            columns = ['Alpha_origin', 'Alpha_Predicted'])

df_predicted.to_csv(f'Data/Predicted/Variants/Infected/alpha_{best_model}.csv')

# %%
df_predicted
# Out:
#             Alpha_origin  Alpha_Predicted
# stdDay
# 2021-06-13          1.80         1.971080
# 2021-06-14          2.40         1.904724
# 2021-06-15          1.92         1.807943
# 2021-06-16          1.92         1.688533
# 2021-06-17          0.84         1.564924
# ...                  ...              ...
# 2021-08-11          0.66         0.634585
# 2021-08-12          0.39         0.622334
# 2021-08-13          0.57         0.613830
# 2021-08-14          0.82         0.611241
# 2021-08-15          0.57         0.613635
#
# [64 rows x 2 columns]
